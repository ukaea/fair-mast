# %%
# !pip install matplotlib s3fs fsspec intake ipython xarray dask
# Out:
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/lib/python3.12/site-packages (3.8.4)
# Requirement already satisfied: s3fs in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2024.3.1)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2024.3.1)
# Requirement already satisfied: intake in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2.0.7)
# Requirement already satisfied: ipython in /opt/homebrew/anaconda3/lib/python3.12/site-packages (8.25.0)
# Requirement already satisfied: xarray in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2023.6.0)
# Requirement already satisfied: dask in /opt/homebrew/anaconda3/lib/python3.12/site-packages (2024.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from s3fs) (2.12.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from s3fs) (3.9.5)
# Requirement already satisfied: pyyaml in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from intake) (6.0.1)
# Requirement already satisfied: platformdirs in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from intake) (3.10.0)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from intake) (3.2.1)
# Requirement already satisfied: decorator in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (2.15.1)
# Requirement already satisfied: stack-data in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: pandas>=1.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from xarray) (2.2.2)
# Requirement already satisfied: click>=8.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dask) (2.2.1)
# Requirement already satisfied: partd>=1.2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dask) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from dask) (0.12.0)
# Requirement already satisfied: botocore<1.34.70,>=1.34.41 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.34.69)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.14.1)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas>=1.4->xarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pandas>=1.4->xarray) (2023.3)
# Requirement already satisfied: locket in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from partd>=1.2.0->dask) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.5)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: executing in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: asttokens in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: typing_extensions>=3.7 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from aioitertools<1.0.0,>=0.5.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (4.11.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.2)
# Requirement already satisfied: idna>=2.0 in /opt/homebrew/anaconda3/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)

# %%
import intake
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# First let's take a look at the top level shots. In this table we can find all of the metadata we have about particular shots.

# %%
#https://mastapp.site/intake/catalog.yaml
catalog  = intake.from_yaml_file("/Users/ds2718/ukaea/fair-mast/src/api/static/intake/catalog.yml")
list(catalog.entries)
# Out:
# ['index', 'level1']

# %%
shots_df = catalog.index.level1.shots.read()
shots_df
# Out:
#                                                  context  \
# 0      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 1      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 2      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 3      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 4      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# ...                                                  ...
# 15964  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 15965  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 15966  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 15967  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 15968  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
#
#                                      url  \
# 0      s3://mast/level1/shots/11695.zarr
# 1      s3://mast/level1/shots/11696.zarr
# 2      s3://mast/level1/shots/11697.zarr
# 3      s3://mast/level1/shots/11698.zarr
# 4      s3://mast/level1/shots/11699.zarr
# ...                                  ...
# 15964  s3://mast/level1/shots/30469.zarr
# 15965  s3://mast/level1/shots/30470.zarr
# 15966  s3://mast/level1/shots/30471.zarr
# 15967  s3://mast/level1/shots/30472.zarr
# 15968  s3://mast/level1/shots/30473.zarr
#
#                                      preshot_description  \
# 0                                       \n0.1T TF SHOT\n
# 1                              \nSTANDARD 0.3T TF SHOT\n
# 2                                      \nRAISE TO 0.5T\n
# 3                                      \nRAISE TO .56T\n
# 4                                      \nRAISE TO .58T\n
# ...                                                  ...
# 15964  \nRepeat with increased beam power (74 kV)\ncH...
# 15965  \nRepeat last using hydrogen in outboard and c...
# 15966  \nThe last plasma:\nConvert to i/b Helios 1724...
# 15967                    \nTF unwinding. TF only 80 kA\n
# 15968                   \nRepeat for second unwinding.\n
#
#                                     postshot_description campaign  \
# 0                                                 \nOK\n       M5
# 1                                                 \nOK\n       M5
# 2                               \nOK, ALARMS ARE LOWER\n       M5
# 3                       \nSTILL ALARMS BUT LOWER AGAIN\n       M5
# 4                                                 \nOK\n       M5
# ...                                                  ...      ...
# 15964                      \nGood shot. Modes present.\n       M9
# 15965                                     \nNo HF gas.\n       M9
# 15966                                     \nGood shot.\n       M9
# 15967  \nGood shot\nRise time faster than reference d...       M9
# 15968                                          \nGood.\n       M9
#
#       current_range divertor_config           plasma_shape commissioner  \
# 0              None    Conventional                   None         None
# 1              None    Conventional                   None         None
# 2              None    Conventional                   None         None
# 3              None    Conventional                   None         None
# 4              None    Conventional                   None         None
# ...             ...             ...                    ...          ...
# 15964        700 kA    Conventional  Connected Double Null         None
# 15965        700 kA    Conventional                   None         None
# 15966        700 kA    Conventional      Lower Single Null         None
# 15967          None    Conventional  Connected Double Null         None
# 15968          None    Conventional  Connected Double Null         None
#
#       facility  ... cpf_vol_ipmax cpf_vol_max  cpf_vol_truby cpf_wmhd_ipmax  \
# 0         MAST  ...           NaN         NaN            NaN            NaN
# 1         MAST  ...           NaN         NaN            NaN            NaN
# 2         MAST  ...           NaN         NaN            NaN            NaN
# 3         MAST  ...           NaN         NaN            NaN            NaN
# 4         MAST  ...           NaN         NaN            NaN            NaN
# ...        ...  ...           ...         ...            ...            ...
# 15964     MAST  ...      8.988730    9.047923            NaN   47466.249616
# 15965     MAST  ...      9.687049   10.055509            NaN   17290.432865
# 15966     MAST  ...      8.817559    9.283702            NaN   38063.582380
# 15967     MAST  ...           NaN         NaN            NaN            NaN
# 15968     MAST  ...           NaN         NaN            NaN            NaN
#
#       cpf_wmhd_max cpf_wmhd_truby  cpf_zeff_ipmax  cpf_zeff_max  \
# 0              NaN            NaN             NaN           NaN
# 1              NaN            NaN             NaN           NaN
# 2              NaN            NaN             NaN           NaN
# 3              NaN            NaN             NaN           NaN
# 4              NaN            NaN             NaN           NaN
# ...            ...            ...             ...           ...
# 15964    49115.805            NaN             NaN           NaN
# 15965    22310.516            NaN             NaN           NaN
# 15966    40906.090            NaN             NaN           NaN
# 15967          NaN            NaN             NaN           NaN
# 15968          NaN            NaN             NaN           NaN
#
#       cpf_zeff_truby cpf_zmag_efit
# 0                NaN           NaN
# 1                NaN           NaN
# 2                NaN           NaN
# 3                NaN           NaN
# 4                NaN           NaN
# ...              ...           ...
# 15964            NaN      0.015299
# 15965            NaN      0.015164
# 15966            NaN      0.014340
# 15967            NaN           NaN
# 15968            NaN           NaN
#
# [15969 rows x 290 columns]

# %% [markdown]
# # EFIT Data
# This notebook contains some examples of loading and plotting equillibrium reconstruction data from EFIT.
#
# First we can have a look at how many EFIT reconstructions are in the database:

# %%
sources_df = catalog.index.level1.sources.read()

sources_df = sources_df.loc[(sources_df.name == 'efm')]
sources_df
# Out:
#                                                   context description  \
# 14      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 35      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 58      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 79      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 101     {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# ...                                                   ...         ...
# 394555  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 394577  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 394599  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 394621  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
# 394642  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  Basic EFIT
#
#             quality          type           title  \
# 14      Not Checked  dcat:Dataset  Source Dataset
# 35      Not Checked  dcat:Dataset  Source Dataset
# 58      Not Checked  dcat:Dataset  Source Dataset
# 79      Not Checked  dcat:Dataset  Source Dataset
# 101     Not Checked  dcat:Dataset  Source Dataset
# ...             ...           ...             ...
# 394555  Not Checked  dcat:Dataset  Source Dataset
# 394577  Not Checked  dcat:Dataset  Source Dataset
# 394599  Not Checked  dcat:Dataset  Source Dataset
# 394621  Not Checked  dcat:Dataset  Source Dataset
# 394642  Not Checked  dcat:Dataset  Source Dataset
#
#                                         uuid name  \
# 14      32d09069-5bc1-5182-afe3-f4381cbb5c35  efm
# 35      58ca3107-52f7-59a0-b4e1-b24eb3202e72  efm
# 58      cf34cf2a-75a4-5a80-8c80-8233b1338bed  efm
# 79      b794da2d-d9b8-508a-93ab-54318e28467e  efm
# 101     a2ef275d-61ee-57a1-9e81-48ad4a5f4da5  efm
# ...                                      ...  ...
# 394555  ff73a569-fe8c-5220-9ea8-62f65f1ea63e  efm
# 394577  70fbe805-8c27-5f0d-ba34-b3d8188b6fb6  efm
# 394599  0e6d896b-582e-568e-a3cb-1b665af1a635  efm
# 394621  3fbbf1fc-da42-5f47-bbd9-f90a1fa1c850  efm
# 394642  93020098-b25a-575f-9b07-71a1986a6d35  efm
#
#                                       url                endpoint_url imas  \
# 14      s3://mast/level1/shots/15143.zarr  https://s3.echo.stfc.ac.uk
# 35      s3://mast/level1/shots/15144.zarr  https://s3.echo.stfc.ac.uk
# 58      s3://mast/level1/shots/15145.zarr  https://s3.echo.stfc.ac.uk
# 79      s3://mast/level1/shots/15146.zarr  https://s3.echo.stfc.ac.uk
# 101     s3://mast/level1/shots/15147.zarr  https://s3.echo.stfc.ac.uk
# ...                                   ...                         ...  ...
# 394555  s3://mast/level1/shots/15137.zarr  https://s3.echo.stfc.ac.uk
# 394577  s3://mast/level1/shots/15139.zarr  https://s3.echo.stfc.ac.uk
# 394599  s3://mast/level1/shots/15140.zarr  https://s3.echo.stfc.ac.uk
# 394621  s3://mast/level1/shots/15141.zarr  https://s3.echo.stfc.ac.uk
# 394642  s3://mast/level1/shots/15142.zarr  https://s3.echo.stfc.ac.uk
#
#         shot_id
# 14        15143
# 35        15144
# 58        15145
# 79        15146
# 101       15147
# ...         ...
# 394555    15137
# 394577    15139
# 394599    15140
# 394621    15141
# 394642    15142
#
# [14633 rows x 11 columns]

# %% [markdown]
# Let's look at the data for a particular shot. Here we are going to use shot 30420 as an example. Below we get the url for the `efm` data.

# %%
shot_id = 30420
url = sources_df.loc[sources_df.shot_id == shot_id].iloc[0].url
url
# Out:
# 's3://mast/level1/shots/30420.zarr'

# %% [markdown]
# `efm` source holds the EFIT data as a single dataset.

# %%
level1_catalog = catalog.level1.read()
dataset = level1_catalog(urlpath=url).sources.read()

dataset
# Out:
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/zarr/storage/_fsspec.py:195: UserWarning: fs (<fsspec.implementations.cached.SimpleCacheFileSystem object at 0x306a75070>) was not created with `asynchronous=True`, this may lead to surprising behavior
#   return cls(fs=fs, path=path, read_only=read_only, allowed_exceptions=allowed_exceptions)
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*
# Attributes:
#     dataset_uuid:  e84a303b-af96-56bc-aab3-031e2ab37630
#     shot_id:       30420

# %%
time_index = 50

plasma_current = dataset['plasma_current_rz'].dropna(dim='time')
plasma_current = plasma_current.isel(time=time_index)

polodial_flux_rz = dataset['psirz']
polodial_flux_rz = polodial_flux_rz.dropna(dim='profile_r')
polodial_flux_rz = polodial_flux_rz.isel(time=time_index)

lcfs_R = dataset['lcfs_r'].isel(time=time_index)
lcfs_Z = dataset['lcfs_z'].isel(time=time_index)

# Get the R and Z coordinates of the profiles.
r = dataset['r']
z = dataset['z']
R, Z = np.meshgrid(r, z)

# Get the x-point
xpoint_r = dataset['xpoint2_rc'][time_index]
xpoint_z = dataset['xpoint2_zc'][time_index]

# Get the current centre
mag_axis_r = dataset['current_centrd_r'][time_index]
mag_axis_z = dataset['current_centrd_z'][time_index]


# Get the last closed flux surface (LCFS)
lcfs_r = lcfs_R.values
lcfs_r = lcfs_r[~np.isnan(lcfs_r)]
lcfs_z = lcfs_Z.values
lcfs_z = lcfs_z[~np.isnan(lcfs_z)]

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.contourf(R, Z, polodial_flux_rz, cmap='magma', levels=50, label='Polodial Flux')
ax1.scatter(xpoint_r, xpoint_z, marker='x', color='green', label='X Point')
ax1.scatter(mag_axis_r, mag_axis_z, marker='o', color='purple', label='Current Centre')
ax1.plot(lcfs_r, lcfs_z, c='blue', linestyle='--', label='LCFS')
ax1.set_title(f'Polodial Flux for Shot {polodial_flux_rz.attrs["shot_id"]}')
ax1.set_ylabel('Z (m)')
ax1.set_xlabel('R (m)')

ax2.contourf(R, Z, plasma_current, cmap='magma', levels=20, label='Plasma Current')
ax2.scatter(xpoint_r, xpoint_z, marker='x', color='green', label='X Point')
ax2.scatter(mag_axis_r, mag_axis_z, marker='o', color='purple', label='Current Centre')
ax2.plot(lcfs_r, lcfs_z, c='blue', linestyle='--', label='LCFS')
ax2.set_title(f'Plasma Current for Shot {plasma_current.attrs["shot_id"]}')
plt.ylabel('Z (m)')
plt.xlabel('R (m)')
plt.legend()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/xarray/core/dataset.py in ?(self, name)
#    1206             variable = self._variables[name]
#    1207         except KeyError:
# -> 1208             _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1209
#
# KeyError: 'plasma_current_rz'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/xarray/core/dataset.py:1305, in Dataset.__getitem__(self, key)
#    1304 try:
# -> 1305     return self._construct_dataarray(key)
#    1306 except KeyError as e:
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/xarray/core/dataset.py:1208, in Dataset._construct_dataarray(self, name)
#    1207 except KeyError:
# -> 1208     _, name, variable = _get_virtual_variable(self._variables, name, self.sizes)
#    1210 needed_dims = set(variable.dims)
#
# File /opt/homebrew/anaconda3/lib/python3.12/site-packages/xarray/core/dataset_utils.py:79, in _get_virtual_variable(variables, key, dim_sizes)
#      78 if len(split_key) != 2:
# ---> 79     raise KeyError(key)
#      81 ref_name, var_name = split_key
#
# KeyError: 'plasma_current_rz'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/nm/_cbjksw57lq1_xxxvjhcsr1w0000gp/T/ipykernel_72635/494923854.py in ?()
#       1 time_index = 50
#       2
# ----> 3 plasma_current = dataset['plasma_current_rz'].dropna(dim='time')
#       4 plasma_current = plasma_current.isel(time=time_index)
#       5
#       6 polodial_flux_rz = dataset['psirz']
#
# /opt/homebrew/anaconda3/lib/python3.12/site-packages/xarray/core/dataset.py in ?(self, key)
#    1314
#    1315                 # If someone attempts `ds['foo' , 'bar']` instead of `ds[['foo', 'bar']]`
#    1316                 if isinstance(key, tuple):
#    1317                     message += f"\nHint: use a list to select multiple variables, for example `ds[{list(key)}]`"
# -> 1318                 raise KeyError(message) from e
#    1319
#    1320         if utils.iterable_of_hashable(key):
#    1321             return self._copy_listed(key)
#
# KeyError: "No variable named 'plasma_current_rz'. Variables on the dataset include []"
