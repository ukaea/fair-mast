# %% [markdown]
# # Quickstart
# This notebook shows some very simple example of getting started.
#
# First we need to install some dependancies into your conda or venv environment

# %%
# !pip install matplotlib s3fs fsspec intake ipython xarray dask

# %% [markdown]
# #### Open the intake Catalog

# %%
import intake
catalog  = intake.from_yaml_file("https://mastapp.site/intake/catalog.yml")
list(catalog.entries)
# Out:
# ['index', 'level1']

# %% [markdown]
# #### List All Shots

# %%
shots_df = catalog.index.level1.shots.read()
shots_df
# Out:
#                                      url  \
# 0      s3://mast/level1/shots/11695.zarr
# 1      s3://mast/level1/shots/11696.zarr
# 2      s3://mast/level1/shots/11697.zarr
# 3      s3://mast/level1/shots/11698.zarr
# 4      s3://mast/level1/shots/11699.zarr
# ...                                  ...
# 15916  s3://mast/level1/shots/30467.zarr
# 15917  s3://mast/level1/shots/30468.zarr
# 15918  s3://mast/level1/shots/30469.zarr
# 15919  s3://mast/level1/shots/30470.zarr
# 15920  s3://mast/level1/shots/30471.zarr
#
#                                      preshot_description  \
# 0                                       \n0.1T TF SHOT\n
# 1                              \nSTANDARD 0.3T TF SHOT\n
# 2                                      \nRAISE TO 0.5T\n
# 3                                      \nRAISE TO .56T\n
# 4                                      \nRAISE TO .58T\n
# ...                                                  ...
# 15916  \nRepeat with new neutron camera position.\ncH...
# ...

# %% [markdown]
# #### List All Sources

# %%
sources_df = catalog.index.level1.sources.read()
sources_df
# Out:
#                                               description      quality  \
# 0                                            Neutron Dose  Not Checked
# 1                                                Neutrons  Not Checked
# 2       H-mode and locked mode detector, Outer Saddle ...  Not Checked
# 3                                              Basic EFIT  Not Checked
# 4                                  Digital Plasma Control          Bad
# ...                                                   ...          ...
# 308129             Plasma Current and PF/TF Coil Currents  Not Checked
# 308130  Halo current Measurements (HAL), P2/P3 Halo Cu...          Bad
# 308131  Output from EFIT's wall model: calculated indu...  Not Checked
# 308132                        Neutral Beam Injection data  Not Checked
# 308133                                 CO2 Interferometry          Bad
#
#                                         uuid  shot_id name  \
# ...

# %% [markdown]
# #### List all signals Given a Shot Number

# %%
index_l1_catalog = catalog.index.level1.read()
signals_df = index_l1_catalog(shot_id=30420).signals.read()
signals_df
# Out:
#          quality         shape provenance description signal_type  \
# 0    Not Checked            []       None                Analysed
# 1    Not Checked      [132812]       None                Analysed
# 2    Not Checked            []       None                Analysed
# 3    Not Checked          [32]       None                Analysed
# 4    Not Checked          [32]       None                Analysed
# ..           ...           ...        ...         ...         ...
# 864  Not Checked  [18, 300000]       None                     Raw
# 865  Not Checked  [18, 300000]       None                     Raw
# 866  Not Checked      [300000]       None                     Raw
# 867  Not Checked  [18, 300000]       None                     Raw
# 868  Not Checked      [300000]       None                     Raw
#
#                  dimensions                                  uuid  shot_id  \
# 0                        []  241c96df-a7fc-55bf-b375-44bf15a49d32    30420
# ...

# %% [markdown]
# #### Open and plot shot data.
#
# Here we are visualising some plasma current data.

# %%
import matplotlib.pyplot as plt
level1_catalog = catalog.level1.read()
dataset = level1_catalog(urlpath="s3://mast/level1/shots/30420.zarr/amc").sources.read()
plt.plot(dataset['time'], dataset['plasma_current'])
