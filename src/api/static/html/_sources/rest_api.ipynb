# %% [markdown]
# # Querying Metadata with the REST API
#
# In this notebook we explore searching for metadata from the REST API. The REST API provides a method to programmatically extract a JSON representation of the meta data from the API.
#
# First we load some python dependancies that we will use as part of this notebook and set the variable `ENDPOINT_URL` to the location of the REST API.

# %%
import pandas as pd
import yaml
import requests
import dask
import intake
import dask.dataframe as dd

def load_config() -> dict:
    """Helper function to load the configuration file"""
    with open('config.yml') as file_handle:
        config = yaml.load(file_handle, yaml.FullLoader)
    return config

config = load_config()
ENDPOINT_URL = config['rest_api']

# %% [markdown]
# Below we print the location of the endpoint we will query in this notebook:

# %%
print(f"REST API Endpoint: {ENDPOINT_URL}")
# Out:
# REST API Endpoint: https://ada-sam-app.oxfordfun.com/json

# %% [markdown]
# ## Querying Shots with the REST API
#
# We're going to use the python `requests` library to query metadata from get metadata from the database. All we need to do to get a result is to query the database with a HTTP GET at the appropriate endpoint. For example, to get information about different experimental shots we can query the `/json/shots/` endpoint.

# %%
response = requests.get(f'{ENDPOINT_URL}/shots/')
result = response.json()
print(f"Query returned status code: {response.status_code}")
# Out:
# Query returned status code: 200

# %% [markdown]
# The shots endpoint returns a JSON payload with a lot of different information inside it. Let's take a closer look at what is returned:

# %%
result.keys()
# Out:
# dict_keys(['items', 'total', 'page', 'size', 'pages', 'column_metadata'])

# %% [markdown]
# The main item of interest is the `items` entry. This contains a list of meta-data items that correspond to our query. In this case, each item contains information about a different MAST shot. Each item lots of information about different shots, for example the shot ID, the campaign the shot was part of, the pre- and post-shot description by investigators.
#
# For more information on the what's returned by the API you can look at the endpoint documentation:
#
# https://ada-sam-app.oxfordfun.com/redoc
#
# Let's take a look at the first item returned:

# %%
result['items'][0]
# Out:
# {'shot_id': 47206,
#  'timestamp': '2023-03-31T16:04:44',
#  'preshot_description': 'retry',
#  'postshot_description': 'rtp stops st07 and st25, plus event 40 and 50 (px-cc-soft and trip) at 0.867s. Signs of BC action in xcm/ibc-* but it only made a slight difference to the LVPS dc link voltage (about 10V).',
#  'campaign': 'MU3',
#  'reference_shot': None,
#  'scenario': None,
#  'heating': None,
#  'pellets': False,
#  'rmp_coil': False,
#  'current_range': None,
#  'divertor_config': None,
#  'plasma_shape': None,
#  'comissioner': 'UKAEA',
#  'facility': 'MAST',
#  'cpf_p03249': None,
#  'cpf_p04673': None,
#  'cpf_p04674': None,
#  'cpf_p04675': None,
#  'cpf_p04676': None,
#  'cpf_p04677': None,
#  'cpf_p04678': None,
#  'cpf_p04679': None,
#  'cpf_p04680': None,
#  'cpf_p04681': None,
#  'cpf_p04833': None,
#  'cpf_p04993': None,
#  'cpf_p05007': None,
#  'cpf_p05008': None,
#  'cpf_p05009': None,
#  'cpf_p05010': None,
#  'cpf_p05011': None,
#  'cpf_p05015': None,
#  'cpf_p05016': None,
#  'cpf_p05017': None,
#  'cpf_p05025': None,
#  'cpf_p05027': None,
#  'cpf_p05028': None,
#  'cpf_p05029': None,
#  'cpf_p05030': None,
#  'cpf_p05032': None,
#  'cpf_p05033': None,
#  'cpf_p05153': None,
#  'cpf_p06000': None,
#  'cpf_p06001': None,
#  'cpf_p06002': None,
#  'cpf_p06003': None,
#  'cpf_p06004': None,
#  'cpf_p10963': None,
#  'cpf_p10964': None,
#  'cpf_p12441': None,
#  'cpf_p12450': None,
#  'cpf_p12451': None,
#  'cpf_p12452': None,
#  'cpf_p15202': None,
#  'cpf_p15203': None,
#  'cpf_p15209': None,
#  'cpf_p15659': None,
#  'cpf_p15660': None,
#  'cpf_p15661': None,
#  'cpf_p20000': None,
#  'cpf_p20204': None,
#  'cpf_p20205': None,
#  'cpf_p20206': None,
#  'cpf_p20207': None,
#  'cpf_p20208': None,
#  'cpf_p21010': None,
#  'cpf_p21011': None,
#  'cpf_p21012': None,
#  'cpf_p21021': None,
#  'cpf_p21022': None,
#  'cpf_p21029': None,
#  'cpf_p21035': None,
#  'cpf_p21037': None,
#  'cpf_p21041': None,
#  'cpf_p21042': None,
#  'cpf_p21043': None,
#  'cpf_p21044': None,
#  'cpf_p21045': None,
#  'cpf_p21046': None,
#  'cpf_p21047': None,
#  'cpf_p21048': None,
#  'cpf_p21051': None,
#  'cpf_p21052': None,
#  'cpf_p21053': None,
#  'cpf_p21054': None,
#  'cpf_p21055': None,
#  'cpf_p21056': None,
#  'cpf_p21075': None,
#  'cpf_p21076': None,
#  'cpf_p21077': None,
#  'cpf_p21078': None,
#  'cpf_p21079': None,
#  'cpf_p21080': None,
#  'cpf_p21081': None,
#  'cpf_p21082': None,
#  'cpf_p21083': None,
#  'cpf_p21084': None,
#  'cpf_p21085': None,
#  'cpf_p21086': None,
#  'cpf_p21087': None,
#  'cpf_p21088': None,
#  'cpf_p21089': None,
#  'cpf_p21092': None,
#  'cpf_p21093': None,
#  'cpf_abort': None,
#  'cpf_amin_ipmax': None,
#  'cpf_amin_max': None,
#  'cpf_amin_truby': None,
#  'cpf_area_ipmax': None,
#  'cpf_area_max': None,
#  'cpf_area_truby': None,
#  'cpf_bepmhd_ipmax': None,
#  'cpf_bepmhd_max': None,
#  'cpf_bepmhd_truby': None,
#  'cpf_betmhd_ipmax': None,
#  'cpf_betmhd_max': None,
#  'cpf_betmhd_truby': None,
#  'cpf_bt_ipmax': None,
#  'cpf_bt_max': None,
#  'cpf_bt_truby': None,
#  'cpf_c2ratio': None,
#  'cpf_column_temp_in': None,
#  'cpf_column_temp_out': None,
#  'cpf_creation': None,
#  'cpf_dwmhd_ipmax': None,
#  'cpf_dwmhd_max': None,
#  'cpf_dwmhd_truby': None,
#  'cpf_enbi_max_ss': None,
#  'cpf_enbi_max_sw': None,
#  'cpf_exp_date': None,
#  'cpf_exp_number': None,
#  'cpf_exp_time': None,
#  'cpf_gdc_duration': None,
#  'cpf_gdc_time': None,
#  'cpf_ibgas_pressure': None,
#  'cpf_ip_av': None,
#  'cpf_ip_max': None,
#  'cpf_jnbi_ipmax': None,
#  'cpf_jnbi_ipmax_ss': None,
#  'cpf_jnbi_ipmax_sw': None,
#  'cpf_jnbi_max': None,
#  'cpf_jnbi_max_ss': None,
#  'cpf_jnbi_max_sw': None,
#  'cpf_jnbi_total': None,
#  'cpf_jnbi_total_ss': None,
#  'cpf_jnbi_total_sw': None,
#  'cpf_jnbi_truby': None,
#  'cpf_jnbi_truby_ss': None,
#  'cpf_jnbi_truby_sw': None,
#  'cpf_johm_ipmax': None,
#  'cpf_johm_max': None,
#  'cpf_johm_total': None,
#  'cpf_johm_truby': None,
#  'cpf_kappa_ipmax': None,
#  'cpf_kappa_max': None,
#  'cpf_kappa_truby': None,
#  'cpf_li_2_ipmax': None,
#  'cpf_li_2_max': None,
#  'cpf_li_2_truby': None,
#  'cpf_li_3_ipmax': None,
#  'cpf_li_3_max': None,
#  'cpf_li_3_truby': None,
#  'cpf_log_base_pressure': None,
#  'cpf_ndl_co2_ipmax': None,
#  'cpf_ndl_co2_max': None,
#  'cpf_ndl_co2_truby': None,
#  'cpf_ne0_ipmax': None,
#  'cpf_ne0_max': None,
#  'cpf_ne0_truby': None,
#  'cpf_ne0ratio_ipmax': None,
#  'cpf_ne0ruby': None,
#  'cpf_ne_bar_ipmax': None,
#  'cpf_ne_yag_bar_ipmax': None,
#  'cpf_ngreenwald_ipmax': None,
#  'cpf_ngreenwaldratio_ipmax': None,
#  'cpf_o2ratio': None,
#  'cpf_objective': None,
#  'cpf_pe0_ipmax': None,
#  'cpf_pe0_max': None,
#  'cpf_pe0_truby': None,
#  'cpf_pe0ruby': None,
#  'cpf_pic': None,
#  'cpf_pnbi_ipmax': None,
#  'cpf_pnbi_ipmax_ss': None,
#  'cpf_pnbi_ipmax_sw': None,
#  'cpf_pnbi_max': None,
#  'cpf_pnbi_max_ss': None,
#  'cpf_pnbi_max_sw': None,
#  'cpf_pnbi_truby': None,
#  'cpf_pnbi_truby_ss': None,
#  'cpf_pnbi_truby_sw': None,
#  'cpf_pohm_ipmax': None,
#  'cpf_pohm_max': None,
#  'cpf_pohm_truby': None,
#  'cpf_postshot': None,
#  'cpf_prad_ipmax': None,
#  'cpf_prad_max': None,
#  'cpf_prad_truby': None,
#  'cpf_pradne2': None,
#  'cpf_preshot': None,
#  'cpf_program': None,
#  'cpf_pulno': None,
#  'cpf_q95_ipmax': None,
#  'cpf_q95_min': None,
#  'cpf_q95_truby': None,
#  'cpf_reference': None,
#  'cpf_rgeo_ipmax': None,
#  'cpf_rgeo_max': None,
#  'cpf_rgeo_truby': None,
#  'cpf_rinner_da': None,
#  'cpf_rinner_efit': None,
#  'cpf_rmag_efit': None,
#  'cpf_router_da': None,
#  'cpf_router_efit': None,
#  'cpf_sarea_ipmax': None,
#  'cpf_sarea_max': None,
#  'cpf_sarea_truby': None,
#  'cpf_sl': None,
#  'cpf_summary': None,
#  'cpf_tamin_max': None,
#  'cpf_tarea_max': None,
#  'cpf_tautot_ipmax': None,
#  'cpf_tautot_max': None,
#  'cpf_tautot_truby': None,
#  'cpf_tbepmhd_max': None,
#  'cpf_tbetmhd_max': None,
#  'cpf_tbt_max': None,
#  'cpf_tdwmhd_max': None,
#  'cpf_te0_ipmax': None,
#  'cpf_te0_max': None,
#  'cpf_te0_truby': None,
#  'cpf_te0ratio_ipmax': None,
#  'cpf_te0ruby': None,
#  'cpf_te_yag_bar_ipmax': None,
#  'cpf_tend': None,
#  'cpf_tend_ibgas': None,
#  'cpf_tend_nbi': None,
#  'cpf_tend_nbi_ss': None,
#  'cpf_tend_nbi_sw': None,
#  'cpf_term_code': None,
#  'cpf_tftend': None,
#  'cpf_tftstart': None,
#  'cpf_tipmax': None,
#  'cpf_tkappa_max': None,
#  'cpf_tli_2_max': None,
#  'cpf_tli_3_max': None,
#  'cpf_tndl_co2_max': None,
#  'cpf_tne0_max': None,
#  'cpf_tpe0_max': None,
#  'cpf_tpnbi_max': None,
#  'cpf_tpnbi_max_ss': None,
#  'cpf_tpnbi_max_sw': None,
#  'cpf_tpohm_max': None,
#  'cpf_tprad_max': None,
#  'cpf_tq95_min': None,
#  'cpf_trgeo_max': None,
#  'cpf_truby': None,
#  'cpf_tsarea_max': None,
#  'cpf_tstart': None,
#  'cpf_tstart_ibgas': None,
#  'cpf_tstart_nbi': None,
#  'cpf_tstart_nbi_ss': None,
#  'cpf_tstart_nbi_sw': None,
#  'cpf_ttautot_max': None,
#  'cpf_tte0_max': None,
#  'cpf_tvol_max': None,
#  'cpf_twmhd_max': None,
#  'cpf_tzeff_max': None,
#  'cpf_useful': None,
#  'cpf_vol_ipmax': None,
#  'cpf_vol_max': None,
#  'cpf_vol_truby': None,
#  'cpf_wmhd_ipmax': None,
#  'cpf_wmhd_max': None,
#  'cpf_wmhd_truby': None,
#  'cpf_zeff_ipmax': None,
#  'cpf_zeff_max': None,
#  'cpf_zeff_truby': None,
#  'cpf_zmag_efit': None}

# %% [markdown]
# Of course, we can read all this JSON data directly into common python data analysis packages, for example, we can create a `pandas` dataframe for the meta data.

# %%
df = pd.DataFrame(result['items'])
df.head()
# Out:
#    shot_id            timestamp  \
# 0    47206  2023-03-31T16:04:44
# 1    47205  2023-03-31T15:52:21
# 2    47204  2023-03-31T15:38:20
# 3    47203  2023-03-31T15:19:43
# 4    47202  2023-03-31T14:59:33
#
#                                  preshot_description  \
# 0                                              retry
# 1  Brake chopper test. Restore 44539. P1, TF and ...
# 2  Repeat daily test shot with PS enable windows ...
# 3  Restore prepared setup all-coil-first-shot. Ex...
# 4                                              retry
#
#                                 postshot_description campaign  reference_shot  \
# 0  rtp stops st07 and st25, plus event 40 and 50 ...      MU3             NaN
# 1                                              abort      MU3         44539.0
# 2  Error in channels 11 and 12 on bolometer. Wave...      MU3             NaN
# 3  Looks OK, I don't have a code to test the magn...      MU3             NaN
# 4     Ran OK, no trips, all PF currents as demanded.      MU3         45847.0
#
#    scenario heating  pellets  rmp_coil  ... cpf_vol_ipmax cpf_vol_max  \
# 0       NaN    None    False     False  ...          None        None
# 1       NaN    None    False     False  ...          None        None
# 2       NaN    None    False     False  ...          None        None
# 3       NaN    None    False     False  ...          None        None
# 4       NaN    None    False     False  ...          None        None
#
#   cpf_vol_truby cpf_wmhd_ipmax cpf_wmhd_max cpf_wmhd_truby cpf_zeff_ipmax  \
# 0          None           None         None           None           None
# 1          None           None         None           None           None
# 2          None           None         None           None           None
# 3          None           None         None           None           None
# 4          None           None         None           None           None
#
#   cpf_zeff_max cpf_zeff_truby cpf_zmag_efit
# 0         None           None          None
# 1         None           None          None
# 2         None           None          None
# 3         None           None          None
# 4         None           None          None
#
# [5 rows x 280 columns]

# %% [markdown]
# ### Searching & Filtering Data
#
# All REST API endpoints can take query parameters to filter the data returned. For example, we can return all shots for the `M9` campaign by using the approrpiate query string.
#
# For example, we can query for everything from the `M9` campaign by adding `?campaign=M9` to our query string.

# %%
response = requests.get(f"{config['rest_api']}/shots/?campaign=M9")
result = response.json()
pd.DataFrame(result['items'])
# Out:
#     shot_id            timestamp  \
# 0     30473  2013-09-27T15:51:00
# 1     30472  2013-09-27T15:36:00
# 2     30471  2013-09-27T15:20:00
# 3     30470  2013-09-27T15:03:00
# 4     30469  2013-09-27T14:39:00
# 5     30468  2013-09-27T14:21:00
# 6     30467  2013-09-27T14:03:00
# 7     30466  2013-09-27T13:40:00
# 8     30465  2013-09-27T13:13:00
# 9     30464  2013-09-27T12:56:00
# 10    30463  2013-09-27T12:39:00
# 11    30462  2013-09-27T12:23:00
# 12    30461  2013-09-27T12:06:00
# 13    30460  2013-09-27T11:52:00
# 14    30459  2013-09-27T11:34:00
# 15    30458  2013-09-27T11:14:00
# 16    30457  2013-09-27T10:54:00
# 17    30456  2013-09-27T10:36:00
# 18    30455  2013-09-27T10:12:00
# 19    30454  2013-09-27T09:50:00
# 20    30453  2013-09-27T09:00:00
# 21    30452  2013-09-27T08:26:00
# 22    30451  2013-09-26T16:58:00
# 23    30450  2013-09-26T16:37:00
# 24    30449  2013-09-26T16:20:00
# 25    30448  2013-09-26T15:55:00
# 26    30447  2013-09-26T15:20:00
# 27    30446  2013-09-26T14:41:00
# 28    30445  2013-09-26T14:07:00
# 29    30444  2013-09-26T12:21:00
# 30    30443  2013-09-26T11:44:00
# 31    30442  2013-09-26T11:22:00
# 32    30441  2013-09-26T10:28:00
# 33    30440  2013-09-26T10:05:00
# 34    30439  2013-09-26T09:13:00
# 35    30438  2013-09-26T08:57:00
# 36    30437  2013-09-26T08:41:00
# 37    30436  2013-09-25T16:17:00
# 38    30435  2013-09-25T15:55:00
# 39    30434  2013-09-25T15:39:00
# 40    30433  2013-09-25T15:19:00
# 41    30432  2013-09-25T15:04:00
# 42    30431  2013-09-25T14:33:00
# 43    30430  2013-09-25T14:17:00
# 44    30429  2013-09-25T14:13:00
# 45    30428  2013-09-25T13:57:00
# 46    30427  2013-09-25T13:39:00
# 47    30426  2013-09-25T13:14:00
# 48    30425  2013-09-25T12:55:00
# 49    30424  2013-09-25T12:38:00
#
#                                   preshot_description  \
# 0                    \nRepeat for second unwinding.\n
# 1                     \nTF unwinding. TF only 80 kA\n
# 2   \nThe last plasma:\nConvert to i/b Helios 1724...
# 3   \nRepeat last using hydrogen in outboard and c...
# 4   \nRepeat with increased beam power (74 kV)\ncH...
# 5   \nRepeat with new neutron camera position.\ncH...
# 6   \nRepeat with new neutron camera position.\ncH...
# 7   \nRestore 30459 - now starting shot with deute...
# 8   \nRepeat last shot with new neutron camera set...
# 9   \nRaise the level of hydrogen in the plasma to...
# 10  \nReturn to lower hydrogen level shot\nRestore...
# 11  \nRepeat last after missing beam.\ncHFS 213 mb...
# 12  \nRestore 30458 to increase hydrogen level.\nc...
# 13  \nRepeat the previous with neutron camera in n...
# 14  \nDecrease the Hydrogen amount.\nMove switch t...
# 15               \nRefill main LFS plenum with H2. \n
# 16  \nrevert to CHFs gas with D2 to check nothing ...
# 17                                  \nraise gas 20%\n
# 18   \nreplace CHFS gas with LFS gas, retime YAG TS\n
# 19        \nreference shot uses CHFS gas at 200mBar\n
# 20                                        \nPF test\n
# 21                                        \nTF test\n
# 22  \nRepeat with TF settings as in 29341. Very lo...
# 23      \nReload 30377 and TF settings as in 29301.\n
# 24  \nReload 30366. TF settings as in 29301 after ...
# 25  \nreload scenario 6 1 beam SS at 50 ms - corre...
# 26  \nRestore shot 30383 for MHD-012. Changed timi...
# 27  \nRestore standard TF test shot 24529 for Grah...
# 28  \nRepeat with SEG01_GP and SEG12_GP isoflux pr...
# 29     \nRepeat, with SS NBI. S file generation on.\n
# 30                                        \nRepeat.\n
# 31  \nStarting rtefit testing. Restore shot 30338 ...
# 32  \nReload 29417. Increased duration of impurity...
# 33  \nReload 29275. N injection at 255 ms. Move ZR...
# 34                \nReload 29261. N puff at 195 ms.\n
# 35                         \nStandard PF test shot.\n
# 36                         \nStandard TF test shot.\n
# 37             \nVac.Pump checks: P4(16kA)+P5(15kA)\n
# 38                     \nP5 lower  (14kA) + P3(2kV)\n
# 39                           \nP4L (14kA) + P3(2kV)\n
# 40                             \nP5 upper 14kA + P3\n
# 41                        \nP4(upper) at 14kA + P3 \n
# 42  \nBeam into gas shot - TF only 100ms beam leng...
# 43                      \nrepeat IP=910 TF=0.624 T \n
# 44  \nincrease TF to 91 kA BT=0.624 IP=910 kA - TF...
# 45  \nrepeat - bringing TF start time 200 ms earli...
# 46  \nrestore from Lgarzot set up file based on 22...
# 47      \nuse 30421 with IELM = 1.3 KA and pellets \n
# 48  \nreload 30421 - IP ramp up  from 600 at 400ms...
# 49                        \nScenario 3 for Pellets \n
#
#                                  postshot_description campaign  \
# 0                                           \nGood.\n       M9
# 1   \nGood shot\nRise time faster than reference d...       M9
# 2                                      \nGood shot.\n       M9
# 3                                      \nNo HF gas.\n       M9
# 4                       \nGood shot. Modes present.\n       M9
# 5                        \nGood beam.\nGood repeat.\n       M9
# 6   \nTwo times lower DD neutron rate than referen...       M9
# 7         \nGood repeat, however modes disappeared.\n       M9
# 8                                    \nGood repeat.\n       M9
# 9   \nGood beam.\nGood repeat. H mode 140ms to 190...       M9
# 10  \nH mode from 150ms to 190ms.\nOnly a small ef...       M9
# 11  \nGood repeat. H mode present, good beam.\nTyp...       M9
# 12         \nNo beam - calorimeter gate not opened.\n       M9
# 13  \nGood repeat - H mode from 140 to 190ms. ELMy...       M9
# 14  \nDuration similar to previous.\nMore deuteriu...       M9
# 15                 \nToo much H2 - modes disappear.\n       M9
# 16                   \nmiserable shot, but modes OK\n       M9
# 17  \ndensity increased and shot a bit longer but ...       M9
# 18  \nShot a bit shorter mostly due to lack of H m...       M9
# 19  \nran OK, density a bit low, intermittent H mo...       M9
# 20                                             \nOK\n       M9
# 21                                           \nOkay\n       M9
# 22  \nOk. Dies very early, but late enough for the...       M9
# 23  \nOk, although shorter than reference, probabl...       M9
# 24                                 \nOk. Good shot.\n       M9
# 25  \nno real time density so shot flooded with ga...       M9
# 26                                           \nOk. \n       M9
# 27                                            \nOK.\n       M9
# 28   \nShot terminated at 320ms, but may be useful.\n       M9
# 29  \nShot terminated early at 240ms, but coils ra...       M9
# 30                                     \nGood shot.\n       M9
# 31  \nNo breakdown. Not a fuelling problem, and co...       M9
# 32  \nOk, nice long shot. N injected. Underdense w...       M9
# 33  \nOk. Good shot. N injected. Smaller ELMs than...       M9
# 34                  \nOk. As reference. N observed.\n       M9
# 35                               \nOk. Runcheck ok.\n       M9
# 36                                            \nOk.\n       M9
# 37  \nsector 6  (45deg) trips. Sec 8 (no shield) d...       M9
# 38                                             \nOK\n       M9
# 39                                             \nok\n       M9
# 40                                             \nOK\n       M9
# 41                                             \nok\n       M9
# 42                                    \ngood beams \n       M9
# 43  \ngood beam - good shot - TF resistance OK BUT...       M9
# 44                             \naborted JET pulse \n       M9
# 45             \ngood shot TF now reaches flat top \n       M9
# 46  \ngood beams - H-mode from 280ms  \nX_MM_LVPS ...       M9
# 47  \ngood beams - all ELM coils fired- good pelle...       M9
# 48  \ngood beams - good ramp up of current until f...       M9
# 49  \nenormous pellet increase density by almost 1...       M9
#
#     reference_shot  scenario                  heating  pellets rmp_coil  ...  \
# 0            16492       NaN                    Ohmic    False    False  ...
# 1            16492       NaN                    Ohmic    False    False  ...
# 2            30470       2.0                  SS Beam    False    False  ...
# 3            30467       2.0                  SS Beam    False     None  ...
# 4            30467       3.0                  SS Beam    False    False  ...
# 5            30467       2.0                  SS Beam    False    False  ...
# 6            30459       3.0                  SS Beam    False    False  ...
# 7            30459       3.0                  SS Beam    False    False  ...
# 8            30464       3.0                  SS Beam    False    False  ...
# 9            30459       3.0                  SS Beam    False    False  ...
# 10           30459       3.0                  SS Beam    False    False  ...
# 11           30458       3.0                  SS Beam    False    False  ...
# 12           30458       3.0                    Ohmic    False     None  ...
# 13           30459       3.0                  SS Beam    False    False  ...
# 14           30457       3.0                  SS Beam    False    False  ...
# 15           30457       2.0                  SS Beam    False    False  ...
# 16           30454       3.0                  SS Beam    False    False  ...
# 17           30455       3.0                  SS Beam    False    False  ...
# 18           30454       1.0                  SS Beam    False    False  ...
# 19           30080       3.0                  SS Beam    False    False  ...
# 20           29713       NaN                    Ohmic    False    False  ...
# 21           24529       NaN                    Ohmic    False    False  ...
# 22           30377       2.0                  SS Beam    False    False  ...
# 23           30377       2.0                  SS Beam    False    False  ...
# 24           30366       2.0                  SS Beam    False    False  ...
# 25           29089       3.0                  SS Beam    False     None  ...
# 26           30383       4.0                  SS Beam    False    False  ...
# 27           24529       NaN                    Ohmic    False    False  ...
# 28           30444       3.0                  SS Beam    False    False  ...
# 29           30442       3.0                  SS Beam    False     None  ...
# 30           30442       3.0                    Ohmic    False    False  ...
# 31           30338       NaN                    Ohmic    False     None  ...
# 32           29417       3.0                  SS Beam    False    False  ...
# 33           29275       4.0                  SS Beam    False     True  ...
# 34           29261       4.0                  SS Beam    False    False  ...
# 35           29713       NaN                    Ohmic    False    False  ...
# 36           24529       NaN                    Ohmic    False    False  ...
# 37           30395       NaN                    Ohmic    False    False  ...
# 38           24969       NaN                    Ohmic    False    False  ...
# 39           24967       NaN                    Ohmic    False    False  ...
# 40           24979       NaN                    Ohmic    False    False  ...
# 41           24977       NaN                    Ohmic    False    False  ...
# 42           30403       NaN  2 Beams,SS Beam,SW Beam    False    False  ...
# 43           22664       4.0  2 Beams,SS Beam,SW Beam    False    False  ...
# 44           22664       4.0                    Ohmic    False     None  ...
# 45           22664       4.0  2 Beams,SS Beam,SW Beam    False    False  ...
# 46           22664       4.0  2 Beams,SS Beam,SW Beam    False    False  ...
# 47           30421       6.0  2 Beams,SS Beam,SW Beam     True     True  ...
# 48           30421       6.0  2 Beams,SS Beam,SW Beam    False     True  ...
# 49           30421       6.0  2 Beams,SS Beam,SW Beam     True     True  ...
#
#    cpf_vol_ipmax cpf_vol_max cpf_vol_truby cpf_wmhd_ipmax cpf_wmhd_max  \
# 0            NaN         NaN           NaN            NaN          NaN
# 1            NaN         NaN           NaN            NaN          NaN
# 2       8.817559    9.283702           0.0   38063.582380    40906.090
# 3       9.687049   10.055509           0.0   17290.432865    22310.516
# 4       8.988730    9.047923           0.0   47466.249616    49115.805
# 5       9.102411    9.107017           0.0   48516.962675    49382.133
# 6       9.029202    9.046394           0.0   49469.122469    52653.445
# 7       8.960357    9.183257           0.0   57084.818719    57487.250
# 8       9.164259    9.232228           0.0   50343.600779    59688.746
# 9       9.038266    9.254038           0.0   53875.521385    59566.730
# 10      9.180079    9.286997           0.0   54159.988464    60221.860
# 11      9.070707    9.174255           0.0   54121.281054    58587.890
# 12      9.178861    9.201421           0.0   30480.655937    32651.332
# 13      9.096625    9.193935           0.0   56986.547813    58198.630
# 14      9.287829    9.293427           0.0   55675.753591    61687.066
# 15      9.166664    9.226780           0.0   49758.189503    57926.260
# 16      9.018215    9.212822           0.0   44840.697733    53959.360
# 17      8.543673    8.593537           0.0   33368.213702    37685.863
# 18      8.289615    8.615048           0.0   29649.260554    39124.020
# 19      9.121819    9.194451           0.0   45477.618580    54211.120
# 20           NaN         NaN           NaN            NaN          NaN
# 21           NaN         NaN           NaN            NaN          NaN
# 22      7.022583    7.216327           0.0   25568.796591    25959.920
# 23      7.812098    9.001694           0.0   47538.293348    63824.930
# 24      6.597761    8.314781           0.0   65728.478985    70913.760
# 25      8.815775    9.058844           0.0   32439.705193    56034.824
# 26           NaN         NaN           NaN            NaN          NaN
# 27           NaN         NaN           NaN            NaN          NaN
# 28      9.714882   10.370983           0.0   11191.883363    57275.793
# 29      8.294926   10.425436           0.0   61047.623087    61704.594
# 30      9.666388   10.215392           0.0    9286.036456    28979.887
# 31           NaN         NaN           NaN            NaN          NaN
# 32      8.471967    8.497842           0.0   43352.395460    56814.320
# 33      8.656765    8.914458           0.0  109718.993874   116309.970
# 34      8.254542    8.889631           0.0   95721.941212   106715.414
# 35           NaN         NaN           NaN            NaN          NaN
# 36           NaN         NaN           NaN            NaN          NaN
# 37           NaN         NaN           NaN            NaN          NaN
# 38           NaN         NaN           NaN            NaN          NaN
# 39           NaN         NaN           NaN            NaN          NaN
# 40           NaN         NaN           NaN            NaN          NaN
# 41           NaN         NaN           NaN            NaN          NaN
# 42           NaN         NaN           NaN            NaN          NaN
# 43      8.477901    8.643984           0.0  170476.168860   178948.920
# 44           NaN         NaN           NaN            NaN          NaN
# 45      8.500732    8.650459           0.0  144699.332930   170789.940
# 46      8.541490    8.835944           0.0  152923.988849   169370.300
# 47      7.144154    7.378681           0.0   60606.465501    69974.980
# 48      6.845509    7.572480           0.0   60765.969684    82571.230
# 49      7.014817    7.609876           0.0   56703.727206    86957.660
#
#    cpf_wmhd_truby cpf_zeff_ipmax cpf_zeff_max cpf_zeff_truby cpf_zmag_efit
# 0             NaN           None         None           None      0.000000
# 1             NaN           None         None           None      0.000000
# 2             0.0           None         None           None      0.014340
# 3             0.0           None         None           None      0.015164
# 4             0.0           None         None           None      0.015299
# 5             0.0           None         None           None      0.012445
# 6             0.0           None         None           None      0.013202
# 7             0.0           None         None           None      0.015284
# 8             0.0           None         None           None      0.014395
# 9             0.0           None         None           None      0.013686
# 10            0.0           None         None           None      0.012317
# 11            0.0           None         None           None      0.012485
# 12            0.0           None         None           None      0.014711
# 13            0.0           None         None           None      0.014128
# 14            0.0           None         None           None      0.013762
# 15            0.0           None         None           None      0.014747
# 16            0.0           None         None           None      0.015216
# 17            0.0           None         None           None      0.013499
# 18            0.0           None         None           None      0.011206
# 19            0.0           None         None           None      0.016469
# 20            NaN           None         None           None      0.000000
# 21            NaN           None         None           None      0.000000
# 22            0.0           None         None           None     -0.000501
# 23            0.0           None         None           None      0.005763
# 24            0.0           None         None           None      0.001269
# 25            0.0           None         None           None      0.150922
# 26            NaN           None         None           None      0.000000
# 27            NaN           None         None           None      0.000000
# 28            0.0           None         None           None      0.022854
# 29            0.0           None         None           None      0.022490
# 30            0.0           None         None           None      0.023246
# 31            NaN           None         None           None      0.000000
# 32            0.0           None         None           None      0.061943
# 33            0.0           None         None           None      0.000019
# 34            0.0           None         None           None      0.024210
# 35            NaN           None         None           None      0.000000
# 36            NaN           None         None           None      0.000000
# 37            NaN           None         None           None      0.000000
# 38            NaN           None         None           None      0.000000
# 39            NaN           None         None           None      0.000000
# 40            NaN           None         None           None      0.000000
# 41            NaN           None         None           None      0.000000
# 42            NaN           None         None           None      0.000000
# 43            0.0           None         None           None     -0.000588
# 44            NaN           None         None           None      0.000000
# 45            0.0           None         None           None      0.009114
# 46            0.0           None         None           None      0.003268
# 47            0.0           None         None           None     -0.180858
# 48            0.0           None         None           None     -0.236074
# 49            0.0           None         None           None     -0.181962
#
# [50 rows x 280 columns]

# %% [markdown]
# ### Pagination
# The REST API responses are _paginated_, meaning that only a subset of the full items are returned with each query. Pagination is used to limit the total number of requests made by each user to prevent any single user overloading the server with huge data requests.
#
# Pagination information is included in the response:
#
#  - `total` - this is the total number of items in the database which matched your query.
#  - `size` - the number of items returned on each page.
#  - `page` - the current page of information. Each page contains `size` number of items
#  - `pages` - the total number of pages for information in the database. This is `math.ceil(size / total)`.
#
# You can control the pagination using the following options:
#  - `page=xx` to the next page of items.
#  - `size=xx` to set the number of results returned by each page.

# %%
response = requests.get(f'{ENDPOINT_URL}/shots/?size=2&page=2')
result = response.json()

print(f"Number of items returned = {len(result['items'])}")
result
# Out:
# Number of items returned = 2
# {'items': [{'shot_id': 47204,
#    'timestamp': '2023-03-31T15:38:20',
#    'preshot_description': 'Repeat daily test shot with PS enable windows tight around the current waveforms, as a test for diagnostic noise. Enable as many diagnostics as possible.',
#    'postshot_description': 'Error in channels 11 and 12 on bolometer. Waveforms mostly OK except Px chopped early for no apparent reason (no RTP events)',
#    'campaign': 'MU3',
#    'reference_shot': None,
#    'scenario': None,
#    'heating': None,
#    'pellets': False,
#    'rmp_coil': False,
#    'current_range': None,
#    'divertor_config': None,
#    'plasma_shape': None,
#    'comissioner': 'UKAEA',
#    'facility': 'MAST',
#    'cpf_p03249': None,
#    'cpf_p04673': None,
#    'cpf_p04674': None,
#    'cpf_p04675': None,
#    'cpf_p04676': None,
#    'cpf_p04677': None,
#    'cpf_p04678': None,
#    'cpf_p04679': None,
#    'cpf_p04680': None,
#    'cpf_p04681': None,
#    'cpf_p04833': None,
#    'cpf_p04993': None,
#    'cpf_p05007': None,
#    'cpf_p05008': None,
#    'cpf_p05009': None,
#    'cpf_p05010': None,
#    'cpf_p05011': None,
#    'cpf_p05015': None,
#    'cpf_p05016': None,
#    'cpf_p05017': None,
#    'cpf_p05025': None,
#    'cpf_p05027': None,
#    'cpf_p05028': None,
#    'cpf_p05029': None,
#    'cpf_p05030': None,
#    'cpf_p05032': None,
#    'cpf_p05033': None,
#    'cpf_p05153': None,
#    'cpf_p06000': None,
#    'cpf_p06001': None,
#    'cpf_p06002': None,
#    'cpf_p06003': None,
#    'cpf_p06004': None,
#    'cpf_p10963': None,
#    'cpf_p10964': None,
#    'cpf_p12441': None,
#    'cpf_p12450': None,
#    'cpf_p12451': None,
#    'cpf_p12452': None,
#    'cpf_p15202': None,
#    'cpf_p15203': None,
#    'cpf_p15209': None,
#    'cpf_p15659': None,
#    'cpf_p15660': None,
#    'cpf_p15661': None,
#    'cpf_p20000': None,
#    'cpf_p20204': None,
#    'cpf_p20205': None,
#    'cpf_p20206': None,
#    'cpf_p20207': None,
#    'cpf_p20208': None,
#    'cpf_p21010': None,
#    'cpf_p21011': None,
#    'cpf_p21012': None,
#    'cpf_p21021': None,
#    'cpf_p21022': None,
#    'cpf_p21029': None,
#    'cpf_p21035': None,
#    'cpf_p21037': None,
#    'cpf_p21041': None,
#    'cpf_p21042': None,
#    'cpf_p21043': None,
#    'cpf_p21044': None,
#    'cpf_p21045': None,
#    'cpf_p21046': None,
#    'cpf_p21047': None,
#    'cpf_p21048': None,
#    'cpf_p21051': None,
#    'cpf_p21052': None,
#    'cpf_p21053': None,
#    'cpf_p21054': None,
#    'cpf_p21055': None,
#    'cpf_p21056': None,
#    'cpf_p21075': None,
#    'cpf_p21076': None,
#    'cpf_p21077': None,
#    'cpf_p21078': None,
#    'cpf_p21079': None,
#    'cpf_p21080': None,
#    'cpf_p21081': None,
#    'cpf_p21082': None,
#    'cpf_p21083': None,
#    'cpf_p21084': None,
#    'cpf_p21085': None,
#    'cpf_p21086': None,
#    'cpf_p21087': None,
#    'cpf_p21088': None,
#    'cpf_p21089': None,
#    'cpf_p21092': None,
#    'cpf_p21093': None,
#    'cpf_abort': None,
#    'cpf_amin_ipmax': None,
#    'cpf_amin_max': None,
#    'cpf_amin_truby': None,
#    'cpf_area_ipmax': None,
#    'cpf_area_max': None,
#    'cpf_area_truby': None,
#    'cpf_bepmhd_ipmax': None,
#    'cpf_bepmhd_max': None,
#    'cpf_bepmhd_truby': None,
#    'cpf_betmhd_ipmax': None,
#    'cpf_betmhd_max': None,
#    'cpf_betmhd_truby': None,
#    'cpf_bt_ipmax': None,
#    'cpf_bt_max': None,
#    'cpf_bt_truby': None,
#    'cpf_c2ratio': None,
#    'cpf_column_temp_in': None,
#    'cpf_column_temp_out': None,
#    'cpf_creation': None,
#    'cpf_dwmhd_ipmax': None,
#    'cpf_dwmhd_max': None,
#    'cpf_dwmhd_truby': None,
#    'cpf_enbi_max_ss': None,
#    'cpf_enbi_max_sw': None,
#    'cpf_exp_date': None,
#    'cpf_exp_number': None,
#    'cpf_exp_time': None,
#    'cpf_gdc_duration': None,
#    'cpf_gdc_time': None,
#    'cpf_ibgas_pressure': None,
#    'cpf_ip_av': None,
#    'cpf_ip_max': None,
#    'cpf_jnbi_ipmax': None,
#    'cpf_jnbi_ipmax_ss': None,
#    'cpf_jnbi_ipmax_sw': None,
#    'cpf_jnbi_max': None,
#    'cpf_jnbi_max_ss': None,
#    'cpf_jnbi_max_sw': None,
#    'cpf_jnbi_total': None,
#    'cpf_jnbi_total_ss': None,
#    'cpf_jnbi_total_sw': None,
#    'cpf_jnbi_truby': None,
#    'cpf_jnbi_truby_ss': None,
#    'cpf_jnbi_truby_sw': None,
#    'cpf_johm_ipmax': None,
#    'cpf_johm_max': None,
#    'cpf_johm_total': None,
#    'cpf_johm_truby': None,
#    'cpf_kappa_ipmax': None,
#    'cpf_kappa_max': None,
#    'cpf_kappa_truby': None,
#    'cpf_li_2_ipmax': None,
#    'cpf_li_2_max': None,
#    'cpf_li_2_truby': None,
#    'cpf_li_3_ipmax': None,
#    'cpf_li_3_max': None,
#    'cpf_li_3_truby': None,
#    'cpf_log_base_pressure': None,
#    'cpf_ndl_co2_ipmax': None,
#    'cpf_ndl_co2_max': None,
#    'cpf_ndl_co2_truby': None,
#    'cpf_ne0_ipmax': None,
#    'cpf_ne0_max': None,
#    'cpf_ne0_truby': None,
#    'cpf_ne0ratio_ipmax': None,
#    'cpf_ne0ruby': None,
#    'cpf_ne_bar_ipmax': None,
#    'cpf_ne_yag_bar_ipmax': None,
#    'cpf_ngreenwald_ipmax': None,
#    'cpf_ngreenwaldratio_ipmax': None,
#    'cpf_o2ratio': None,
#    'cpf_objective': None,
#    'cpf_pe0_ipmax': None,
#    'cpf_pe0_max': None,
#    'cpf_pe0_truby': None,
#    'cpf_pe0ruby': None,
#    'cpf_pic': None,
#    'cpf_pnbi_ipmax': None,
#    'cpf_pnbi_ipmax_ss': None,
#    'cpf_pnbi_ipmax_sw': None,
#    'cpf_pnbi_max': None,
#    'cpf_pnbi_max_ss': None,
#    'cpf_pnbi_max_sw': None,
#    'cpf_pnbi_truby': None,
#    'cpf_pnbi_truby_ss': None,
#    'cpf_pnbi_truby_sw': None,
#    'cpf_pohm_ipmax': None,
#    'cpf_pohm_max': None,
#    'cpf_pohm_truby': None,
#    'cpf_postshot': None,
#    'cpf_prad_ipmax': None,
#    'cpf_prad_max': None,
#    'cpf_prad_truby': None,
#    'cpf_pradne2': None,
#    'cpf_preshot': None,
#    'cpf_program': None,
#    'cpf_pulno': None,
#    'cpf_q95_ipmax': None,
#    'cpf_q95_min': None,
#    'cpf_q95_truby': None,
#    'cpf_reference': None,
#    'cpf_rgeo_ipmax': None,
#    'cpf_rgeo_max': None,
#    'cpf_rgeo_truby': None,
#    'cpf_rinner_da': None,
#    'cpf_rinner_efit': None,
#    'cpf_rmag_efit': None,
#    'cpf_router_da': None,
#    'cpf_router_efit': None,
#    'cpf_sarea_ipmax': None,
#    'cpf_sarea_max': None,
#    'cpf_sarea_truby': None,
#    'cpf_sl': None,
#    'cpf_summary': None,
#    'cpf_tamin_max': None,
#    'cpf_tarea_max': None,
#    'cpf_tautot_ipmax': None,
#    'cpf_tautot_max': None,
#    'cpf_tautot_truby': None,
#    'cpf_tbepmhd_max': None,
#    'cpf_tbetmhd_max': None,
#    'cpf_tbt_max': None,
#    'cpf_tdwmhd_max': None,
#    'cpf_te0_ipmax': None,
#    'cpf_te0_max': None,
#    'cpf_te0_truby': None,
#    'cpf_te0ratio_ipmax': None,
#    'cpf_te0ruby': None,
#    'cpf_te_yag_bar_ipmax': None,
#    'cpf_tend': None,
#    'cpf_tend_ibgas': None,
#    'cpf_tend_nbi': None,
#    'cpf_tend_nbi_ss': None,
#    'cpf_tend_nbi_sw': None,
#    'cpf_term_code': None,
#    'cpf_tftend': None,
#    'cpf_tftstart': None,
#    'cpf_tipmax': None,
#    'cpf_tkappa_max': None,
#    'cpf_tli_2_max': None,
#    'cpf_tli_3_max': None,
#    'cpf_tndl_co2_max': None,
#    'cpf_tne0_max': None,
#    'cpf_tpe0_max': None,
#    'cpf_tpnbi_max': None,
#    'cpf_tpnbi_max_ss': None,
#    'cpf_tpnbi_max_sw': None,
#    'cpf_tpohm_max': None,
#    'cpf_tprad_max': None,
#    'cpf_tq95_min': None,
#    'cpf_trgeo_max': None,
#    'cpf_truby': None,
#    'cpf_tsarea_max': None,
#    'cpf_tstart': None,
#    'cpf_tstart_ibgas': None,
#    'cpf_tstart_nbi': None,
#    'cpf_tstart_nbi_ss': None,
#    'cpf_tstart_nbi_sw': None,
#    'cpf_ttautot_max': None,
#    'cpf_tte0_max': None,
#    'cpf_tvol_max': None,
#    'cpf_twmhd_max': None,
#    'cpf_tzeff_max': None,
#    'cpf_useful': None,
#    'cpf_vol_ipmax': None,
#    'cpf_vol_max': None,
#    'cpf_vol_truby': None,
#    'cpf_wmhd_ipmax': None,
#    'cpf_wmhd_max': None,
#    'cpf_wmhd_truby': None,
#    'cpf_zeff_ipmax': None,
#    'cpf_zeff_max': None,
#    'cpf_zeff_truby': None,
#    'cpf_zmag_efit': None},
#   {'shot_id': 47203,
#    'timestamp': '2023-03-31T15:19:43',
#    'preshot_description': 'Restore prepared setup all-coil-first-shot. Extend PCS acquisition time to -2.1 to +5.1 to inhibit warnings.',
#    'postshot_description': "Looks OK, I don't have a code to test the magnetics data.",
#    'campaign': 'MU3',
#    'reference_shot': None,
#    'scenario': None,
#    'heating': None,
#    'pellets': False,
#    'rmp_coil': False,
#    'current_range': None,
#    'divertor_config': None,
#    'plasma_shape': None,
#    'comissioner': 'UKAEA',
#    'facility': 'MAST',
#    'cpf_p03249': None,
#    'cpf_p04673': None,
#    'cpf_p04674': None,
#    'cpf_p04675': None,
#    'cpf_p04676': None,
#    'cpf_p04677': None,
#    'cpf_p04678': None,
#    'cpf_p04679': None,
#    'cpf_p04680': None,
#    'cpf_p04681': None,
#    'cpf_p04833': None,
#    'cpf_p04993': None,
#    'cpf_p05007': None,
#    'cpf_p05008': None,
#    'cpf_p05009': None,
#    'cpf_p05010': None,
#    'cpf_p05011': None,
#    'cpf_p05015': None,
#    'cpf_p05016': None,
#    'cpf_p05017': None,
#    'cpf_p05025': None,
#    'cpf_p05027': None,
#    'cpf_p05028': None,
#    'cpf_p05029': None,
#    'cpf_p05030': None,
#    'cpf_p05032': None,
#    'cpf_p05033': None,
#    'cpf_p05153': None,
#    'cpf_p06000': None,
#    'cpf_p06001': None,
#    'cpf_p06002': None,
#    'cpf_p06003': None,
#    'cpf_p06004': None,
#    'cpf_p10963': None,
#    'cpf_p10964': None,
#    'cpf_p12441': None,
#    'cpf_p12450': None,
#    'cpf_p12451': None,
#    'cpf_p12452': None,
#    'cpf_p15202': None,
#    'cpf_p15203': None,
#    'cpf_p15209': None,
#    'cpf_p15659': None,
#    'cpf_p15660': None,
#    'cpf_p15661': None,
#    'cpf_p20000': None,
#    'cpf_p20204': None,
#    'cpf_p20205': None,
#    'cpf_p20206': None,
#    'cpf_p20207': None,
#    'cpf_p20208': None,
#    'cpf_p21010': None,
#    'cpf_p21011': None,
#    'cpf_p21012': None,
#    'cpf_p21021': None,
#    'cpf_p21022': None,
#    'cpf_p21029': None,
#    'cpf_p21035': None,
#    'cpf_p21037': None,
#    'cpf_p21041': None,
#    'cpf_p21042': None,
#    'cpf_p21043': None,
#    'cpf_p21044': None,
#    'cpf_p21045': None,
#    'cpf_p21046': None,
#    'cpf_p21047': None,
#    'cpf_p21048': None,
#    'cpf_p21051': None,
#    'cpf_p21052': None,
#    'cpf_p21053': None,
#    'cpf_p21054': None,
#    'cpf_p21055': None,
#    'cpf_p21056': None,
#    'cpf_p21075': None,
#    'cpf_p21076': None,
#    'cpf_p21077': None,
#    'cpf_p21078': None,
#    'cpf_p21079': None,
#    'cpf_p21080': None,
#    'cpf_p21081': None,
#    'cpf_p21082': None,
#    'cpf_p21083': None,
#    'cpf_p21084': None,
#    'cpf_p21085': None,
#    'cpf_p21086': None,
#    'cpf_p21087': None,
#    'cpf_p21088': None,
#    'cpf_p21089': None,
#    'cpf_p21092': None,
#    'cpf_p21093': None,
#    'cpf_abort': None,
#    'cpf_amin_ipmax': None,
#    'cpf_amin_max': None,
#    'cpf_amin_truby': None,
#    'cpf_area_ipmax': None,
#    'cpf_area_max': None,
#    'cpf_area_truby': None,
#    'cpf_bepmhd_ipmax': None,
#    'cpf_bepmhd_max': None,
#    'cpf_bepmhd_truby': None,
#    'cpf_betmhd_ipmax': None,
#    'cpf_betmhd_max': None,
#    'cpf_betmhd_truby': None,
#    'cpf_bt_ipmax': None,
#    'cpf_bt_max': None,
#    'cpf_bt_truby': None,
#    'cpf_c2ratio': None,
#    'cpf_column_temp_in': None,
#    'cpf_column_temp_out': None,
#    'cpf_creation': None,
#    'cpf_dwmhd_ipmax': None,
#    'cpf_dwmhd_max': None,
#    'cpf_dwmhd_truby': None,
#    'cpf_enbi_max_ss': None,
#    'cpf_enbi_max_sw': None,
#    'cpf_exp_date': None,
#    'cpf_exp_number': None,
#    'cpf_exp_time': None,
#    'cpf_gdc_duration': None,
#    'cpf_gdc_time': None,
#    'cpf_ibgas_pressure': None,
#    'cpf_ip_av': None,
#    'cpf_ip_max': None,
#    'cpf_jnbi_ipmax': None,
#    'cpf_jnbi_ipmax_ss': None,
#    'cpf_jnbi_ipmax_sw': None,
#    'cpf_jnbi_max': None,
#    'cpf_jnbi_max_ss': None,
#    'cpf_jnbi_max_sw': None,
#    'cpf_jnbi_total': None,
#    'cpf_jnbi_total_ss': None,
#    'cpf_jnbi_total_sw': None,
#    'cpf_jnbi_truby': None,
#    'cpf_jnbi_truby_ss': None,
#    'cpf_jnbi_truby_sw': None,
#    'cpf_johm_ipmax': None,
#    'cpf_johm_max': None,
#    'cpf_johm_total': None,
#    'cpf_johm_truby': None,
#    'cpf_kappa_ipmax': None,
#    'cpf_kappa_max': None,
#    'cpf_kappa_truby': None,
#    'cpf_li_2_ipmax': None,
#    'cpf_li_2_max': None,
#    'cpf_li_2_truby': None,
#    'cpf_li_3_ipmax': None,
#    'cpf_li_3_max': None,
#    'cpf_li_3_truby': None,
#    'cpf_log_base_pressure': None,
#    'cpf_ndl_co2_ipmax': None,
#    'cpf_ndl_co2_max': None,
#    'cpf_ndl_co2_truby': None,
#    'cpf_ne0_ipmax': None,
#    'cpf_ne0_max': None,
#    'cpf_ne0_truby': None,
#    'cpf_ne0ratio_ipmax': None,
#    'cpf_ne0ruby': None,
#    'cpf_ne_bar_ipmax': None,
#    'cpf_ne_yag_bar_ipmax': None,
#    'cpf_ngreenwald_ipmax': None,
#    'cpf_ngreenwaldratio_ipmax': None,
#    'cpf_o2ratio': None,
#    'cpf_objective': None,
#    'cpf_pe0_ipmax': None,
#    'cpf_pe0_max': None,
#    'cpf_pe0_truby': None,
#    'cpf_pe0ruby': None,
#    'cpf_pic': None,
#    'cpf_pnbi_ipmax': None,
#    'cpf_pnbi_ipmax_ss': None,
#    'cpf_pnbi_ipmax_sw': None,
#    'cpf_pnbi_max': None,
#    'cpf_pnbi_max_ss': None,
#    'cpf_pnbi_max_sw': None,
#    'cpf_pnbi_truby': None,
#    'cpf_pnbi_truby_ss': None,
#    'cpf_pnbi_truby_sw': None,
#    'cpf_pohm_ipmax': None,
#    'cpf_pohm_max': None,
#    'cpf_pohm_truby': None,
#    'cpf_postshot': None,
#    'cpf_prad_ipmax': None,
#    'cpf_prad_max': None,
#    'cpf_prad_truby': None,
#    'cpf_pradne2': None,
#    'cpf_preshot': None,
#    'cpf_program': None,
#    'cpf_pulno': None,
#    'cpf_q95_ipmax': None,
#    'cpf_q95_min': None,
#    'cpf_q95_truby': None,
#    'cpf_reference': None,
#    'cpf_rgeo_ipmax': None,
#    'cpf_rgeo_max': None,
#    'cpf_rgeo_truby': None,
#    'cpf_rinner_da': None,
#    'cpf_rinner_efit': None,
#    'cpf_rmag_efit': None,
#    'cpf_router_da': None,
#    'cpf_router_efit': None,
#    'cpf_sarea_ipmax': None,
#    'cpf_sarea_max': None,
#    'cpf_sarea_truby': None,
#    'cpf_sl': None,
#    'cpf_summary': None,
#    'cpf_tamin_max': None,
#    'cpf_tarea_max': None,
#    'cpf_tautot_ipmax': None,
#    'cpf_tautot_max': None,
#    'cpf_tautot_truby': None,
#    'cpf_tbepmhd_max': None,
#    'cpf_tbetmhd_max': None,
#    'cpf_tbt_max': None,
#    'cpf_tdwmhd_max': None,
#    'cpf_te0_ipmax': None,
#    'cpf_te0_max': None,
#    'cpf_te0_truby': None,
#    'cpf_te0ratio_ipmax': None,
#    'cpf_te0ruby': None,
#    'cpf_te_yag_bar_ipmax': None,
#    'cpf_tend': None,
#    'cpf_tend_ibgas': None,
#    'cpf_tend_nbi': None,
#    'cpf_tend_nbi_ss': None,
#    'cpf_tend_nbi_sw': None,
#    'cpf_term_code': None,
#    'cpf_tftend': None,
#    'cpf_tftstart': None,
#    'cpf_tipmax': None,
#    'cpf_tkappa_max': None,
#    'cpf_tli_2_max': None,
#    'cpf_tli_3_max': None,
#    'cpf_tndl_co2_max': None,
#    'cpf_tne0_max': None,
#    'cpf_tpe0_max': None,
#    'cpf_tpnbi_max': None,
#    'cpf_tpnbi_max_ss': None,
#    'cpf_tpnbi_max_sw': None,
#    'cpf_tpohm_max': None,
#    'cpf_tprad_max': None,
#    'cpf_tq95_min': None,
#    'cpf_trgeo_max': None,
#    'cpf_truby': None,
#    'cpf_tsarea_max': None,
#    'cpf_tstart': None,
#    'cpf_tstart_ibgas': None,
#    'cpf_tstart_nbi': None,
#    'cpf_tstart_nbi_ss': None,
#    'cpf_tstart_nbi_sw': None,
#    'cpf_ttautot_max': None,
#    'cpf_tte0_max': None,
#    'cpf_tvol_max': None,
#    'cpf_twmhd_max': None,
#    'cpf_tzeff_max': None,
#    'cpf_useful': None,
#    'cpf_vol_ipmax': None,
#    'cpf_vol_max': None,
#    'cpf_vol_truby': None,
#    'cpf_wmhd_ipmax': None,
#    'cpf_wmhd_max': None,
#    'cpf_wmhd_truby': None,
#    'cpf_zeff_ipmax': None,
#    'cpf_zeff_max': None,
#    'cpf_zeff_truby': None,
#    'cpf_zmag_efit': None}],
#  'total': 25556,
#  'page': 2,
#  'size': 2,
#  'pages': 12778,
#  'column_metadata': {'shot_id': 'int',
#   'timestamp': 'object',
#   'preshot_description': 'str',
#   'postshot_description': 'str',
#   'campaign': 'str',
#   'reference_shot': 'object',
#   'scenario': 'object',
#   'heating': 'object',
#   'pellets': 'object',
#   'rmp_coil': 'object',
#   'current_range': 'object',
#   'divertor_config': 'object',
#   'plasma_shape': 'object',
#   'comissioner': 'object',
#   'facility': 'object',
#   'cpf_p03249': 'object',
#   'cpf_p04673': 'object',
#   'cpf_p04674': 'object',
#   'cpf_p04675': 'object',
#   'cpf_p04676': 'object',
#   'cpf_p04677': 'object',
#   'cpf_p04678': 'object',
#   'cpf_p04679': 'object',
#   'cpf_p04680': 'object',
#   'cpf_p04681': 'object',
#   'cpf_p04833': 'object',
#   'cpf_p04993': 'object',
#   'cpf_p05007': 'object',
#   'cpf_p05008': 'object',
#   'cpf_p05009': 'object',
#   'cpf_p05010': 'object',
#   'cpf_p05011': 'object',
#   'cpf_p05015': 'object',
#   'cpf_p05016': 'object',
#   'cpf_p05017': 'object',
#   'cpf_p05025': 'object',
#   'cpf_p05027': 'object',
#   'cpf_p05028': 'object',
#   'cpf_p05029': 'object',
#   'cpf_p05030': 'object',
#   'cpf_p05032': 'object',
#   'cpf_p05033': 'object',
#   'cpf_p05153': 'object',
#   'cpf_p06000': 'object',
#   'cpf_p06001': 'object',
#   'cpf_p06002': 'object',
#   'cpf_p06003': 'object',
#   'cpf_p06004': 'object',
#   'cpf_p10963': 'object',
#   'cpf_p10964': 'object',
#   'cpf_p12441': 'object',
#   'cpf_p12450': 'object',
#   'cpf_p12451': 'object',
#   'cpf_p12452': 'object',
#   'cpf_p15202': 'object',
#   'cpf_p15203': 'object',
#   'cpf_p15209': 'object',
#   'cpf_p15659': 'object',
#   'cpf_p15660': 'object',
#   'cpf_p15661': 'object',
#   'cpf_p20000': 'object',
#   'cpf_p20204': 'object',
#   'cpf_p20205': 'object',
#   'cpf_p20206': 'object',
#   'cpf_p20207': 'object',
#   'cpf_p20208': 'object',
#   'cpf_p21010': 'object',
#   'cpf_p21011': 'object',
#   'cpf_p21012': 'object',
#   'cpf_p21021': 'object',
#   'cpf_p21022': 'object',
#   'cpf_p21029': 'object',
#   'cpf_p21035': 'object',
#   'cpf_p21037': 'object',
#   'cpf_p21041': 'object',
#   'cpf_p21042': 'object',
#   'cpf_p21043': 'object',
#   'cpf_p21044': 'object',
#   'cpf_p21045': 'object',
#   'cpf_p21046': 'object',
#   'cpf_p21047': 'object',
#   'cpf_p21048': 'object',
#   'cpf_p21051': 'object',
#   'cpf_p21052': 'object',
#   'cpf_p21053': 'object',
#   'cpf_p21054': 'object',
#   'cpf_p21055': 'object',
#   'cpf_p21056': 'object',
#   'cpf_p21075': 'object',
#   'cpf_p21076': 'object',
#   'cpf_p21077': 'object',
#   'cpf_p21078': 'object',
#   'cpf_p21079': 'object',
#   'cpf_p21080': 'object',
#   'cpf_p21081': 'object',
#   'cpf_p21082': 'object',
#   'cpf_p21083': 'object',
#   'cpf_p21084': 'object',
#   'cpf_p21085': 'object',
#   'cpf_p21086': 'object',
#   'cpf_p21087': 'object',
#   'cpf_p21088': 'object',
#   'cpf_p21089': 'object',
#   'cpf_p21092': 'object',
#   'cpf_p21093': 'object',
#   'cpf_abort': 'object',
#   'cpf_amin_ipmax': 'object',
#   'cpf_amin_max': 'object',
#   'cpf_amin_truby': 'object',
#   'cpf_area_ipmax': 'object',
#   'cpf_area_max': 'object',
#   'cpf_area_truby': 'object',
#   'cpf_bepmhd_ipmax': 'object',
#   'cpf_bepmhd_max': 'object',
#   'cpf_bepmhd_truby': 'object',
#   'cpf_betmhd_ipmax': 'object',
#   'cpf_betmhd_max': 'object',
#   'cpf_betmhd_truby': 'object',
#   'cpf_bt_ipmax': 'object',
#   'cpf_bt_max': 'object',
#   'cpf_bt_truby': 'object',
#   'cpf_c2ratio': 'object',
#   'cpf_column_temp_in': 'object',
#   'cpf_column_temp_out': 'object',
#   'cpf_creation': 'object',
#   'cpf_dwmhd_ipmax': 'object',
#   'cpf_dwmhd_max': 'object',
#   'cpf_dwmhd_truby': 'object',
#   'cpf_enbi_max_ss': 'object',
#   'cpf_enbi_max_sw': 'object',
#   'cpf_exp_date': 'object',
#   'cpf_exp_number': 'object',
#   'cpf_exp_time': 'object',
#   'cpf_gdc_duration': 'object',
#   'cpf_gdc_time': 'object',
#   'cpf_ibgas_pressure': 'object',
#   'cpf_ip_av': 'object',
#   'cpf_ip_max': 'object',
#   'cpf_jnbi_ipmax': 'object',
#   'cpf_jnbi_ipmax_ss': 'object',
#   'cpf_jnbi_ipmax_sw': 'object',
#   'cpf_jnbi_max': 'object',
#   'cpf_jnbi_max_ss': 'object',
#   'cpf_jnbi_max_sw': 'object',
#   'cpf_jnbi_total': 'object',
#   'cpf_jnbi_total_ss': 'object',
#   'cpf_jnbi_total_sw': 'object',
#   'cpf_jnbi_truby': 'object',
#   'cpf_jnbi_truby_ss': 'object',
#   'cpf_jnbi_truby_sw': 'object',
#   'cpf_johm_ipmax': 'object',
#   'cpf_johm_max': 'object',
#   'cpf_johm_total': 'object',
#   'cpf_johm_truby': 'object',
#   'cpf_kappa_ipmax': 'object',
#   'cpf_kappa_max': 'object',
#   'cpf_kappa_truby': 'object',
#   'cpf_li_2_ipmax': 'object',
#   'cpf_li_2_max': 'object',
#   'cpf_li_2_truby': 'object',
#   'cpf_li_3_ipmax': 'object',
#   'cpf_li_3_max': 'object',
#   'cpf_li_3_truby': 'object',
#   'cpf_log_base_pressure': 'object',
#   'cpf_ndl_co2_ipmax': 'object',
#   'cpf_ndl_co2_max': 'object',
#   'cpf_ndl_co2_truby': 'object',
#   'cpf_ne0_ipmax': 'object',
#   'cpf_ne0_max': 'object',
#   'cpf_ne0_truby': 'object',
#   'cpf_ne0ratio_ipmax': 'object',
#   'cpf_ne0ruby': 'object',
#   'cpf_ne_bar_ipmax': 'object',
#   'cpf_ne_yag_bar_ipmax': 'object',
#   'cpf_ngreenwald_ipmax': 'object',
#   'cpf_ngreenwaldratio_ipmax': 'object',
#   'cpf_o2ratio': 'object',
#   'cpf_objective': 'object',
#   'cpf_pe0_ipmax': 'object',
#   'cpf_pe0_max': 'object',
#   'cpf_pe0_truby': 'object',
#   'cpf_pe0ruby': 'object',
#   'cpf_pic': 'object',
#   'cpf_pnbi_ipmax': 'object',
#   'cpf_pnbi_ipmax_ss': 'object',
#   'cpf_pnbi_ipmax_sw': 'object',
#   'cpf_pnbi_max': 'object',
#   'cpf_pnbi_max_ss': 'object',
#   'cpf_pnbi_max_sw': 'object',
#   'cpf_pnbi_truby': 'object',
#   'cpf_pnbi_truby_ss': 'object',
#   'cpf_pnbi_truby_sw': 'object',
#   'cpf_pohm_ipmax': 'object',
#   'cpf_pohm_max': 'object',
#   'cpf_pohm_truby': 'object',
#   'cpf_postshot': 'object',
#   'cpf_prad_ipmax': 'object',
#   'cpf_prad_max': 'object',
#   'cpf_prad_truby': 'object',
#   'cpf_pradne2': 'object',
#   'cpf_preshot': 'object',
#   'cpf_program': 'object',
#   'cpf_pulno': 'object',
#   'cpf_q95_ipmax': 'object',
#   'cpf_q95_min': 'object',
#   'cpf_q95_truby': 'object',
#   'cpf_reference': 'object',
#   'cpf_rgeo_ipmax': 'object',
#   'cpf_rgeo_max': 'object',
#   'cpf_rgeo_truby': 'object',
#   'cpf_rinner_da': 'object',
#   'cpf_rinner_efit': 'object',
#   'cpf_rmag_efit': 'object',
#   'cpf_router_da': 'object',
#   'cpf_router_efit': 'object',
#   'cpf_sarea_ipmax': 'object',
#   'cpf_sarea_max': 'object',
#   'cpf_sarea_truby': 'object',
#   'cpf_sl': 'object',
#   'cpf_summary': 'object',
#   'cpf_tamin_max': 'object',
#   'cpf_tarea_max': 'object',
#   'cpf_tautot_ipmax': 'object',
#   'cpf_tautot_max': 'object',
#   'cpf_tautot_truby': 'object',
#   'cpf_tbepmhd_max': 'object',
#   'cpf_tbetmhd_max': 'object',
#   'cpf_tbt_max': 'object',
#   'cpf_tdwmhd_max': 'object',
#   'cpf_te0_ipmax': 'object',
#   'cpf_te0_max': 'object',
#   'cpf_te0_truby': 'object',
#   'cpf_te0ratio_ipmax': 'object',
#   'cpf_te0ruby': 'object',
#   'cpf_te_yag_bar_ipmax': 'object',
#   'cpf_tend': 'object',
#   'cpf_tend_ibgas': 'object',
#   'cpf_tend_nbi': 'object',
#   'cpf_tend_nbi_ss': 'object',
#   'cpf_tend_nbi_sw': 'object',
#   'cpf_term_code': 'object',
#   'cpf_tftend': 'object',
#   'cpf_tftstart': 'object',
#   'cpf_tipmax': 'object',
#   'cpf_tkappa_max': 'object',
#   'cpf_tli_2_max': 'object',
#   'cpf_tli_3_max': 'object',
#   'cpf_tndl_co2_max': 'object',
#   'cpf_tne0_max': 'object',
#   'cpf_tpe0_max': 'object',
#   'cpf_tpnbi_max': 'object',
#   'cpf_tpnbi_max_ss': 'object',
#   'cpf_tpnbi_max_sw': 'object',
#   'cpf_tpohm_max': 'object',
#   'cpf_tprad_max': 'object',
#   'cpf_tq95_min': 'object',
#   'cpf_trgeo_max': 'object',
#   'cpf_truby': 'object',
#   'cpf_tsarea_max': 'object',
#   'cpf_tstart': 'object',
#   'cpf_tstart_ibgas': 'object',
#   'cpf_tstart_nbi': 'object',
#   'cpf_tstart_nbi_ss': 'object',
#   'cpf_tstart_nbi_sw': 'object',
#   'cpf_ttautot_max': 'object',
#   'cpf_tte0_max': 'object',
#   'cpf_tvol_max': 'object',
#   'cpf_twmhd_max': 'object',
#   'cpf_tzeff_max': 'object',
#   'cpf_useful': 'object',
#   'cpf_vol_ipmax': 'object',
#   'cpf_vol_max': 'object',
#   'cpf_vol_truby': 'object',
#   'cpf_wmhd_ipmax': 'object',
#   'cpf_wmhd_max': 'object',
#   'cpf_wmhd_truby': 'object',
#   'cpf_zeff_ipmax': 'object',
#   'cpf_zeff_max': 'object',
#   'cpf_zeff_truby': 'object',
#   'cpf_zmag_efit': 'object'}}

# %% [markdown]
# ### Loading Paginated Responses with Dask
#
# Some times we want to load all of the results from all pages of of a query. The next code snippet shows how to lazily build a query for each page of information and return a `dask` dataframe which will hold all of the results.

# %%
response = requests.get(f'{ENDPOINT_URL}/shots/')
num_pages = response.json()['pages']

@dask.delayed
def load_one_page(i): 
    """Load one page of requests from the REST API"""
    response = requests.get(f'{ENDPOINT_URL}/shots/?page={i}')
    response = response.json()
    # Important! need to include column_metadata here to get the correct data types for each column
    return (
        pd.DataFrame
            .from_dict(response['items'])
            .astype(response['column_metadata'])
    )

df = dd.from_delayed([load_one_page(i) for i in range(1, 5)])
df
# Out:
# Dask DataFrame Structure:
#               shot_id timestamp preshot_description postshot_description campaign reference_shot scenario heating pellets rmp_coil current_range divertor_config plasma_shape comissioner facility cpf_p03249 cpf_p04673 cpf_p04674 cpf_p04675 cpf_p04676 cpf_p04677 cpf_p04678 cpf_p04679 cpf_p04680 cpf_p04681 cpf_p04833 cpf_p04993 cpf_p05007 cpf_p05008 cpf_p05009 cpf_p05010 cpf_p05011 cpf_p05015 cpf_p05016 cpf_p05017 cpf_p05025 cpf_p05027 cpf_p05028 cpf_p05029 cpf_p05030 cpf_p05032 cpf_p05033 cpf_p05153 cpf_p06000 cpf_p06001 cpf_p06002 cpf_p06003 cpf_p06004 cpf_p10963 cpf_p10964 cpf_p12441 cpf_p12450 cpf_p12451 cpf_p12452 cpf_p15202 cpf_p15203 cpf_p15209 cpf_p15659 cpf_p15660 cpf_p15661 cpf_p20000 cpf_p20204 cpf_p20205 cpf_p20206 cpf_p20207 cpf_p20208 cpf_p21010 cpf_p21011 cpf_p21012 cpf_p21021 cpf_p21022 cpf_p21029 cpf_p21035 cpf_p21037 cpf_p21041 cpf_p21042 cpf_p21043 cpf_p21044 cpf_p21045 cpf_p21046 cpf_p21047 cpf_p21048 cpf_p21051 cpf_p21052 cpf_p21053 cpf_p21054 cpf_p21055 cpf_p21056 cpf_p21075 cpf_p21076 cpf_p21077 cpf_p21078 cpf_p21079 cpf_p21080 cpf_p21081 cpf_p21082 cpf_p21083 cpf_p21084 cpf_p21085 cpf_p21086 cpf_p21087 cpf_p21088 cpf_p21089 cpf_p21092 cpf_p21093 cpf_abort cpf_amin_ipmax cpf_amin_max cpf_amin_truby cpf_area_ipmax cpf_area_max cpf_area_truby cpf_bepmhd_ipmax cpf_bepmhd_max cpf_bepmhd_truby cpf_betmhd_ipmax cpf_betmhd_max cpf_betmhd_truby cpf_bt_ipmax cpf_bt_max cpf_bt_truby cpf_c2ratio cpf_column_temp_in cpf_column_temp_out cpf_creation cpf_dwmhd_ipmax cpf_dwmhd_max cpf_dwmhd_truby cpf_enbi_max_ss cpf_enbi_max_sw cpf_exp_date cpf_exp_number cpf_exp_time cpf_gdc_duration cpf_gdc_time cpf_ibgas_pressure cpf_ip_av cpf_ip_max cpf_jnbi_ipmax cpf_jnbi_ipmax_ss cpf_jnbi_ipmax_sw cpf_jnbi_max cpf_jnbi_max_ss cpf_jnbi_max_sw cpf_jnbi_total cpf_jnbi_total_ss cpf_jnbi_total_sw cpf_jnbi_truby cpf_jnbi_truby_ss cpf_jnbi_truby_sw cpf_johm_ipmax cpf_johm_max cpf_johm_total cpf_johm_truby cpf_kappa_ipmax cpf_kappa_max cpf_kappa_truby cpf_li_2_ipmax cpf_li_2_max cpf_li_2_truby cpf_li_3_ipmax cpf_li_3_max cpf_li_3_truby cpf_log_base_pressure cpf_ndl_co2_ipmax cpf_ndl_co2_max cpf_ndl_co2_truby cpf_ne0_ipmax cpf_ne0_max cpf_ne0_truby cpf_ne0ratio_ipmax cpf_ne0ruby cpf_ne_bar_ipmax cpf_ne_yag_bar_ipmax cpf_ngreenwald_ipmax cpf_ngreenwaldratio_ipmax cpf_o2ratio cpf_objective cpf_pe0_ipmax cpf_pe0_max cpf_pe0_truby cpf_pe0ruby cpf_pic cpf_pnbi_ipmax cpf_pnbi_ipmax_ss cpf_pnbi_ipmax_sw cpf_pnbi_max cpf_pnbi_max_ss cpf_pnbi_max_sw cpf_pnbi_truby cpf_pnbi_truby_ss cpf_pnbi_truby_sw cpf_pohm_ipmax cpf_pohm_max cpf_pohm_truby cpf_postshot cpf_prad_ipmax cpf_prad_max cpf_prad_truby cpf_pradne2 cpf_preshot cpf_program cpf_pulno cpf_q95_ipmax cpf_q95_min cpf_q95_truby cpf_reference cpf_rgeo_ipmax cpf_rgeo_max cpf_rgeo_truby cpf_rinner_da cpf_rinner_efit cpf_rmag_efit cpf_router_da cpf_router_efit cpf_sarea_ipmax cpf_sarea_max cpf_sarea_truby  cpf_sl cpf_summary cpf_tamin_max cpf_tarea_max cpf_tautot_ipmax cpf_tautot_max cpf_tautot_truby cpf_tbepmhd_max cpf_tbetmhd_max cpf_tbt_max cpf_tdwmhd_max cpf_te0_ipmax cpf_te0_max cpf_te0_truby cpf_te0ratio_ipmax cpf_te0ruby cpf_te_yag_bar_ipmax cpf_tend cpf_tend_ibgas cpf_tend_nbi cpf_tend_nbi_ss cpf_tend_nbi_sw cpf_term_code cpf_tftend cpf_tftstart cpf_tipmax cpf_tkappa_max cpf_tli_2_max cpf_tli_3_max cpf_tndl_co2_max cpf_tne0_max cpf_tpe0_max cpf_tpnbi_max cpf_tpnbi_max_ss cpf_tpnbi_max_sw cpf_tpohm_max cpf_tprad_max cpf_tq95_min cpf_trgeo_max cpf_truby cpf_tsarea_max cpf_tstart cpf_tstart_ibgas cpf_tstart_nbi cpf_tstart_nbi_ss cpf_tstart_nbi_sw cpf_ttautot_max cpf_tte0_max cpf_tvol_max cpf_twmhd_max cpf_tzeff_max cpf_useful cpf_vol_ipmax cpf_vol_max cpf_vol_truby cpf_wmhd_ipmax cpf_wmhd_max cpf_wmhd_truby cpf_zeff_ipmax cpf_zeff_max cpf_zeff_truby cpf_zmag_efit
# npartitions=4
#                 int64    string              string               string   string         string   string  string  string   string        string          string       string      string   string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string     string    string         string       string         string         string       string         string           string         string           string           string         string           string       string     string       string      string             string              string       string          string        string          string          string          string       string         string       string           string       string             string    string     string         string            string            string       string          string          string         string            string            string         string            string            string         string       string         string         string          string        string          string         string       string         string         string       string         string                string            string          string            string        string      string        string             string      string           string               string               string                    string      string        string        string      string        string      string  string         string            string            string       string          string          string         string            string            string         string       string         string       string         string       string         string      string      string      string    string        string      string        string        string         string       string         string        string          string        string        string          string          string        string          string  string      string        string        string           string         string           string          string          string      string         string        string      string        string             string      string               string   string         string       string          string          string        string     string       string     string         string        string        string           string       string       string        string           string           string        string        string       string        string    string         string     string           string         string            string            string          string       string       string        string        string     string        string      string        string         string       string         string         string       string         string        string
#                   ...       ...                 ...                  ...      ...            ...      ...     ...     ...      ...           ...             ...          ...         ...      ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...       ...            ...          ...            ...            ...          ...            ...              ...            ...              ...              ...            ...              ...          ...        ...          ...         ...                ...                 ...          ...             ...           ...             ...             ...             ...          ...            ...          ...              ...          ...                ...       ...        ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...               ...               ...            ...          ...            ...            ...             ...           ...             ...            ...          ...            ...            ...          ...            ...                   ...               ...             ...               ...           ...         ...           ...                ...         ...              ...                  ...                  ...                       ...         ...           ...           ...         ...           ...         ...     ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...          ...            ...          ...            ...          ...            ...         ...         ...         ...       ...           ...         ...           ...           ...            ...          ...            ...           ...             ...           ...           ...             ...             ...           ...             ...     ...         ...           ...           ...              ...            ...              ...             ...             ...         ...            ...           ...         ...           ...                ...         ...                  ...      ...            ...          ...             ...             ...           ...        ...          ...        ...            ...           ...           ...              ...          ...          ...           ...              ...              ...           ...           ...          ...           ...       ...            ...        ...              ...            ...               ...               ...             ...          ...          ...           ...           ...        ...           ...         ...           ...            ...          ...            ...            ...          ...            ...           ...
#                   ...       ...                 ...                  ...      ...            ...      ...     ...     ...      ...           ...             ...          ...         ...      ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...       ...            ...          ...            ...            ...          ...            ...              ...            ...              ...              ...            ...              ...          ...        ...          ...         ...                ...                 ...          ...             ...           ...             ...             ...             ...          ...            ...          ...              ...          ...                ...       ...        ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...               ...               ...            ...          ...            ...            ...             ...           ...             ...            ...          ...            ...            ...          ...            ...                   ...               ...             ...               ...           ...         ...           ...                ...         ...              ...                  ...                  ...                       ...         ...           ...           ...         ...           ...         ...     ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...          ...            ...          ...            ...          ...            ...         ...         ...         ...       ...           ...         ...           ...           ...            ...          ...            ...           ...             ...           ...           ...             ...             ...           ...             ...     ...         ...           ...           ...              ...            ...              ...             ...             ...         ...            ...           ...         ...           ...                ...         ...                  ...      ...            ...          ...             ...             ...           ...        ...          ...        ...            ...           ...           ...              ...          ...          ...           ...              ...              ...           ...           ...          ...           ...       ...            ...        ...              ...            ...               ...               ...             ...          ...          ...           ...           ...        ...           ...         ...           ...            ...          ...            ...            ...          ...            ...           ...
#                   ...       ...                 ...                  ...      ...            ...      ...     ...     ...      ...           ...             ...          ...         ...      ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...       ...            ...          ...            ...            ...          ...            ...              ...            ...              ...              ...            ...              ...          ...        ...          ...         ...                ...                 ...          ...             ...           ...             ...             ...             ...          ...            ...          ...              ...          ...                ...       ...        ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...               ...               ...            ...          ...            ...            ...             ...           ...             ...            ...          ...            ...            ...          ...            ...                   ...               ...             ...               ...           ...         ...           ...                ...         ...              ...                  ...                  ...                       ...         ...           ...           ...         ...           ...         ...     ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...          ...            ...          ...            ...          ...            ...         ...         ...         ...       ...           ...         ...           ...           ...            ...          ...            ...           ...             ...           ...           ...             ...             ...           ...             ...     ...         ...           ...           ...              ...            ...              ...             ...             ...         ...            ...           ...         ...           ...                ...         ...                  ...      ...            ...          ...             ...             ...           ...        ...          ...        ...            ...           ...           ...              ...          ...          ...           ...              ...              ...           ...           ...          ...           ...       ...            ...        ...              ...            ...               ...               ...             ...          ...          ...           ...           ...        ...           ...         ...           ...            ...          ...            ...            ...          ...            ...           ...
#                   ...       ...                 ...                  ...      ...            ...      ...     ...     ...      ...           ...             ...          ...         ...      ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...        ...       ...            ...          ...            ...            ...          ...            ...              ...            ...              ...              ...            ...              ...          ...        ...          ...         ...                ...                 ...          ...             ...           ...             ...             ...             ...          ...            ...          ...              ...          ...                ...       ...        ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...               ...               ...            ...          ...            ...            ...             ...           ...             ...            ...          ...            ...            ...          ...            ...                   ...               ...             ...               ...           ...         ...           ...                ...         ...              ...                  ...                  ...                       ...         ...           ...           ...         ...           ...         ...     ...            ...               ...               ...          ...             ...             ...            ...               ...               ...            ...          ...            ...          ...            ...          ...            ...         ...         ...         ...       ...           ...         ...           ...           ...            ...          ...            ...           ...             ...           ...           ...             ...             ...           ...             ...     ...         ...           ...           ...              ...            ...              ...             ...             ...         ...            ...           ...         ...           ...                ...         ...                  ...      ...            ...          ...             ...             ...           ...        ...          ...        ...            ...           ...           ...              ...          ...          ...           ...              ...              ...           ...           ...          ...           ...       ...            ...        ...              ...            ...               ...               ...             ...          ...          ...           ...           ...        ...           ...         ...           ...            ...          ...            ...            ...          ...            ...           ...
# Dask Name: to_pyarrow_string, 6 graph layers

# %% [markdown]
# When we are ready, we can compute the all queries and return the resulting dataframe with all the meta data gathered from the database.

# %%
df.compute()
# Out:
#     shot_id            timestamp  \
# 0     47206  2023-03-31T16:04:44
# 1     47205  2023-03-31T15:52:21
# 2     47204  2023-03-31T15:38:20
# 3     47203  2023-03-31T15:19:43
# 4     47202  2023-03-31T14:59:33
# ..      ...                  ...
# 45    47011  2023-01-21T09:54:47
# 46    47010  2023-01-21T09:31:38
# 47    47009  2023-01-20T17:57:31
# 48    47008  2023-01-20T17:38:16
# 49    47007  2023-01-20T17:19:06
#
#                                   preshot_description  \
# 0                                               retry
# 1   Brake chopper test. Restore 44539. P1, TF and ...
# 2   Repeat daily test shot with PS enable windows ...
# 3   Restore prepared setup all-coil-first-shot. Ex...
# 4                                               retry
# ..                                                ...
# 45  [Integrated control test] Restore IntegratedCt...
# 46             [TF test] Restore All_Coil_First_Shot.
# 47   [FPP-02 TAEs] Repeat, diagnostics in position 1.
# 48  [FPP-02 TAEs] Straight repeat again. Diagnosti...
# 49  [FPP-02 TAEs] Straight repeat with movement of...
#
#                                  postshot_description campaign reference_shot  \
# 0   rtp stops st07 and st25, plus event 40 and 50 ...      MU3           <NA>
# 1                                               abort      MU3        44539.0
# 2   Error in channels 11 and 12 on bolometer. Wave...      MU3           <NA>
# 3   Looks OK, I don't have a code to test the magn...      MU3           <NA>
# 4      Ran OK, no trips, all PF currents as demanded.      MU3        45847.0
# ..                                                ...      ...            ...
# 45  Terminated early but the gas response was bett...      MU2        46994.0
# 46                                Currents look good.      MU2           <NA>
# 47  Good SW but only 30ms of south. Not useful for...      MU2        47008.0
# 48  Density higher than the previous shot early on...      MU2        47007.0
# 49  Sort of interesting, SW beam cuts out then the...      MU2        47006.0
#
#    scenario  heating pellets rmp_coil  ... cpf_vol_ipmax cpf_vol_max  \
# 0      <NA>     <NA>   False    False  ...          <NA>        <NA>
# 1      <NA>     <NA>   False    False  ...          <NA>        <NA>
# 2      <NA>     <NA>   False    False  ...          <NA>        <NA>
# 3      <NA>     <NA>   False    False  ...          <NA>        <NA>
# 4      <NA>     <NA>   False    False  ...          <NA>        <NA>
# ..      ...      ...     ...      ...  ...           ...         ...
# 45     15.0    Ohmic   False    False  ...          <NA>        <NA>
# 46     <NA>     <NA>   False    False  ...          <NA>        <NA>
# 47     14.0     <NA>   False    False  ...          <NA>        <NA>
# 48     14.0  2 Beams   False    False  ...          <NA>        <NA>
# 49     14.0  2 Beams   False    False  ...          <NA>        <NA>
#
#    cpf_vol_truby cpf_wmhd_ipmax cpf_wmhd_max cpf_wmhd_truby cpf_zeff_ipmax  \
# 0           <NA>           <NA>         <NA>           <NA>           <NA>
# 1           <NA>           <NA>         <NA>           <NA>           <NA>
# 2           <NA>           <NA>         <NA>           <NA>           <NA>
# 3           <NA>           <NA>         <NA>           <NA>           <NA>
# 4           <NA>           <NA>         <NA>           <NA>           <NA>
# ..           ...            ...          ...            ...            ...
# 45          <NA>           <NA>         <NA>           <NA>           <NA>
# 46          <NA>           <NA>         <NA>           <NA>           <NA>
# 47          <NA>           <NA>         <NA>           <NA>           <NA>
# 48          <NA>           <NA>         <NA>           <NA>           <NA>
# 49          <NA>           <NA>         <NA>           <NA>           <NA>
#
#    cpf_zeff_max cpf_zeff_truby cpf_zmag_efit
# 0          <NA>           <NA>          <NA>
# 1          <NA>           <NA>          <NA>
# 2          <NA>           <NA>          <NA>
# 3          <NA>           <NA>          <NA>
# 4          <NA>           <NA>          <NA>
# ..          ...            ...           ...
# 45         <NA>           <NA>          <NA>
# 46         <NA>           <NA>          <NA>
# 47         <NA>           <NA>          <NA>
# 48         <NA>           <NA>          <NA>
# 49         <NA>           <NA>          <NA>
#
# [200 rows x 280 columns]
