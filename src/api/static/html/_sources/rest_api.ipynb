# %% [markdown]
# # Querying Metadata with the REST API
#
# In this notebook we explore searching for metadata from the REST API. The REST API provides a method to programmatically extract a JSON representation of the meta data from the API.
#
# First we load some python dependancies that we will use as part of this notebook and set the variable `ENDPOINT_URL` to the location of the REST API.

# %%
import pandas as pd
import requests
import dask
import dask.dataframe as dd
import yaml

with open('config.yml') as file_handle:
    config = yaml.load(file_handle, yaml.FullLoader)

ENDPOINT_URL = config['rest_api']

# %% [markdown]
# Below we print the location of the endpoint we will query in this notebook:

# %%
print(f"REST API Endpoint: {ENDPOINT_URL}")
# Out:
# REST API Endpoint: http://209.97.185.27:8081/json

# %% [markdown]
# ## Querying Shots with the REST API
#
# We're going to use the python `requests` library to query metadata from get metadata from the database. All we need to do to get a result is to query the database with a HTTP GET at the appropriate endpoint. For example, to get information about different experimental shots we can query the `/json/shots/` endpoint.

# %%
response = requests.get(f'{ENDPOINT_URL}/shots')
result = response.json()
print(f"Query returned status code: {response.status_code}")
# Out:
# Query returned status code: 200

# %% [markdown]
# The shots endpoint returns a JSON payload with a list of shots. Let's look at the first element from the payload:

# %%
result[0]
# Out:
# {'shot_id': 30471,
#  'timestamp': '2013-09-27T15:20:00',
#  'preshot_description': '\nThe last plasma:\nConvert to i/b Helios 1724 mbar fill and repeat\nStop beam at 140ms, beam at 70kV. \n',
#  'postshot_description': '\nGood shot.\n',
#  'campaign': 'M9',
#  'reference_shot': 30470,
#  'scenario': 2,
#  'heating': 'SS Beam',
#  'pellets': False,
#  'rmp_coil': False,
#  'current_range': '700 kA',
#  'divertor_config': 'Conventional',
#  'plasma_shape': 'Lower Single Null',
#  'facility': 'MAST',
#  'cpf_abort': 0.0,
#  'cpf_amin_ipmax': 0.6082594266596257,
#  'cpf_amin_max': 0.6102043,
#  'cpf_amin_truby': 0.0,
#  'cpf_area_ipmax': 1.9033160214221327,
#  'cpf_area_max': 1.965805,
#  'cpf_area_truby': 0.0,
#  'cpf_bepmhd_ipmax': 0.34328417278133033,
#  'cpf_bepmhd_max': 0.39305434,
#  'cpf_bepmhd_truby': 0.0,
#  'cpf_betmhd_ipmax': 7.1242606250376665,
#  'cpf_betmhd_max': 7.4911194,
#  'cpf_betmhd_truby': 0.0,
#  'cpf_bt_ipmax': -0.2851174433375451,
#  'cpf_bt_max': -0.28102276,
#  'cpf_bt_truby': 0.0,
#  'cpf_c2ratio': 0.0,
#  'cpf_creation': '2013-09-27T00:00:00',
#  'cpf_dwmhd_ipmax': -506018.8862366498,
#  'cpf_dwmhd_max': 25309066.0,
#  'cpf_dwmhd_truby': 0.0,
#  'cpf_enbi_max_ss': 71.17717933654785,
#  'cpf_enbi_max_sw': 0.0,
#  'cpf_exp_date': '2013-09-27T00:00:00',
#  'cpf_exp_number': 30471,
#  'cpf_exp_time': '16:20:00',
#  'cpf_gdc_duration': 8.0,
#  'cpf_gdc_time': 16.11,
#  'cpf_ibgas_pressure': 1749.0,
#  'cpf_ip_av': 583.3264,
#  'cpf_ip_max': 601.1647338867188,
#  'cpf_jnbi_ipmax': 0.17206642125259697,
#  'cpf_jnbi_ipmax_ss': 0.17206642125259697,
#  'cpf_jnbi_ipmax_sw': 0.0,
#  'cpf_jnbi_max': 0.13641915,
#  'cpf_jnbi_max_ss': 0.13641915,
#  'cpf_jnbi_max_sw': 0.0,
#  'cpf_jnbi_total': 0.17167596085360026,
#  'cpf_jnbi_total_ss': 0.17167596085360026,
#  'cpf_jnbi_total_sw': 0.0,
#  'cpf_jnbi_truby': 0.0,
#  'cpf_jnbi_truby_ss': 0.000201942,
#  'cpf_jnbi_truby_sw': 0.0,
#  'cpf_johm_ipmax': 0.34418105059390186,
#  'cpf_johm_max': 0.0,
#  'cpf_johm_total': 0.3728483125,
#  'cpf_johm_truby': 0.0,
#  'cpf_kappa_ipmax': 1.882436717585813,
#  'cpf_kappa_max': 1.9741577,
#  'cpf_kappa_truby': 0.0,
#  'cpf_li_2_ipmax': 0.9630862,
#  'cpf_li_2_max': 62.25109,
#  'cpf_li_2_truby': 0.0,
#  'cpf_li_3_ipmax': 0.7087746,
#  'cpf_li_3_max': 59.9186,
#  'cpf_li_3_truby': 0.0,
#  'cpf_ndl_co2_ipmax': 6.56911e+19,
#  'cpf_ndl_co2_max': 8.58863e+19,
#  'cpf_ndl_co2_truby': 0.0,
#  'cpf_ne0_ipmax': 1.703896785505509e+19,
#  'cpf_ne0_max': 4.7875736e+19,
#  'cpf_ne0_truby': 0.0,
#  'cpf_ne0ratio_ipmax': 1.313999913067867,
#  'cpf_ne0ruby': 0.0,
#  'cpf_ne_bar_ipmax': 1.174775331199e+19,
#  'cpf_ne_yag_bar_ipmax': 1.2967251889136953e+19,
#  'cpf_ngreenwald_ipmax': 5.5341344267370635e+19,
#  'cpf_ngreenwaldratio_ipmax': 4.7108023804762835,
#  'cpf_o2ratio': 0.0,
#  'cpf_objective': "'Measure AE mode behaviour while changing H/D ratio'",
#  'cpf_pe0_ipmax': 1915.6897048276294,
#  'cpf_pe0_max': 2144.224609375,
#  'cpf_pe0_truby': 0.0,
#  'cpf_pe0ruby': 0.0,
#  'cpf_pic': "'SS'",
#  'cpf_pnbi_ipmax': 0.0,
#  'cpf_pnbi_ipmax_ss': 0.0,
#  'cpf_pnbi_ipmax_sw': 0.0,
#  'cpf_pnbi_max': 2.062899,
#  'cpf_pnbi_max_ss': 2.062899,
#  'cpf_pnbi_max_sw': 0.0,
#  'cpf_pnbi_truby': 0.0,
#  'cpf_pnbi_truby_ss': 0.0,
#  'cpf_pnbi_truby_sw': 0.0,
#  'cpf_pohm_ipmax': 0.9213806144820933,
#  'cpf_pohm_max': 73.787904,
#  'cpf_pohm_truby': 0.0,
#  'cpf_postshot': "'Good shot.'",
#  'cpf_prad_ipmax': 139612.92719007152,
#  'cpf_prad_max': 176987.38,
#  'cpf_prad_truby': 0.0,
#  'cpf_pradne2': 0.3139487910590756,
#  'cpf_preshot': "'The last plasma:Convert to i/b Helios 1724 mbar fill and repeatStop beam at 140ms beam at 70kV.'",
#  'cpf_program': "'CAE studies'",
#  'cpf_q95_ipmax': 6.019628297654163,
#  'cpf_q95_min': 0.9815048,
#  'cpf_q95_truby': 0.0,
#  'cpf_reference': 30470.0,
#  'cpf_rgeo_ipmax': 0.8088155995649847,
#  'cpf_rgeo_max': 0.82720023,
#  'cpf_rgeo_truby': 0.0,
#  'cpf_rinner_da': 0.23384315,
#  'cpf_rinner_efit': 0.1981900930404663,
#  'cpf_rmag_efit': 0.9027055,
#  'cpf_router_da': 1.4092888,
#  'cpf_router_efit': 1.4182847,
#  'cpf_sarea_ipmax': 24.728232690966795,
#  'cpf_sarea_max': 25.858627,
#  'cpf_sarea_truby': 0.0,
#  'cpf_sl': "'GC/AJT'",
#  'cpf_summary': "'Data from neutron camera and magnetics obtained in plasmas with various mixtures of deuterium and hydrogen'",
#  'cpf_tamin_max': 0.13499999,
#  'cpf_tarea_max': 0.12,
#  'cpf_tautot_ipmax': 0.018096046373580896,
#  'cpf_tautot_max': 0.021804662,
#  'cpf_tautot_truby': 0.0,
#  'cpf_tbepmhd_max': 0.06,
#  'cpf_tbetmhd_max': 0.14,
#  'cpf_tbt_max': 0.125,
#  'cpf_tdwmhd_max': 0.035,
#  'cpf_te0_ipmax': 778.2895702348814,
#  'cpf_te0_max': 782.90155,
#  'cpf_te0_truby': 0.0,
#  'cpf_te0ratio_ipmax': 1.8449364099863268,
#  'cpf_te0ruby': 0.0,
#  'cpf_te_yag_bar_ipmax': 421.8517050355407,
#  'cpf_tend': 0.19099975,
#  'cpf_tend_ibgas': 209.95,
#  'cpf_tend_nbi': 0.14005,
#  'cpf_tend_nbi_ss': 0.14005,
#  'cpf_tend_nbi_sw': 0.0,
#  'cpf_term_code': 0.0,
#  'cpf_tftend': 0.18659973,
#  'cpf_tftstart': 0.121599674,
#  'cpf_tipmax': 0.14179969,
#  'cpf_tkappa_max': 0.12,
#  'cpf_tli_2_max': 0.035,
#  'cpf_tli_3_max': 0.035,
#  'cpf_tndl_co2_max': 0.06144,
#  'cpf_tne0_max': 0.0523736,
#  'cpf_tpe0_max': 0.1190402,
#  'cpf_tpnbi_max': 0.12169999,
#  'cpf_tpnbi_max_ss': 0.12169999,
#  'cpf_tpnbi_max_sw': 0.0,
#  'cpf_tpohm_max': 0.035,
#  'cpf_tprad_max': 0.1516,
#  'cpf_tq95_min': 0.035,
#  'cpf_trgeo_max': 0.125,
#  'cpf_truby': 0.0,
#  'cpf_tsarea_max': 0.125,
#  'cpf_tstart': 0.0009996891,
#  'cpf_tstart_ibgas': 9.95,
#  'cpf_tstart_nbi': 0.050899982,
#  'cpf_tstart_nbi_ss': 0.050899982,
#  'cpf_tstart_nbi_sw': 0.0,
#  'cpf_ttautot_max': 0.13,
#  'cpf_tte0_max': 0.1428533,
#  'cpf_tvol_max': 0.125,
#  'cpf_twmhd_max': 0.13499999,
#  'cpf_useful': 1.0,
#  'cpf_vol_ipmax': 8.817559231505726,
#  'cpf_vol_max': 9.283702,
#  'cpf_vol_truby': 0.0,
#  'cpf_wmhd_ipmax': 38063.58237995773,
#  'cpf_wmhd_max': 40906.09,
#  'cpf_wmhd_truby': 0.0,
#  'cpf_zmag_efit': 0.014340116}

# %% [markdown]
# Each item in the list is a json object. Tis contains a the meta-data items that corresponded to our query. In this case, each item contains information about a different MAST shot. Each item has lots of information about different shots, for example the shot ID, the campaign the shot was part of, the pre- and post-shot description by investigators.
#
# For more information on the what's returned by the API you can look at the endpoint documentation:
#
# https://mast-app.site/redoc

# %% [markdown]
# Of course, we can read all this JSON data directly into common python data analysis packages, for example, we can create a `pandas` dataframe directly from the endpoint

# %%
df = pd.read_json(f'{ENDPOINT_URL}/shots')
df.head()
# Out:
#    shot_id           timestamp  \
# 0    30471 2013-09-27 15:20:00
# 1    30470 2013-09-27 15:03:00
# 2    30469 2013-09-27 14:39:00
# 3    30468 2013-09-27 14:21:00
# 4    30467 2013-09-27 14:03:00
#
#                                  preshot_description  \
# 0  \nThe last plasma:\nConvert to i/b Helios 1724...
# 1  \nRepeat last using hydrogen in outboard and c...
# 2  \nRepeat with increased beam power (74 kV)\ncH...
# 3  \nRepeat with new neutron camera position.\ncH...
# 4  \nRepeat with new neutron camera position.\ncH...
#
#                                 postshot_description campaign  reference_shot  \
# 0                                     \nGood shot.\n       M9           30470
# 1                                     \nNo HF gas.\n       M9           30467
# 2                      \nGood shot. Modes present.\n       M9           30467
# 3                       \nGood beam.\nGood repeat.\n       M9           30467
# 4  \nTwo times lower DD neutron rate than referen...       M9           30459
#
#    scenario  heating  pellets  rmp_coil  ... cpf_tvol_max cpf_twmhd_max  \
# 0       2.0  SS Beam    False       0.0  ...        0.125         0.135
# 1       2.0  SS Beam    False       NaN  ...        0.135         0.105
# 2       3.0  SS Beam    False       0.0  ...        0.140         0.145
# 3       2.0  SS Beam    False       0.0  ...        0.140         0.130
# 4       3.0  SS Beam    False       0.0  ...        0.125         0.180
#
#   cpf_useful cpf_vol_ipmax  cpf_vol_max  cpf_vol_truby  cpf_wmhd_ipmax  \
# 0          1      8.817559     9.283702            0.0    38063.582380
# 1          0      9.687049    10.055509            0.0    17290.432865
# 2          1      8.988730     9.047923            0.0    47466.249616
# 3          1      9.102411     9.107017            0.0    48516.962675
# 4          1      9.029202     9.046394            0.0    49469.122469
#
#    cpf_wmhd_max  cpf_wmhd_truby  cpf_zmag_efit
# 0     40906.090             0.0       0.014340
# 1     22310.516             0.0       0.015164
# 2     49115.805             0.0       0.015299
# 3     49382.133             0.0       0.012445
# 4     52653.445             0.0       0.013202
#
# [5 rows x 181 columns]

# %% [markdown]
# ### Searching & Filtering Data
#
# All REST API endpoints can take query parameters to filter the data returned. For example, we can return all shots for the `M9` campaign by using the approrpiate query string.
#
# For example, we can query for everything from the `M9` campaign by adding `?campaign=M9` to our query string.

# %%
df = pd.read_json(f"{ENDPOINT_URL}/shots?campaign=M9")
df.head()
# Out:
#    shot_id           timestamp  \
# 0    30471 2013-09-27 15:20:00
# 1    30470 2013-09-27 15:03:00
# 2    30469 2013-09-27 14:39:00
# 3    30468 2013-09-27 14:21:00
# 4    30467 2013-09-27 14:03:00
#
#                                  preshot_description  \
# 0  \nThe last plasma:\nConvert to i/b Helios 1724...
# 1  \nRepeat last using hydrogen in outboard and c...
# 2  \nRepeat with increased beam power (74 kV)\ncH...
# 3  \nRepeat with new neutron camera position.\ncH...
# 4  \nRepeat with new neutron camera position.\ncH...
#
#                                 postshot_description campaign  reference_shot  \
# 0                                     \nGood shot.\n       M9           30470
# 1                                     \nNo HF gas.\n       M9           30467
# 2                      \nGood shot. Modes present.\n       M9           30467
# 3                       \nGood beam.\nGood repeat.\n       M9           30467
# 4  \nTwo times lower DD neutron rate than referen...       M9           30459
#
#    scenario  heating  pellets  rmp_coil  ... cpf_tvol_max cpf_twmhd_max  \
# 0       2.0  SS Beam    False       0.0  ...        0.125         0.135
# 1       2.0  SS Beam    False       NaN  ...        0.135         0.105
# 2       3.0  SS Beam    False       0.0  ...        0.140         0.145
# 3       2.0  SS Beam    False       0.0  ...        0.140         0.130
# 4       3.0  SS Beam    False       0.0  ...        0.125         0.180
#
#   cpf_useful cpf_vol_ipmax  cpf_vol_max  cpf_vol_truby  cpf_wmhd_ipmax  \
# 0          1      8.817559     9.283702            0.0    38063.582380
# 1          0      9.687049    10.055509            0.0    17290.432865
# 2          1      8.988730     9.047923            0.0    47466.249616
# 3          1      9.102411     9.107017            0.0    48516.962675
# 4          1      9.029202     9.046394            0.0    49469.122469
#
#    cpf_wmhd_max  cpf_wmhd_truby  cpf_zmag_efit
# 0     40906.090             0.0       0.014340
# 1     22310.516             0.0       0.015164
# 2     49115.805             0.0       0.015299
# 3     49382.133             0.0       0.012445
# 4     52653.445             0.0       0.013202
#
# [5 rows x 181 columns]

# %% [markdown]
# ### Pagination
# The REST API responses are _paginated_, meaning that only a subset of the full items are returned with each query. Pagination is used to limit the total number of requests made by each user to prevent any single user overloading the server with huge data requests.
#
# Pagination information is included in the header of the response and corresponds to [RFC 8288](https://datatracker.ietf.org/doc/html/rfc8288). The header contains the following properties:
#
#  - `x-total-count` - this is the total number of items in the database which matched your query.
#  - `x-total-pages` - this is the total number of pages with the given page size.
#  - `link` - contains links to the next and previous pages for this query.
#
# You can control the pagination using the following options as query arguments:
#  - `page=xx` to set the page of items to view
#  - `per_page=xx` to set the number of results returned by each page.

# %%
response = requests.get(f'{ENDPOINT_URL}/shots?page=10&per_page=2')
result = response.json()
headers = response.headers

print("Total number of pages", headers['x-total-pages'])
print("Total number of items in the database", headers['x-total-count'])
print("Links to the next and previous pages", headers['link'])

df = pd.DataFrame(result)
df
# Out:
# Total number of pages 9185
# Total number of items in the database 18370
# Links to the next and previous pages <http://209.97.185.27:8081/json/shots?page=11&per_page=2>; rel="next"<http://209.97.185.27:8081/json/shots?page=9&per_page=2>; rel="previous"
#    shot_id            timestamp  \
# 0    30451  2013-09-26T16:58:00
# 1    30450  2013-09-26T16:37:00
#
#                                  preshot_description  \
# 0  \nRepeat with TF settings as in 29341. Very lo...
# 1      \nReload 30377 and TF settings as in 29301.\n
#
#                                 postshot_description campaign  reference_shot  \
# 0  \nOk. Dies very early, but late enough for the...       M9           30377
# 1  \nOk, although shorter than reference, probabl...       M9           30377
#
#    scenario  heating  pellets  rmp_coil  ... cpf_tvol_max cpf_twmhd_max  \
# 0         2  SS Beam    False     False  ...        0.130         0.120
# 1         2  SS Beam    False     False  ...        0.165         0.185
#
#   cpf_useful cpf_vol_ipmax  cpf_vol_max  cpf_vol_truby  cpf_wmhd_ipmax  \
# 0        1.0      7.022583     7.216327            0.0    25568.796591
# 1        1.0      7.812098     9.001694            0.0    47538.293348
#
#    cpf_wmhd_max  cpf_wmhd_truby  cpf_zmag_efit
# 0      25959.92             0.0      -0.000501
# 1      63824.93             0.0       0.005763
#
# [2 rows x 181 columns]
