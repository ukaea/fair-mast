# %%
import pandas as pd
import numpy as np
from pprint import pprint
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine, MetaData, insert, delete, select, text

def connect(URI):
    engine = create_engine(URI)
    metadata_obj = MetaData()
    metadata_obj.reflect(engine)
    return metadata_obj, engine

URI = 'mysql+pymysql://root:root@localhost:3306/mast_drupal'
metadata, engine = connect(URI)
Session = sessionmaker(bind = engine)
session = Session()

# pprint([t for t in list(metadata.tables.keys()) if 'field_data_field' in t])
pprint(list(metadata.tables.keys()))
# Out:
# ['actions',
#  'authmap',
#  'backup_migrate_destinations',
#  'backup_migrate_profiles',
#  'backup_migrate_schedules',
#  'backup_migrate_sources',
#  'batch',
#  'block',
#  'block_custom',
#  'block_node_type',
#  'block_role',
#  'blocked_ips',
#  'cache',
#  'cache_admin_menu',
#  'cache_block',
#  'cache_bootstrap',
#  'cache_features',
#  'cache_feeds_http',
#  'cache_field',
#  'cache_filter',
#  'cache_form',
#  'cache_image',
#  'cache_media_oembed',
#  'cache_menu',
#  'cache_page',
#  'cache_panels',
#  'cache_path',
#  'cache_token',
#  'cache_update',
#  'cache_views',
#  'cache_views_data',
#  'ckeditor_input_format',
#  'ckeditor_settings',
#  'comment',
#  'conditional_fields',
#  'ctools_css_cache',
#  'ctools_object_cache',
#  'date_format_locale',
#  'date_format_type',
#  'date_formats',
#  'facetapi',
#  'features_signature',
#  'feeds_importer',
#  'feeds_item',
#  'feeds_log',
#  'feeds_push_subscriptions',
#  'feeds_source',
#  'field_config',
#  'field_config_instance',
#  'field_data_body',
#  'field_data_comment_body',
#  'field_data_field_comment_diagnostics',
#  'field_data_field_comment_type',
#  'field_data_field_eic',
#  'field_data_field_eventlog_author',
#  'field_data_field_eventlog_category',
#  'field_data_field_eventlog_delay_duration',
#  'field_data_field_eventlog_delay_flag',
#  'field_data_field_eventlog_end_datetime',
#  'field_data_field_eventlog_hidden_daterange',
#  'field_data_field_eventlog_id',
#  'field_data_field_eventlog_keywords',
#  'field_data_field_eventlog_meic_ref',
#  'field_data_field_eventlog_nbishot',
#  'field_data_field_eventlog_rangeselect',
#  'field_data_field_eventlog_related',
#  'field_data_field_eventlog_res',
#  'field_data_field_eventlog_resolution_user',
#  'field_data_field_eventlog_role',
#  'field_data_field_eventlog_severity',
#  'field_data_field_eventlog_shots',
#  'field_data_field_eventlog_start_datetime',
#  'field_data_field_eventlog_status',
#  'field_data_field_eventlog_title',
#  'field_data_field_experiment_tags',
#  'field_data_field_fault_files',
#  'field_data_field_file_image_alt_text',
#  'field_data_field_file_image_title_text',
#  'field_data_field_file_tag',
#  'field_data_field_first_name',
#  'field_data_field_image',
#  'field_data_field_meic_comment_bform_type',
#  'field_data_field_meic_comment_datetime',
#  'field_data_field_meic_comment_elog',
#  'field_data_field_meic_comment_gform_type',
#  'field_data_field_meic_comment_type',
#  'field_data_field_meic_session_date',
#  'field_data_field_meic_shot_comment',
#  'field_data_field_meic_shot_datac',
#  'field_data_field_meic_shot_datetime',
#  'field_data_field_meic_shot_meic',
#  'field_data_field_meic_shot_nbi',
#  'field_data_field_meic_shot_psoe',
#  'field_data_field_meic_shot_role_type',
#  'field_data_field_meic_shot_sc',
#  'field_data_field_meic_shot_sl',
#  'field_data_field_meic_shot_sl_shot',
#  'field_data_field_meic_shot_status',
#  'field_data_field_meic_sllog',
#  'field_data_field_meic_sllog_aborted_shots',
#  'field_data_field_meic_sllog_aims',
#  'field_data_field_meic_sllog_bform_closed',
#  'field_data_field_meic_sllog_bform_raised',
#  'field_data_field_meic_sllog_datac',
#  'field_data_field_meic_sllog_datac_shots',
#  'field_data_field_meic_sllog_delay',
#  'field_data_field_meic_sllog_elogs_closed',
#  'field_data_field_meic_sllog_elogs_raised',
#  'field_data_field_meic_sllog_elogs_ref',
#  'field_data_field_meic_sllog_experiment_tags',
#  'field_data_field_meic_sllog_failed_shots',
#  'field_data_field_meic_sllog_gform_closed',
#  'field_data_field_meic_sllog_gform_raised',
#  'field_data_field_meic_sllog_meic',
#  'field_data_field_meic_sllog_nbi',
#  'field_data_field_meic_sllog_psoe',
#  'field_data_field_meic_sllog_role_type',
#  'field_data_field_meic_sllog_sc',
#  'field_data_field_meic_sllog_sl',
#  'field_data_field_meic_sllog_sllog',
#  'field_data_field_meic_sllog_success_shots',
#  'field_data_field_meic_sllog_summary',
#  'field_data_field_moi_annexes',
#  'field_data_field_moi_category',
#  'field_data_field_moi_document',
#  'field_data_field_moi_number',
#  'field_data_field_ops_role_date_appointed',
#  'field_data_field_ops_role_name',
#  'field_data_field_ops_role_qualification',
#  'field_data_field_ops_role_role',
#  'field_data_field_ops_role_status',
#  'field_data_field_run_record_assignee',
#  'field_data_field_run_record_code',
#  'field_data_field_run_record_end_time',
#  'field_data_field_run_record_expt',
#  'field_data_field_run_record_file_location',
#  'field_data_field_run_record_id',
#  'field_data_field_run_record_input_desc',
#  'field_data_field_run_record_output_date',
#  'field_data_field_run_record_output_desc',
#  'field_data_field_run_record_request_date',
#  'field_data_field_run_record_request_id',
#  'field_data_field_run_record_requested_by',
#  'field_data_field_run_record_run_number',
#  'field_data_field_run_record_shot',
#  'field_data_field_run_record_start_time',
#  'field_data_field_run_record_status',
#  'field_data_field_run_record_type',
#  'field_data_field_sc',
#  'field_data_field_shot_abort',
#  'field_data_field_shot_betmhd_max',
#  'field_data_field_shot_bt_max',
#  'field_data_field_shot_datac',
#  'field_data_field_shot_datetime',
#  'field_data_field_shot_gas_valves',
#  'field_data_field_shot_ip_max',
#  'field_data_field_shot_meic_shot_log',
#  'field_data_field_shot_nbi_operators',
#  'field_data_field_shot_ne0_max',
#  'field_data_field_shot_owner',
#  'field_data_field_shot_phys_pellets',
#  'field_data_field_shot_phys_rmp_coils',
#  'field_data_field_shot_physics_div_config',
#  'field_data_field_shot_physics_heating',
#  'field_data_field_shot_physics_ip_range',
#  'field_data_field_shot_physics_shape',
#  'field_data_field_shot_pnbi_max',
#  'field_data_field_shot_postshot',
#  'field_data_field_shot_preshot',
#  'field_data_field_shot_psoe',
#  'field_data_field_shot_reference',
#  'field_data_field_shot_request',
#  'field_data_field_shot_scenario',
#  'field_data_field_shot_sessionlog',
#  'field_data_field_shot_te0_max',
#  'field_data_field_shot_type',
#  'field_data_field_shot_useful',
#  'field_data_field_sl',
#  'field_data_field_sllog_aims',
#  'field_data_field_sllog_campaign',
#  'field_data_field_sllog_date',
#  'field_data_field_sllog_meic_session_log',
#  'field_data_field_sllog_programme',
#  'field_data_field_sllog_scenarios',
#  'field_data_field_sllog_shot_range',
#  'field_data_field_sllog_summary',
#  'field_data_field_surname',
#  'field_data_field_tags',
#  'field_data_field_term_link',
#  'field_data_ldap_user_current_dn',
#  'field_data_ldap_user_last_checked',
#  'field_data_ldap_user_ldap_exclude',
#  'field_data_ldap_user_prov_entries',
#  'field_data_ldap_user_puid',
#  'field_data_ldap_user_puid_property',
#  'field_data_ldap_user_puid_sid',
#  'field_group',
#  'field_revision_body',
#  'field_revision_comment_body',
#  'field_revision_field_comment_diagnostics',
#  'field_revision_field_comment_type',
#  'field_revision_field_eic',
#  'field_revision_field_eventlog_author',
#  'field_revision_field_eventlog_category',
#  'field_revision_field_eventlog_delay_duration',
#  'field_revision_field_eventlog_delay_flag',
#  'field_revision_field_eventlog_end_datetime',
#  'field_revision_field_eventlog_hidden_daterange',
#  'field_revision_field_eventlog_id',
#  'field_revision_field_eventlog_keywords',
#  'field_revision_field_eventlog_meic_ref',
#  'field_revision_field_eventlog_nbishot',
#  'field_revision_field_eventlog_rangeselect',
#  'field_revision_field_eventlog_related',
#  'field_revision_field_eventlog_res',
#  'field_revision_field_eventlog_resolution_user',
#  'field_revision_field_eventlog_role',
#  'field_revision_field_eventlog_severity',
#  'field_revision_field_eventlog_shots',
#  'field_revision_field_eventlog_start_datetime',
#  'field_revision_field_eventlog_status',
#  'field_revision_field_eventlog_title',
#  'field_revision_field_experiment_tags',
#  'field_revision_field_fault_files',
#  'field_revision_field_file_image_alt_text',
#  'field_revision_field_file_image_title_text',
#  'field_revision_field_file_tag',
#  'field_revision_field_first_name',
#  'field_revision_field_image',
#  'field_revision_field_meic_comment_bform_type',
#  'field_revision_field_meic_comment_datetime',
#  'field_revision_field_meic_comment_elog',
#  'field_revision_field_meic_comment_gform_type',
#  'field_revision_field_meic_comment_type',
#  'field_revision_field_meic_session_date',
#  'field_revision_field_meic_shot_comment',
#  'field_revision_field_meic_shot_datac',
#  'field_revision_field_meic_shot_datetime',
#  'field_revision_field_meic_shot_meic',
#  'field_revision_field_meic_shot_nbi',
#  'field_revision_field_meic_shot_psoe',
#  'field_revision_field_meic_shot_role_type',
#  'field_revision_field_meic_shot_sc',
#  'field_revision_field_meic_shot_sl',
#  'field_revision_field_meic_shot_sl_shot',
#  'field_revision_field_meic_shot_status',
#  'field_revision_field_meic_sllog',
#  'field_revision_field_meic_sllog_aborted_shots',
#  'field_revision_field_meic_sllog_aims',
#  'field_revision_field_meic_sllog_bform_closed',
#  'field_revision_field_meic_sllog_bform_raised',
#  'field_revision_field_meic_sllog_datac',
#  'field_revision_field_meic_sllog_datac_shots',
#  'field_revision_field_meic_sllog_delay',
#  'field_revision_field_meic_sllog_elogs_closed',
#  'field_revision_field_meic_sllog_elogs_raised',
#  'field_revision_field_meic_sllog_elogs_ref',
#  'field_revision_field_meic_sllog_experiment_tags',
#  'field_revision_field_meic_sllog_failed_shots',
#  'field_revision_field_meic_sllog_gform_closed',
#  'field_revision_field_meic_sllog_gform_raised',
#  'field_revision_field_meic_sllog_meic',
#  'field_revision_field_meic_sllog_nbi',
#  'field_revision_field_meic_sllog_psoe',
#  'field_revision_field_meic_sllog_role_type',
#  'field_revision_field_meic_sllog_sc',
#  'field_revision_field_meic_sllog_sl',
#  'field_revision_field_meic_sllog_sllog',
#  'field_revision_field_meic_sllog_success_shots',
#  'field_revision_field_meic_sllog_summary',
#  'field_revision_field_moi_annexes',
#  'field_revision_field_moi_category',
#  'field_revision_field_moi_document',
#  'field_revision_field_moi_number',
#  'field_revision_field_ops_role_date_appointed',
#  'field_revision_field_ops_role_name',
#  'field_revision_field_ops_role_qualification',
#  'field_revision_field_ops_role_role',
#  'field_revision_field_ops_role_status',
#  'field_revision_field_run_record_assignee',
#  'field_revision_field_run_record_code',
#  'field_revision_field_run_record_end_time',
#  'field_revision_field_run_record_expt',
#  'field_revision_field_run_record_file_location',
#  'field_revision_field_run_record_id',
#  'field_revision_field_run_record_input_desc',
#  'field_revision_field_run_record_output_date',
#  'field_revision_field_run_record_output_desc',
#  'field_revision_field_run_record_request_date',
#  'field_revision_field_run_record_request_id',
#  'field_revision_field_run_record_requested_by',
#  'field_revision_field_run_record_run_number',
#  'field_revision_field_run_record_shot',
#  'field_revision_field_run_record_start_time',
#  'field_revision_field_run_record_status',
#  'field_revision_field_run_record_type',
#  'field_revision_field_sc',
#  'field_revision_field_shot_abort',
#  'field_revision_field_shot_betmhd_max',
#  'field_revision_field_shot_bt_max',
#  'field_revision_field_shot_datac',
#  'field_revision_field_shot_datetime',
#  'field_revision_field_shot_gas_valves',
#  'field_revision_field_shot_ip_max',
#  'field_revision_field_shot_meic_shot_log',
#  'field_revision_field_shot_nbi_operators',
#  'field_revision_field_shot_ne0_max',
#  'field_revision_field_shot_owner',
#  'field_revision_field_shot_phys_pellets',
#  'field_revision_field_shot_phys_rmp_coils',
#  'field_revision_field_shot_physics_div_config',
#  'field_revision_field_shot_physics_heating',
#  'field_revision_field_shot_physics_ip_range',
#  'field_revision_field_shot_physics_shape',
#  'field_revision_field_shot_pnbi_max',
#  'field_revision_field_shot_postshot',
#  'field_revision_field_shot_preshot',
#  'field_revision_field_shot_psoe',
#  'field_revision_field_shot_reference',
#  'field_revision_field_shot_request',
#  'field_revision_field_shot_scenario',
#  'field_revision_field_shot_sessionlog',
#  'field_revision_field_shot_te0_max',
#  'field_revision_field_shot_type',
#  'field_revision_field_shot_useful',
#  'field_revision_field_sl',
#  'field_revision_field_sllog_aims',
#  'field_revision_field_sllog_campaign',
#  'field_revision_field_sllog_date',
#  'field_revision_field_sllog_meic_session_log',
#  'field_revision_field_sllog_programme',
#  'field_revision_field_sllog_scenarios',
#  'field_revision_field_sllog_shot_range',
#  'field_revision_field_sllog_summary',
#  'field_revision_field_surname',
#  'field_revision_field_tags',
#  'field_revision_field_term_link',
#  'field_revision_ldap_user_current_dn',
#  'field_revision_ldap_user_last_checked',
#  'field_revision_ldap_user_ldap_exclude',
#  'field_revision_ldap_user_prov_entries',
#  'field_revision_ldap_user_puid',
#  'field_revision_ldap_user_puid_property',
#  'field_revision_ldap_user_puid_sid',
#  'file_display',
#  'file_managed',
#  'file_metadata',
#  'file_type',
#  'file_usage',
#  'filter',
#  'filter_format',
#  'flood',
#  'history',
#  'image_effects',
#  'image_styles',
#  'job_schedule',
#  'ldap_query',
#  'ldap_servers',
#  'login_destination',
#  'masquerade',
#  'masquerade_users',
#  'media_oembed_provider',
#  'media_restrict_wysiwyg',
#  'media_view_mode_wysiwyg',
#  'menu_custom',
#  'menu_links',
#  'menu_router',
#  'migrate_field_mapping',
#  'migrate_group',
#  'migrate_log',
#  'migrate_map_cpf_data',
#  'migrate_map_d2d_event_category_tags',
#  'migrate_map_d2d_experiment_tags',
#  'migrate_map_d2d_machine_category_tags',
#  'migrate_map_d2d_moi_category_tags',
#  'migrate_map_meicshotlogstimeupdate',
#  'migrate_map_mucodetagmigration',
#  'migrate_map_mumenulinksmigration',
#  'migrate_map_mumenumigration',
#  'migrate_map_murequestsmigration',
#  'migrate_map_murolemigration',
#  'migrate_map_muusermigration',
#  'migrate_map_pellet_tags',
#  'migrate_map_rmp_tags',
#  'migrate_map_scenario_tags',
#  'migrate_map_session_logs',
#  'migrate_map_session_sl_comments',
#  'migrate_map_shot_logs',
#  'migrate_map_shotlogstimeupdate',
#  'migrate_map_usersmigration',
#  'migrate_message_cpf_data',
#  'migrate_message_d2d_event_category_tags',
#  'migrate_message_d2d_experiment_tags',
#  'migrate_message_d2d_machine_category_tags',
#  'migrate_message_d2d_moi_category_tags',
#  'migrate_message_meicshotlogstimeupdate',
#  'migrate_message_mucodetagmigration',
#  'migrate_message_mumenulinksmigration',
#  'migrate_message_mumenumigration',
#  'migrate_message_murequestsmigration',
#  'migrate_message_murolemigration',
#  'migrate_message_muusermigration',
#  'migrate_message_pellet_tags',
#  'migrate_message_rmp_tags',
#  'migrate_message_scenario_tags',
#  'migrate_message_session_logs',
#  'migrate_message_session_sl_comments',
#  'migrate_message_shot_logs',
#  'migrate_message_shotlogstimeupdate',
#  'migrate_message_usersmigration',
#  'migrate_status',
#  'node',
#  'node_access',
#  'node_comment_statistics',
#  'node_revision',
#  'node_type',
#  'page_manager_handlers',
#  'page_manager_pages',
#  'page_manager_weights',
#  'panels_allowed_types',
#  'panels_display',
#  'panels_layout',
#  'panels_mini',
#  'panels_node',
#  'panels_pane',
#  'panels_renderer_pipeline',
#  'pathauto_state',
#  'print_node_conf',
#  'print_page_counter',
#  'print_pdf_node_conf',
#  'print_pdf_page_counter',
#  'queue',
#  'quicktabs',
#  'rdf_mapping',
#  'registry',
#  'registry_file',
#  'role',
#  'role_permission',
#  'search_api_db_event_log_index',
#  'search_api_db_event_log_index_field_eventlog_category',
#  'search_api_db_event_log_index_field_eventlog_keywords',
#  'search_api_db_event_log_index_field_eventlog_role',
#  'search_api_db_event_log_index_field_eventlog_shots',
#  'search_api_db_event_log_index_text',
#  'search_api_db_mast_operating_instruction_index',
#  'search_api_db_meic_session_log_index',
#  'search_api_db_meic_session_log_index_field_meic_sllog_datac',
#  'search_api_db_meic_session_log_index_field_meic_sllog_experime',
#  'search_api_db_meic_session_log_index_field_meic_sllog_meic',
#  'search_api_db_meic_session_log_index_field_meic_sllog_nbi',
#  'search_api_db_meic_session_log_index_field_meic_sllog_psoe',
#  'search_api_db_meic_session_log_index_field_meic_sllog_sc',
#  'search_api_db_meic_session_log_index_field_meic_sllog_sl',
#  'search_api_db_meic_session_log_index_text',
#  'search_api_db_moi_index_text',
#  'search_api_db_new_event_log_index',
#  'search_api_db_new_event_log_index_field_eventlog_keywords',
#  'search_api_db_new_event_log_index_text',
#  'search_api_db_run_record_index',
#  'search_api_db_run_record_index_text',
#  'search_api_db_session_index',
#  'search_api_db_session_index_field_eic',
#  'search_api_db_session_index_field_experiment_tags',
#  'search_api_db_session_index_field_sc',
#  'search_api_db_session_index_field_sl',
#  'search_api_db_session_index_field_sllog_scenarios',
#  'search_api_db_session_index_text',
#  'search_api_db_shot_index',
#  'search_api_db_shot_index_field_eic',
#  'search_api_db_shot_index_field_experiment_tags',
#  'search_api_db_shot_index_field_sc',
#  'search_api_db_shot_index_field_shot_scenario',
#  'search_api_db_shot_index_field_sl',
#  'search_api_db_shot_index_new',
#  'search_api_db_shot_index_new_field_eic',
#  'search_api_db_shot_index_new_field_experiment_tags',
#  'search_api_db_shot_index_new_field_sc',
#  'search_api_db_shot_index_new_field_shot_gas_valves',
#  'search_api_db_shot_index_new_field_shot_scenario',
#  'search_api_db_shot_index_new_field_sl',
#  'search_api_db_shot_index_new_text',
#  'search_api_db_shot_index_text',
#  'search_api_index',
#  'search_api_item',
#  'search_api_item_string_id',
#  'search_api_server',
#  'search_api_task',
#  'search_dataset',
#  'search_index',
#  'search_node_links',
#  'search_total',
#  'semaphore',
#  'sequences',
#  'serial_0e0477a8a1de4aa68e9072f6662bf69f',
#  'serial_c7d0d079579948240970b3872052b641',
#  'sessions',
#  'shortcut_set',
#  'shortcut_set_users',
#  'system',
#  'taxonomy_index',
#  'taxonomy_term_data',
#  'taxonomy_term_hierarchy',
#  'taxonomy_vocabulary',
#  'trigger_assignments',
#  'url_alias',
#  'users',
#  'users_roles',
#  'variable',
#  'views_data_export',
#  'views_data_export_object_cache',
#  'views_display',
#  'views_view',
#  'watchdog',
#  'workbench_access',
#  'workbench_access_node',
#  'workbench_access_role',
#  'workbench_access_user']

# %%
table_names = [
    'shot_physics_div_config',
    'shot_physics_heating',
    'shot_physics_ip_range',
    'shot_physics_shape',
    'shot_phys_pellets',
    'shot_phys_rmp_coils',
    'shot_preshot',
    'shot_postshot',
    'shot_owner',
    'shot_reference',
    'shot_scenario',
    'shot_datetime',
    'shot_sessionlog'
]

name_mapping = dict(
    shot_reference='field_shot_reference_target_id',
    shot_scenario='field_shot_scenario_tid',
    shot_phys_pellets='field_shot_phys_pellets_tid',
    shot_phys_rmp_coils='field_shot_phys_rmp_coils_tid',
    shot_sessionlog='field_shot_sessionlog_target_id'
)

# %%
dfs = []
for name in table_names:
    table = metadata.tables[f'field_data_field_{name}']
    column = name_mapping[name] if name in name_mapping else f'field_{name}_value'
    stmt = select(table.c.entity_id, table.c.bundle, table.columns[column])
        
    df = pd.read_sql(stmt, con=engine.connect())
    df = df.loc[df.bundle == 'mast_shot']
    df = df.drop('bundle', axis=1)
    df = df.set_index('entity_id')

    if '_tid' in column:
        tname = 'taxonomy_term_data'
        table = metadata.tables[tname]
        stmt = select(table.c.tid, table.c.name)
        terms = pd.read_sql(stmt, con=engine.connect())
        terms = terms.set_index('tid')
        df = pd.merge(df, terms, left_on=column, right_index=True)
        s = column.replace('_tid', '_name')
        df = df.rename(dict(name=s), axis=1)

    dfs.append(df)

df = pd.concat(dfs, axis=1).sort_index()

sname = 'field_data_field_sllog_campaign'
table = metadata.tables[sname]
stmt = select(table.c.entity_id, table.c.field_sllog_campaign_value)
slog = pd.read_sql(stmt, con=engine.connect())
slog = slog.set_index('entity_id')
df = pd.merge(df, slog, left_on='field_shot_sessionlog_target_id', right_index=True)

df.sample(50)
# Out:
#           field_shot_physics_div_config_value  \
# entity_id
# 30991                            Conventional
# 40738                                     NaN
# 33080                            Conventional
# 27612                            Conventional
# 22135                            Conventional
# 36860                            Conventional
# 48759                                     NaN
# 33742                            Conventional
# 41576                                     NaN
# 33610                            Conventional
# 47888                                     NaN
# 30921                            Conventional
# 27325                            Conventional
# 30849                            Conventional
# 48165                                     NaN
# 37266                            Conventional
# 29178                            Conventional
# 38228                            Conventional
# 21577                            Conventional
# 28719                            Conventional
# 22740                            Conventional
# 52611                                     NaN
# 44468                                     NaN
# 28394                            Conventional
# 32239                            Conventional
# 48664                                     NaN
# 35099                            Conventional
# 24331                            Conventional
# 49445                            Conventional
# 23796                            Conventional
# 24196                            Conventional
# 34471                            Conventional
# 21791                            Conventional
# 39403                                     NaN
# 34781                            Conventional
# 21331                            Conventional
# 24269                            Conventional
# 34754                            Conventional
# 49361                            Conventional
# 34540                            Conventional
# 44079                                     NaN
# 40008                                     NaN
# 27420                            Conventional
# 29766                            Conventional
# 36156                            Conventional
# 36463                            Conventional
# 30440                            Conventional
# 25015                            Conventional
# 44885                                     NaN
# 25440                            Conventional
#
#           field_shot_physics_heating_value field_shot_physics_ip_range_value  \
# entity_id
# 30991                                  NaN                               NaN
# 40738                                  NaN                               NaN
# 33080                                  NaN                               NaN
# 27612                                  NaN                               NaN
# 22135                                  NaN                               NaN
# 36860              2 Beams,SS Beam,SW Beam                            700 kA
# 48759                                  NaN                               NaN
# 33742                                  NaN                               NaN
# 41576                                  NaN                               NaN
# 33610                                  NaN                               NaN
# 47888                                  NaN                               NaN
# 30921                                  NaN                               NaN
# 27325                                  NaN                               NaN
# 30849                                  NaN                               NaN
# 48165                                  NaN                               NaN
# 37266                                Ohmic                               NaN
# 29178                                  NaN                               NaN
# 38228                              SW Beam                            700 kA
# 21577                                  NaN                               NaN
# 28719                                  NaN                               NaN
# 22740                                  NaN                               NaN
# 52611                                  NaN                               NaN
# 44468                                  NaN                               NaN
# 28394                                  NaN                               NaN
# 32239                                  NaN                               NaN
# 48664                                  NaN                               NaN
# 35099                              SS Beam                            700 kA
# 24331                                  NaN                               NaN
# 49445                               1 Beam                            700 kA
# 23796                                  NaN                               NaN
# 24196                                  NaN                               NaN
# 34471                                Ohmic                               NaN
# 21791                                  NaN                               NaN
# 39403                                  NaN                               NaN
# 34781                                Ohmic                               NaN
# 21331                                  NaN                               NaN
# 24269                                  NaN                               NaN
# 34754                                Ohmic                            400 kA
# 49361                               1 Beam                            700 kA
# 34540                                Ohmic                            700 kA
# 44079                                  NaN                               NaN
# 40008                                  NaN                               NaN
# 27420                                  NaN                               NaN
# 29766                                  NaN                               NaN
# 36156                              SS Beam                            700 kA
# 36463                              SW Beam                            400 kA
# 30440                                  NaN                               NaN
# 25015                                  NaN                               NaN
# 44885                                  NaN                               NaN
# 25440                                  NaN                               NaN
#
#           field_shot_physics_shape_value  field_shot_phys_pellets_tid  \
# entity_id
# 30991                                NaN                        884.0
# 40738                                NaN                        884.0
# 33080                                NaN                        884.0
# 27612                                NaN                        884.0
# 22135                                NaN                        884.0
# 36860                                NaN                        884.0
# 48759                                NaN                        884.0
# 33742                                NaN                        884.0
# 41576                                NaN                        884.0
# 33610                                NaN                        884.0
# 47888                                NaN                        884.0
# 30921                                NaN                        884.0
# 27325                                NaN                        884.0
# 30849                                NaN                        884.0
# 48165                                NaN                        884.0
# 37266              Connected Double Null                        884.0
# 29178                                NaN                        884.0
# 38228                  Lower Single Null                        884.0
# 21577                                NaN                        884.0
# 28719                                NaN                        884.0
# 22740                                NaN                        884.0
# 52611                                NaN                        884.0
# 44468                                NaN                        884.0
# 28394                                NaN                        884.0
# 32239                                NaN                        884.0
# 48664                                NaN                        884.0
# 35099              Connected Double Null                        884.0
# 24331                                NaN                        884.0
# 49445              Connected Double Null                        884.0
# 23796                                NaN                        884.0
# 24196                                NaN                        884.0
# 34471              Connected Double Null                        884.0
# 21791                                NaN                        884.0
# 39403                                NaN                        884.0
# 34781              Connected Double Null                        884.0
# 21331                                NaN                        884.0
# 24269                                NaN                        884.0
# 34754                  Lower Single Null                        884.0
# 49361              Connected Double Null                        884.0
# 34540              Connected Double Null                        884.0
# 44079                                NaN                        884.0
# 40008                                NaN                        884.0
# 27420                                NaN                        884.0
# 29766                                NaN                        884.0
# 36156                                NaN                        884.0
# 36463                                NaN                        884.0
# 30440                                NaN                        884.0
# 25015                                NaN                        884.0
# 44885                                NaN                        884.0
# 25440                                NaN                        884.0
#
#           field_shot_phys_pellets_name  field_shot_phys_rmp_coils_tid  \
# entity_id
# 30991                               No                            NaN
# 40738                               No                          888.0
# 33080                               No                            NaN
# 27612                               No                            NaN
# 22135                               No                            NaN
# 36860                               No                            NaN
# 48759                               No                          888.0
# 33742                               No                            NaN
# 41576                               No                          888.0
# 33610                               No                            NaN
# 47888                               No                          888.0
# 30921                               No                            NaN
# 27325                               No                            NaN
# 30849                               No                            NaN
# 48165                               No                          888.0
# 37266                               No                          888.0
# 29178                               No                            NaN
# 38228                               No                          911.0
# 21577                               No                            NaN
# 28719                               No                            NaN
# 22740                               No                            NaN
# 52611                               No                          888.0
# 44468                               No                          888.0
# 28394                               No                            NaN
# 32239                               No                            NaN
# 48664                               No                          888.0
# 35099                               No                          905.0
# 24331                               No                            NaN
# 49445                               No                          888.0
# 23796                               No                            NaN
# 24196                               No                            NaN
# 34471                               No                          888.0
# 21791                               No                            NaN
# 39403                               No                          888.0
# 34781                               No                          888.0
# 21331                               No                            NaN
# 24269                               No                            NaN
# 34754                               No                          888.0
# 49361                               No                          888.0
# 34540                               No                          901.0
# 44079                               No                          888.0
# 40008                               No                          888.0
# 27420                               No                            NaN
# 29766                               No                            NaN
# 36156                               No                            NaN
# 36463                               No                            NaN
# 30440                               No                            NaN
# 25015                               No                            NaN
# 44885                               No                          888.0
# 25440                               No                            NaN
#
#           field_shot_phys_rmp_coils_name  \
# entity_id
# 30991                                NaN
# 40738                                 No
# 33080                                NaN
# 27612                                NaN
# 22135                                NaN
# 36860                                NaN
# 48759                                 No
# 33742                                NaN
# 41576                                 No
# 33610                                NaN
# 47888                                 No
# 30921                                NaN
# 27325                                NaN
# 30849                                NaN
# 48165                                 No
# 37266                                 No
# 29178                                NaN
# 38228                                 26
# 21577                                NaN
# 28719                                NaN
# 22740                                NaN
# 52611                                 No
# 44468                                 No
# 28394                                NaN
# 32239                                NaN
# 48664                                 No
# 35099                                 24
# 24331                                NaN
# 49445                                 No
# 23796                                NaN
# 24196                                NaN
# 34471                                 No
# 21791                                NaN
# 39403                                 No
# 34781                                 No
# 21331                                NaN
# 24269                                NaN
# 34754                                 No
# 49361                                 No
# 34540                                  7
# 44079                                 No
# 40008                                 No
# 27420                                NaN
# 29766                                NaN
# 36156                                NaN
# 36463                                NaN
# 30440                                NaN
# 25015                                NaN
# 44885                                 No
# 25440                                NaN
#
#                                     field_shot_preshot_value  \
# entity_id
# 30991      \nRepeat 22026 after adding D to the impurity ...
# 40738      [TF] Run 12 kA pulse to create a reference for...
# 33080      \nReload shot 20691. Disabled FA3 and FA4 and ...
# 27612                                   \nRepeat - SW only\n
# 22135      \nprolonged G1-4 puff by 2ms, remove spike fro...
# 36860      \nrepeat with two beams for new neutron camera...
# 48759      [TF]. Restore 44483. TF 65kA Test Shot. Disabl...
# 33742              \nPF retest with only P2 and P3 left on\n
# 41576                        [TF]. Restore amd repeat 41446.
# 33610      \nFinal current dropped to 400 kA. Same decay ...
# 47888      [750 kA} Reduce P4 by 200 As at 100 ms - set Z...
# 30921                                       \nTF test shot\n
# 27325                                            \nPF test\n
# 30849                                       \nAdd SS beam.\n
# 48165                                                 Retry.
# 37266      \nRepeat PF test shot. Disable piezo valves. E...
# 29178                         \nRaman/Rayleigh at 108mbar \n
# 38228      \nRepeat with coils added.\nRestore staircase ...
# 21577                                              \nRETRY\n
# 28719                                       \nrepeat at 4V\n
# 22740      \nreload 12528 - reduce Ip ramp - flat top now...
# 52611      Restore 46029 - reduce magnitude of vertical f...
# 44468      [P6] Further reduce overshoot: remove all poin...
# 28394                                \nRepeat after abort.\n
# 32239                                              \nretry\n
# 48664      Repeat 44455. TF test shot for PCS, switch to ...
# 35099         \nRepeat, with CP3s voltage reduced to 2900.\n
# 24331                \nRepeat increase PCS-P1 limit+/-54kA\n
# 49445      Restore "mast_sl_44738_gas_scan". Based on 447...
# 23796                        \nTF test\n Reference => 10084.
# 24196          \nrepeat with RP forward to the plasma now.\n
# 34471                                       \nTF test shot\n
# 21791      \nTURN RADIAL FDBACK OFF, CPLG COEF CHANGED FR...
# 39403                    MFPS ELD - Repeat of previous shot.
# 34781                              \nRestore PF test shot.\n
# 21331      \nTF SHOT -SET TS VALUE TO 0.05 AND DURATION T...
# 24269      \nRestore 15008 (pre waterleak shot) as a base...
# 34754      \nChange Ip to ramp up to 450kA at 84ms (TF=0....
# 49361      [MU09-FPP-01] Restore 44751 and adjust South b...
# 34540               \nload 25949 (std shot with elm coils)\n
# 44079           [Px]. Restore 42598 (=42179) 2kA for 0.75s.
# 40008      MFPS. Repeat 40630 with time constant reduced ...
# 27420                      \nreduce gas influx to 8e21(25)\n
# 29766                                \nCombine P4 5 and TF\n
# 36156      \ndivertor detachment program: repeat with lon...
# 36463       \nRepeat - adding 1.4 kA from the upper coils \n
# 30440      \nRepeat with vertical control restored from s...
# 25015                                    \nStandard plasma\n
# 44885      [Magnetics] D5 shot 1500 ms flattop at 3.4kA. ...
# 25440                           \nRepeat with ATS at 0.33s\n
#
#                                    field_shot_postshot_value  \
# entity_id
# 30991            \nNo conclusive sign of Ne in the vessel.\n
# 40738      Pulse ran successfully to provide a reference ...
# 33080                              \nNo H-mode. Good beam.\n
# 27612                                    \nBetter SW beam.\n
# 22135                                                   \n\n
# 36860                                          \nbeam late\n
# 48759      Sparking recorded on camera and Rogowskii coil...
# 33742           \nCCBV24-28 still awry after software work\n
# 41576                                   Good match to 41446.
# 33610      \nNo SS beam again. Some suspicion that a prob...
# 47888      Good beams - Ip set has gone back to 450 and D...
# 30921                                                 \nOK\n
# 27325                                      \nruncheck okay\n
# 30849                        \nMultiple breakdowns on SS. \n
# 48165      Full length beam, disrupted at 0.340, probably...
# 37266                                                   \n\n
# 29178                             \nRaman/Rayleigh data OK\n
# 38228      \nAll ELM coils fired.\nNo effect seen on EM f...
# 21577      \nBINGO, EFPS, MFPS AND SFPS ALL OPERATED. DON...
# 28719                                          \nP=1.22e-4\n
# 22740      \n450 ms shot  - survives large event at 300 m...
# 52611      No current driven in coils for this shot. Gas ...
# 44468                   RFPS trip: rectifier trip this time.
# 28394       \nGood NBI, short shot. Vertical control lost.\n
# 32239      \ngood beam . IRE at 0.250 again. We have SPEX...
# 48664              Good match to reference, ran as expected.
# 35099                  \nBrief H-mode only. Needs 2 beams.\n
# 24331                                           \nSimiliar\n
# 49445      A lot of breakdowns in South NBI until around ...
# 23796                                               \nOkay\n
# 24196          \ngood shot. weak interaction plasma/probe.\n
# 34471                                            \nRan OK.\n
# 21791                              \nDROPS OUT OF FEEDBACK\n
# 39403                                MFPS - ELD did not trip
# 34781      \nRuncheck reports AMB_OBR10 faulty. Not on cr...
# 21331      \nSHOT ABORTED - TOROIDAL DEVICE FAILURE / AC ...
# 24269      \ngood repeat of global performance, small dif...
# 34754      \nSuccessful 250ms plasma shot. q95~5 at DMV t...
# 49361      Beam start at 100 ms, duration 300 ms. Disrupt...
# 34540      \nTriggered locked mode at about 230 ms. Compa...
# 44079                                              LVPS Trip
# 40008                                             Good shot.
# 27420      \nslightly better but not good - disruption re...
# 29766                                  \nabort by operator\n
# 36156                         \nMARFE starting from ~100ms\n
# 36463      \nNo SS beam due to NGV - a similar coil off s...
# 30440      \nGood shot. No massive gas injection at the e...
# 25015                      \nShort shot 300ms, large snake\n
# 44885                             Successful pulse no trips.
# 25440      \ngood beam performance again, ATS again just ...
#
#           field_shot_owner_value  field_shot_reference_target_id  \
# entity_id
# 30991                        NaN                         30987.0
# 40738                        NaN                             NaN
# 33080                        NaN                         29672.0
# 27612                        NaN                         27294.0
# 22135                        NaN                         22134.0
# 36860                        NaN                         36852.0
# 48759                   Internal                         48712.0
# 33742                        NaN                         33490.0
# 41576                        NaN                             NaN
# 33610                        NaN                         33609.0
# 47888                   Internal                             NaN
# 30921                        NaN                         27565.0
# 27325                        NaN                         26347.0
# 30849                        NaN                         30848.0
# 48165                   Internal                             NaN
# 37266                        NaN                         37265.0
# 29178                        NaN                         29154.0
# 38228                        NaN                         38117.0
# 21577                        NaN                             NaN
# 28719                        NaN                         28718.0
# 22740                        NaN                         21511.0
# 52611                   Internal                         52607.0
# 44468                        NaN                         44466.0
# 28394                        NaN                         28377.0
# 32239                        NaN                         32238.0
# 48664                   Internal                         48645.0
# 35099                        NaN                         35098.0
# 24331                        NaN                         24330.0
# 49445                   Internal                         49330.0
# 23796                        NaN                             NaN
# 24196                        NaN                         24152.0
# 34471                        NaN                         33489.0
# 21791                        NaN                             NaN
# 39403                        NaN                             NaN
# 34781                        NaN                         34455.0
# 21331                        NaN                             NaN
# 24269                        NaN                         23991.0
# 34754                        NaN                         34751.0
# 49361                 Eurofusion                         49359.0
# 34540                        NaN                         34526.0
# 44079                        NaN                             NaN
# 40008                        NaN                             NaN
# 27420                        NaN                         27419.0
# 29766                        NaN                         26347.0
# 36156                        NaN                         35965.0
# 36463                        NaN                         36456.0
# 30440                        NaN                             NaN
# 25015                        NaN                         24807.0
# 44885                        NaN                             NaN
# 25440                        NaN                         25254.0
#
#            field_shot_scenario_tid field_shot_scenario_name  \
# entity_id
# 30991                          NaN                      NaN
# 40738                          NaN                      NaN
# 33080                          NaN                      NaN
# 27612                          NaN                      NaN
# 22135                          NaN                      NaN
# 36860                          NaN                      NaN
# 48759                          NaN                      NaN
# 33742                          NaN                      NaN
# 41576                          NaN                      NaN
# 33610                          NaN                      NaN
# 47888                          NaN                      NaN
# 30921                          NaN                      NaN
# 27325                          NaN                      NaN
# 30849                          NaN                      NaN
# 48165                       1632.0           DN-750-CD-1BSW
# 37266                          NaN                      NaN
# 29178                          NaN                      NaN
# 38228                        922.0                       S3
# 21577                          NaN                      NaN
# 28719                          NaN                      NaN
# 22740                          NaN                      NaN
# 52611                       1664.0           LIM-750-LIM-OH
# 44468                          NaN                      NaN
# 28394                          NaN                      NaN
# 32239                          NaN                      NaN
# 48664                          NaN                      NaN
# 35099                        923.0                       S4
# 24331                          NaN                      NaN
# 49445                       1613.0           DN-750-CD-1BSS
# 23796                          NaN                      NaN
# 24196                          NaN                      NaN
# 34471                          NaN                      NaN
# 21791                          NaN                      NaN
# 39403                          NaN                      NaN
# 34781                          NaN                      NaN
# 21331                          NaN                      NaN
# 24269                          NaN                      NaN
# 34754                        927.0                       S8
# 49361                       1613.0           DN-750-CD-1BSS
# 34540                        924.0                       S5
# 44079                          NaN                      NaN
# 40008                          NaN                      NaN
# 27420                          NaN                      NaN
# 29766                          NaN                      NaN
# 36156                        925.0                       S6
# 36463                        925.0                       S6
# 30440                          NaN                      NaN
# 25015                          NaN                      NaN
# 44885                          NaN                      NaN
# 25440                          NaN                      NaN
#
#           field_shot_datetime_value  field_shot_sessionlog_target_id  \
# entity_id
# 30991           2009-04-23 12:50:00                            20160
# 40738           2020-09-09 14:02:16                            40718
# 33080           2010-01-22 10:22:00                            20289
# 27612           2007-06-29 10:35:00                            19955
# 22135           2005-06-07 14:03:00                            19615
# 36860           2012-01-25 17:44:00                            20550
# 48759           2021-07-20 15:18:30                            48754
# 33742           2010-03-16 10:20:00                            20327
# 41576           2020-10-05 12:53:17                            41559
# 33610           2010-03-04 13:17:00                            20319
# 47888           2021-06-02 17:40:41                            47849
# 30921           2009-04-21 09:38:00                            20158
# 27325           2007-06-07 08:24:00                            19935
# 30849           2009-04-14 17:55:00                            20153
# 48165           2021-06-18 14:04:42                            48141
# 37266           2013-05-03 14:41:00                            20592
# 29178           2008-09-04 13:44:00                            20055
# 38228           2013-08-06 12:37:00                            20645
# 21577           2005-04-22 14:09:00                            19585
# 28719           2008-07-11 10:49:00                            20026
# 22740           2005-08-16 09:30:00                            19651
# 52611           2022-10-13 14:32:50                            52577
# 44468           2020-12-23 12:37:59                            44450
# 28394           2008-05-15 11:29:00                            20008
# 32239           2009-10-02 10:28:00                            20236
# 48664           2021-07-09 16:14:47                            48643
# 35099           2011-07-08 12:34:00                            20406
# 24331           2006-05-16 16:24:00                            19742
# 49445           2021-08-24 13:42:36                            49412
# 23796           2006-02-07 09:52:00                            19712
# 24196           2006-05-04 12:34:00                            19733
# 34471           2011-05-06 10:08:00                            20371
# 21791           2005-05-10 10:35:00                            19597
# 39403           2019-10-23 14:07:49                            39400
# 34781           2011-06-01 13:20:00                            20392
# 21331           2005-03-10 11:55:00                            19573
# 24269           2006-05-10 14:40:00                            19737
# 34754           2011-05-26 14:23:00                            20390
# 49361           2021-08-19 15:29:30                            49321
# 34540           2011-05-11 09:36:00                            20374
# 44079           2020-12-16 08:38:38                            44074
# 40008           2020-07-29 16:14:03                            39984
# 27420           2007-06-14 12:05:00                            19941
# 29766           2008-10-30 17:23:00                            20090
# 36156           2011-11-17 14:05:00                            20485
# 36463           2011-12-14 10:31:00                            20513
# 30440           2009-02-26 11:24:00                            20129
# 25015           2006-08-01 09:41:00                            19794
# 44885           2021-01-18 08:53:33                            44882
# 25440           2006-09-06 16:24:00                            19826
#
#           field_sllog_campaign_value
# entity_id
# 30991                             M7
# 40738                            MU1
# 33080                             M7
# 27612                             M6
# 22135                             M5
# 36860                             M8
# 48759                            MU1
# 33742                             M7
# 41576                            MU1
# 33610                             M7
# 47888                            MU1
# 30921                             M7
# 27325                             M6
# 30849                             M7
# 48165                            MU1
# 37266                             M9
# 29178                             M7
# 38228                             M9
# 21577                             M5
# 28719                             M7
# 22740                             M5
# 52611                            MU1
# 44468                            MU1
# 28394                             M7
# 32239                             M7
# 48664                            MU1
# 35099                             M8
# 24331                             M6
# 49445                            MU1
# 23796                             M6
# 24196                             M6
# 34471                             M8
# 21791                             M5
# 39403                            MU1
# 34781                             M8
# 21331                             M5
# 24269                             M6
# 34754                             M8
# 49361                            MU1
# 34540                             M8
# 44079                            MU1
# 40008                            MU1
# 27420                             M6
# 29766                             M7
# 36156                             M8
# 36463                             M8
# 30440                             M7
# 25015                             M6
# 44885                            MU1
# 25440                             M6

# %%
name =  'node'
table = metadata.tables[name]
stmt = select(table)
pd.set_option('display.max_columns', None)
df_node = pd.read_sql(stmt, con=engine.connect())
df_node = df_node.set_index('nid')
df_node = df_node.loc[df_node.type == 'mast_shot']

df_shot = df_node.join(df)

# Drop uninteresting columns
df_shot = df_shot.drop(['vid', 'type', 'language', 'uid', 'comment', 
              'promote', 'sticky', 'translate', 'tnid', 'status', 
              'created', 'changed'], axis=1)


# Rename types
df_shot = df_shot.rename({key: key.replace('field_shot_', '').replace('_value', '').replace('_name', '')
                          for key in df_shot.columns}, axis=1)
df_shot = df_shot.rename(dict(title='shot_id', reference_target_id='reference_id', 
                              owner='comissioner', field_sllog_campaign='campaign'), axis=1)

# Tidy up types
df_shot['shot_id'] = df_shot['shot_id'].astype(int)
df_shot['reference_id'] = df_shot['reference_id'].astype('Int64')
df_shot['datetime'] = pd.to_datetime(df_shot.datetime)

id_columns = [
    'sessionlog_target_id',
    'scenario_tid',
    'phys_rmp_coils_tid',
    'phys_pellets_tid',
]
df_shot = df_shot.drop(id_columns, axis=1)

# Get reference shot ID
ref_index = df_shot['reference_id'].dropna().index
ref_ids = df_shot['reference_id'].dropna().values
ref_shot_ids = df_shot['shot_id'].loc[ref_ids].values
df_shot.loc[ref_index, 'reference_shot_id'] = ref_shot_ids
df_shot['reference_shot_id'] = df_shot['reference_shot_id'].astype('Int64')


scenarios = pd.DataFrame(dict(scenario=df_shot.scenario.unique())).reset_index()
scenarios = scenarios.drop(0)
scenarios  =scenarios.rename(dict(index='scenario_id'), axis=1)
df_shot = pd.merge(df_shot, scenarios, left_on='scenario', right_on='scenario', how='outer')

def null_bool(item):
    if item is np.nan:
        return None
    else:
        return item != 'No'

def comissioner_normalize(item):
    if item == 'Internal':
        return 'UKAEA'
    elif item == 'Eurofusion':
        return 'EuroFusion'

df_shot['phys_rmp_coils'] = df_shot['phys_rmp_coils'].map(null_bool)
df_shot['phys_pellets'] = df_shot['phys_pellets'].map(null_bool)

df_shot['comissioner'] = df_shot['comissioner'].map(comissioner_normalize)

df_shot = df_shot.rename(dict(
    reference_shot_id='reference_shot',
    physics_ip_range='current_range',
    physics_div_config='divertor_config',
    physics_heating='heating',
    physics_shape='plasma_shape',
    preshot='preshot_description',
    postshot='postshot_description',
    phys_pellets='pellets',
    phys_rmp_coils='rmp_coil',
    datetime='timestamp'
), axis=1)

df_shot = df_shot.sort_values('shot_id')
df_shot.sample(10)
# Out:
#        shot_id divertor_config                  heating current_range  \
# 9366     21063    Conventional                      NaN           NaN
# 14850    28968    Conventional                    Ohmic           NaN
# 3040     14735    Conventional                      NaN           NaN
# 4744     16441    Conventional                      NaN           NaN
# 3043     14738    Conventional                      NaN           NaN
# 21217    29957    Conventional  2 Beams,SS Beam,SW Beam        400 kA
# 18049    42874             NaN                      NaN           NaN
# 2149     13844    Conventional                      NaN           NaN
# 16056    40881             NaN                      NaN           NaN
# 7178     18875    Conventional                      NaN           NaN
#
#       plasma_shape pellets rmp_coil  \
# 9366           NaN   False     None
# 14850          NaN   False     None
# 3040           NaN   False     None
# 4744           NaN   False     None
# 3043           NaN   False     None
# 21217          NaN    True     None
# 18049          NaN   False    False
# 2149           NaN   False     None
# 16056          NaN   False    False
# 7178           NaN   False     None
#
#                                      preshot_description  \
# 9366   \nRestore 21061, but run with Ar puff prolonge...
# 14850                                         \nrepeat\n
# 3040                                  \n0.5T test shot\n
# 4744                             \nStandard ohmic shot\n
# 3043                                  \n0.5T test shot\n
# 21217  \nRestore 29953. Include pellets.  Change TS t...
# 18049       [Vacuum] reload 42850 - deselect gas valvle
# 2149                \nTf test shot\n Reference => 10084.
# 16056              [D3] Try repeating pulse 40879 on D3.
# 7178   \nStarting high betaT program. Restore 18578 w...
#
#                                     postshot_description comissioner  \
# 9366   \nBeams from 0.05s good, but VDE at 0.244s due...        None
# 14850  \nSeemed to stop charging at about 3800, then ...        None
# 3040                                              \nOK\n        None
# 4744                                            \nOkay\n        None
# 3043                                              \nOK\n        None
# 21217                      \nOne breakdown on SW beam.\n        None
# 18049  LVPS mod bus alarm - LVPS tripped so shot term...        None
# 2149                                              \nok\n        None
# 16056                           Pulse ran successfully.         None
# 7178                           \nvery similar to 18578\n        None
#
#        reference_id scenario           timestamp campaign  reference_shot  \
# 9366          30042      NaN 2008-12-10 16:52:00       M7           21061
# 14850         37543      NaN 2013-06-10 10:43:00       M9           28967
# 3040          23716      NaN 2006-01-26 09:28:00       M6           14733
# 4744          25048      NaN 2006-09-06 09:02:00       M6           16065
# 3043          23720      NaN 2006-01-26 10:52:00       M6           14737
# 21217         38529       S8 2013-08-21 15:44:00       M9           29953
# 18049          <NA>      NaN 2021-01-13 20:01:33      MU1            <NA>
# 2149           <NA>      NaN 2005-09-07 10:58:00       M5            <NA>
# 16056          <NA>      NaN 2020-08-18 10:42:02      MU1            <NA>
# 7178          27559      NaN 2007-07-17 17:36:00       M6           18578
#
#        scenario_id
# 9366           NaN
# 14850          NaN
# 3040           NaN
# 4744           NaN
# 3043           NaN
# 21217          2.0
# 18049          NaN
# 2149           NaN
# 16056          NaN
# 7178           NaN

# %%
df_shot.to_parquet('../data/shot_metadata.parquet')

# %%
df_shot['divertor_config'].unique()
# Out:
# array(['Conventional', nan, 'Super-X', 'X Divertor', 'Snowflake',
#        'Limiter'], dtype=object)

# %%
name = 'taxonomy_term_data'
# name = 'field_data_field_sllog_campaign'
# name = 'field_data_field_shot_sessionlog'
table = metadata.tables[name]
stmt = select(table)
# stmt = select(table.c.entity_id, table.columns[f'field_{name}_target_id'])
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)
df = pd.read_sql(stmt, con=engine.connect())
# df = df.set_index('entity_id')
df
# Out:
#        tid  vid                         name  \
# 0      315    5                          NBI
# 1      316    5  Plasma Control System (PCS)
# 2      317    5                        DATAC
# 3      318    5               Power Supplies
# 4      319    5                    Scheduler
# ...    ...  ...                          ...
# 1235  1867    4                     MU02-FPP
# 1236  1868    4                     MU02-MHD
# 1237  1869    4                     MU02-EXH
# 1238  1870    4                     MU02-FFP
# 1239  1871    4                 MU03-COMM-01
#
#                                         description   format  weight
# 0                                                    wysiwyg     112
# 1                                                    wysiwyg       7
# 2                                                    wysiwyg       0
# 3                                                    wysiwyg     132
# 4                                                    wysiwyg       0
# ...                                             ...      ...     ...
# 1235                                                 wysiwyg       1
# 1236                                                 wysiwyg       5
# 1237                                                 wysiwyg       2
# 1238                                                 wysiwyg       0
# 1239  <p>Generic commissioning tag for MU03</p>\r\n  wysiwyg       0
#
# [1240 rows x 6 columns]
