# %% [markdown]
# # Quickstart
# This notebook shows some very simple example of getting started.
#
# First we need to install some dependancies into your conda or venv environment

# %%
# !pip install pandas matplotlib fsspec s3fs "zarr<3" pyarrow xarray
# Out:
# Requirement already satisfied: matplotlib in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (3.9.0)
# Requirement already satisfied: s3fs in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (2024.6.0)
# Requirement already satisfied: fsspec in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (2024.6.0)
# Requirement already satisfied: ipython in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (8.25.0)
# Requirement already satisfied: xarray in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (2024.5.0)
# Requirement already satisfied: dask in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (2024.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from s3fs) (2.13.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from s3fs) (3.9.5)
# Requirement already satisfied: decorator in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (2.18.0)
# Requirement already satisfied: stack-data in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: pandas>=2.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from xarray) (2.2.2)
# Requirement already satisfied: click>=8.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from dask) (3.0.0)
# Requirement already satisfied: partd>=1.2.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from dask) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from dask) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from dask) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from dask) (7.1.0)
# Requirement already satisfied: botocore<1.34.107,>=1.34.70 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.34.106)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.4)
# Requirement already satisfied: zipp>=0.5 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask) (3.19.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from pandas>=2.0->xarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from pandas>=2.0->xarray) (2024.1)
# Requirement already satisfied: locket in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from partd>=1.2.0->dask) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: six>=1.5 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from stack-data->ipython) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from stack-data->ipython) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.1)
# Requirement already satisfied: idna>=2.0 in /Users/rt2549/miniconda3/envs/mast-book/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)

# %%
import pandas as pd
URL = 'https://mastapp.site'

# %% [markdown]
# #### List All Shots

# %%
shots_df = pd.read_parquet(f'{URL}/parquet/level2/shots')
shots_df
# Out:
#                                                  context  \
# 0      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 1      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 2      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 3      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 4      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# ...                                                  ...
# 14152  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 14153  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 14154  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 14155  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 14156  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
#
#                                                url  \
# 0                s3://mast/level2/shots/11766.zarr
# 1                s3://mast/level2/shots/11767.zarr
# 2                s3://mast/level2/shots/11768.zarr
# 3                s3://mast/level2/shots/11769.zarr
# 4                s3://mast/level2/shots/11771.zarr
# ...                                            ...
# 14152  s3://fairmast/mastu/level2/shots/47201.zarr
# 14153  s3://fairmast/mastu/level2/shots/47202.zarr
# 14154  s3://fairmast/mastu/level2/shots/47203.zarr
# 14155  s3://fairmast/mastu/level2/shots/47204.zarr
# 14156  s3://fairmast/mastu/level2/shots/47206.zarr
#
#                                      preshot_description  \
# 0      \nRELOAD 10232 PLASMA CONDITIONING SHOT FROM M4\n
# 1                                             \nREPEAT\n
# 2      \nSELECT ALL 4 FAS AND LOAD EFC SETTINGS FROM ...
# 3                    \nREPEAT, WITH TF RAISED TO 0.58.\n
# 4      \nRELOADED 11769 AND SET UP PLASMA CURRENT FEE...
# ...                                                  ...
# 14152  restore 45847 (type 5 commissioning) P4,5 only...
# 14153                                              retry
# 14154  Restore prepared setup all-coil-first-shot. Ex...
# 14155  Repeat daily test shot with PS enable windows ...
# 14156                                              retry
#
#                                     postshot_description campaign  \
# 0      \nGOOD PLASMA, RAN FINE. SL JOINT ALARMS RATHE...       M5
# 1      \nOK BUT LOST VERTICAL CONTROL - FA2 JUST DIED...       M5
# 2                            \nOK. GOT FA4 BUT NOT FA3\n       M5
# 3       \nSLIDING JOINT ALARMS A BIT LOWER. PLASMA OK.\n       M5
# 4      \nGOOD PLASMA F/B CONTROL. SLIDING JOINT ALARM...       M5
# ...                                                  ...      ...
# 14152  Unexpected HW protection fault. ST01 and ST02 ...      MU3
# 14153     Ran OK, no trips, all PF currents as demanded.      MU3
# 14154  Looks OK, I don't have a code to test the magn...      MU3
# 14155  Error in channels 11 and 12 on bolometer. Wave...      MU3
# 14156  rtp stops st07 and st25, plus event 40 and 50 ...      MU3
#
#       current_range divertor_config plasma_shape commissioner facility  ...  \
# 0              None    Conventional         None         None     MAST  ...
# 1              None    Conventional         None         None     MAST  ...
# 2              None    Conventional         None         None     MAST  ...
# 3              None    Conventional         None         None     MAST  ...
# 4              None    Conventional         None         None     MAST  ...
# ...             ...             ...          ...          ...      ...  ...
# 14152          None            None         None        UKAEA   MAST-U  ...
# 14153          None            None         None        UKAEA   MAST-U  ...
# 14154          None            None         None        UKAEA   MAST-U  ...
# 14155          None            None         None        UKAEA   MAST-U  ...
# 14156          None            None         None        UKAEA   MAST-U  ...
#
#       cpf_vol_ipmax cpf_vol_max  cpf_vol_truby cpf_wmhd_ipmax cpf_wmhd_max  \
# 0          8.088068    8.478948            NaN    9286.269388    14370.632
# 1          7.707199    8.559942            NaN    7343.788162    11461.490
# 2          8.300782    8.580827            NaN   10585.928086    12660.081
# 3          8.112973    8.742647            NaN    8189.273726    12494.456
# 4          7.978917    8.760519            NaN    8206.258460    12345.816
# ...             ...         ...            ...            ...          ...
# 14152           NaN         NaN            NaN            NaN          NaN
# 14153           NaN         NaN            NaN            NaN          NaN
# 14154           NaN         NaN            NaN            NaN          NaN
# 14155           NaN         NaN            NaN            NaN          NaN
# 14156           NaN         NaN            NaN            NaN          NaN
#
#       cpf_wmhd_truby  cpf_zeff_ipmax  cpf_zeff_max cpf_zeff_truby  \
# 0                NaN             NaN           NaN            NaN
# 1                NaN             NaN           NaN            NaN
# 2                NaN             NaN           NaN            NaN
# 3                NaN             NaN           NaN            NaN
# 4                NaN             NaN           NaN            NaN
# ...              ...             ...           ...            ...
# 14152            NaN             NaN           NaN            NaN
# 14153            NaN             NaN           NaN            NaN
# 14154            NaN             NaN           NaN            NaN
# 14155            NaN             NaN           NaN            NaN
# 14156            NaN             NaN           NaN            NaN
#
#       cpf_zmag_efit
# 0         -0.011828
# 1         -0.007570
# 2         -0.011107
# 3         -0.008156
# 4         -0.008726
# ...             ...
# 14152           NaN
# 14153           NaN
# 14154           NaN
# 14155           NaN
# 14156           NaN
#
# [14157 rows x 290 columns]

# %% [markdown]
# #### List All Sources

# %%
sources_df = pd.read_parquet(f"{URL}/parquet/level2/sources")
sources_df
# Out:
#                                                   context description  \
# 0       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 1       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 2       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 3       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 4       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# ...                                                   ...         ...
# 110291  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 110292  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 110293  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 110294  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 110295  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
#
#             quality          type           title  \
# 0       Not Checked  dcat:Dataset  Source Dataset
# 1       Not Checked  dcat:Dataset  Source Dataset
# 2       Not Checked  dcat:Dataset  Source Dataset
# 3       Not Checked  dcat:Dataset  Source Dataset
# 4       Not Checked  dcat:Dataset  Source Dataset
# ...             ...           ...             ...
# 110291  Not Checked  dcat:Dataset  Source Dataset
# 110292  Not Checked  dcat:Dataset  Source Dataset
# 110293  Not Checked  dcat:Dataset  Source Dataset
# 110294  Not Checked  dcat:Dataset  Source Dataset
# 110295  Not Checked  dcat:Dataset  Source Dataset
#
#                                         uuid                  name  \
# 0       0f3fbb3a-8915-593b-8a5e-bb2801bd5b6d           equilibrium
# 1       c97c0e5c-c26c-52af-9b37-f6660d08726d             magnetics
# 2       ba47b2a2-a6da-5d8e-b6c2-e093fbfc3553             pf_active
# 3       46662499-0e12-5e7a-a8b8-ec44cdfca24d        pulse_schedule
# 4       0b64b870-4f95-55e7-b8ed-fb56b93194a5  spectrometer_visible
# ...                                      ...                   ...
# 110291  1e9519cb-54ff-5d72-b67a-13429850b6b7               summary
# 110292  006ab513-6b8f-544d-af26-b04920cc3c4f               summary
# 110293  ec012e0a-7b2c-57c5-bb6d-03747a550506               summary
# 110294  7c02604a-4818-59ab-bc5a-6dcda21f5a5a               summary
# 110295  efa39990-4967-5c64-b776-b8f0417422e3               summary
#
#                                                 url  \
# 0                 s3://mast/level2/shots/11766.zarr
# 1                 s3://mast/level2/shots/11766.zarr
# 2                 s3://mast/level2/shots/11766.zarr
# 3                 s3://mast/level2/shots/11766.zarr
# 4                 s3://mast/level2/shots/11766.zarr
# ...                                             ...
# 110291  s3://fairmast/mastu/level2/shots/47201.zarr
# 110292  s3://fairmast/mastu/level2/shots/47202.zarr
# 110293  s3://fairmast/mastu/level2/shots/47203.zarr
# 110294  s3://fairmast/mastu/level2/shots/47204.zarr
# 110295  s3://fairmast/mastu/level2/shots/47206.zarr
#
#                           endpoint_url            imas  shot_id
# 0           https://s3.echo.stfc.ac.uk     equilibrium    11766
# 1           https://s3.echo.stfc.ac.uk       magnetics    11766
# 2           https://s3.echo.stfc.ac.uk       pf_active    11766
# 3           https://s3.echo.stfc.ac.uk  pulse_schedule    11766
# 4           https://s3.echo.stfc.ac.uk            None    11766
# ...                                ...             ...      ...
# 110291  http://mon3.cepheus.hpc.l:8000            None    47201
# 110292  http://mon3.cepheus.hpc.l:8000            None    47202
# 110293  http://mon3.cepheus.hpc.l:8000            None    47203
# 110294  http://mon3.cepheus.hpc.l:8000            None    47204
# 110295  http://mon3.cepheus.hpc.l:8000            None    47206
#
# [110296 rows x 11 columns]

# %% [markdown]
# #### List all signals Given a Shot Number

# %%
signals_df = pd.read_parquet(f"{URL}/parquet/level2/signals?shot_id=30421")
signals_df
# Out:
#                                               context       shape provenance  \
# 0   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...   [73, 160]       None
# 1   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...   [73, 160]       None
# 2   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# 3   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# 4   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# ..                                                ...         ...        ...
# 59  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  [146, 120]       None
# 60  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# 61  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  [146, 120]       None
# 62  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  [146, 120]       None
# 63  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
#
#    description            dimensions      quality          type  \
# 0               [time, major_radius]  Not Checked  dcat:Dataset
# 1               [time, major_radius]  Not Checked  dcat:Dataset
# 2                             [time]  Not Checked  dcat:Dataset
# 3                             [time]  Not Checked  dcat:Dataset
# 4                             [time]  Not Checked  dcat:Dataset
# ..         ...                   ...          ...           ...
# 59              [time, major_radius]  Not Checked  dcat:Dataset
# 60                            [time]  Not Checked  dcat:Dataset
# 61              [time, major_radius]  Not Checked  dcat:Dataset
# 62              [time, major_radius]  Not Checked  dcat:Dataset
# 63                            [time]  Not Checked  dcat:Dataset
#
#              title                                  uuid         name  \
# 0   Signal Dataset  75756c34-c5b1-5e75-a53e-82bd90635d75          t_i
# 1   Signal Dataset  dcb14130-bf6a-5cc3-90ff-3985dad388a7          v_i
# 2   Signal Dataset  eb848f08-2f4e-54a6-8bd5-98a98823aa2e  beta_normal
# 3   Signal Dataset  cb95202b-279e-524a-b6af-899729ca9298     beta_pol
# 4   Signal Dataset  fd1ec81b-5eb9-5a59-b507-8b2df648e0ad     beta_tor
# ..             ...                                   ...          ...
# 59  Signal Dataset  f0b586cd-11ea-5208-927b-4e4f057a6c44          n_e
# 60  Signal Dataset  097cfe72-4d53-5a04-a7dc-97b1898e6e98     n_e_core
# 61  Signal Dataset  23c0ad57-6ff8-5222-9a7a-c897b661b9ad          p_e
# 62  Signal Dataset  6e2f4faf-7eb6-5f9e-a8a3-f0869af4abbf          t_e
# 63  Signal Dataset  c83667d9-fd83-5808-90b9-bb6750e98b77     t_e_core
#
#     version  rank                                url  \
# 0         0     2  s3://mast/level2/shots/30421.zarr
# 1         0     2  s3://mast/level2/shots/30421.zarr
# 2         0     1  s3://mast/level2/shots/30421.zarr
# 3         0     1  s3://mast/level2/shots/30421.zarr
# 4         0     1  s3://mast/level2/shots/30421.zarr
# ..      ...   ...                                ...
# 59        0     2  s3://mast/level2/shots/30421.zarr
# 60        0     1  s3://mast/level2/shots/30421.zarr
# 61        0     2  s3://mast/level2/shots/30421.zarr
# 62        0     2  s3://mast/level2/shots/30421.zarr
# 63        0     1  s3://mast/level2/shots/30421.zarr
#
#                   endpoint_url              source       units  \
# 0   https://s3.echo.stfc.ac.uk     charge_exchange          eV
# 1   https://s3.echo.stfc.ac.uk     charge_exchange       m / s
# 2   https://s3.echo.stfc.ac.uk         equilibrium           T
# 3   https://s3.echo.stfc.ac.uk         equilibrium
# 4   https://s3.echo.stfc.ac.uk         equilibrium
# ..                         ...                 ...         ...
# 59  https://s3.echo.stfc.ac.uk  thomson_scattering  1 / m ** 3
# 60  https://s3.echo.stfc.ac.uk  thomson_scattering  1 / m ** 3
# 61  https://s3.echo.stfc.ac.uk  thomson_scattering       u * a
# 62  https://s3.echo.stfc.ac.uk  thomson_scattering          eV
# 63  https://s3.echo.stfc.ac.uk  thomson_scattering          eV
#
#                                                  imas  shot_id
# 0               charge_exchange.channel[:].ion[:].t_i    30421
# 1                                                None    30421
# 2   equilibrium.time_slice[:].global_quantities.be...    30421
# 3   equilibrium.time_slice[:].global_quantities.be...    30421
# 4   equilibrium.time_slice[:].global_quantities.be...    30421
# ..                                                ...      ...
# 59                  thomson_scattering.channel[:].n_e    30421
# 60                                               None    30421
# 61                                               None    30421
# 62                  thomson_scattering.channel[:].t_e    30421
# 63                                               None    30421
#
# [64 rows x 18 columns]

# %% [markdown]
# #### Open and plot shot data.
#
# Here we are visualising some plasma current data.

# %%
import s3fs
import zarr
import xarray as xr
import matplotlib.pyplot as plt

endpoint_url = 'https://s3.echo.stfc.ac.uk'
url = f's3://mast/level2/shots/30421.zarr'

fs = s3fs.S3FileSystem(anon=True, endpoint_url=endpoint_url)
store =zarr.storage.FSStore(fs=fs, url=url)
dataset = xr.open_zarr(store, group='summary')

dataset['ip'].plot()
