# %% [markdown]
# # Quickstart
# This notebook shows some very simple example of getting started.
#
# First we need to install some dependancies into your conda or venv environment

# %%
# !pip install pandas matplotlib fsspec s3fs "zarr<3" pyarrow xarray
# Out:
# Requirement already satisfied: pandas in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (3.10.1)
# Requirement already satisfied: fsspec in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (2025.3.2)
# Requirement already satisfied: s3fs in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (2025.3.2)
# Requirement already satisfied: zarr<3 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (2.18.7)
# Requirement already satisfied: pyarrow in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (20.0.0)
# Requirement already satisfied: xarray in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (2025.4.0)
# Requirement already satisfied: asciitree in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from zarr<3) (0.3.3)
# Requirement already satisfied: numpy>=1.24 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from zarr<3) (2.2.5)
# Requirement already satisfied: fasteners in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from zarr<3) (0.19)
# Requirement already satisfied: numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from zarr<3) (0.15.1)
# Requirement already satisfied: deprecated in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from numcodecs!=0.14.0,!=0.14.1,<0.16,>=0.10.0->zarr<3) (1.2.18)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from s3fs) (2.22.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from s3fs) (3.11.18)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Requirement already satisfied: botocore<1.37.4,>=1.37.2 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.37.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (6.4.3)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.20.0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from botocore<1.37.4,>=1.37.2->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.4.0)
# Requirement already satisfied: six>=1.5 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: idna>=2.0 in /Users/ds2718/ukaea/fair-mast/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.10)

# %%
import pandas as pd
URL = 'https://mastapp.site'

# %% [markdown]
# #### List All Shots

# %%
shots_df = pd.read_parquet(f'{URL}/parquet/level2/shots')
shots_df
# Out:
#                                                  context  \
# 0      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 1      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 2      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 3      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 4      {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# ...                                                  ...
# 11276  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 11277  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 11278  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 11279  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 11280  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
#
#                                      url  \
# 0      s3://mast/level2/shots/11766.zarr
# 1      s3://mast/level2/shots/11767.zarr
# 2      s3://mast/level2/shots/11768.zarr
# 3      s3://mast/level2/shots/11769.zarr
# 4      s3://mast/level2/shots/11771.zarr
# ...                                  ...
# 11276  s3://mast/level2/shots/30467.zarr
# 11277  s3://mast/level2/shots/30468.zarr
# 11278  s3://mast/level2/shots/30469.zarr
# 11279  s3://mast/level2/shots/30470.zarr
# 11280  s3://mast/level2/shots/30471.zarr
#
#                                      preshot_description  \
# 0      \nRELOAD 10232 PLASMA CONDITIONING SHOT FROM M4\n
# 1                                             \nREPEAT\n
# 2      \nSELECT ALL 4 FAS AND LOAD EFC SETTINGS FROM ...
# 3                    \nREPEAT, WITH TF RAISED TO 0.58.\n
# 4      \nRELOADED 11769 AND SET UP PLASMA CURRENT FEE...
# ...                                                  ...
# 11276  \nRepeat with new neutron camera position.\ncH...
# 11277  \nRepeat with new neutron camera position.\ncH...
# 11278  \nRepeat with increased beam power (74 kV)\ncH...
# 11279  \nRepeat last using hydrogen in outboard and c...
# 11280  \nThe last plasma:\nConvert to i/b Helios 1724...
#
#                                     postshot_description campaign  \
# 0      \nGOOD PLASMA, RAN FINE. SL JOINT ALARMS RATHE...       M5
# 1      \nOK BUT LOST VERTICAL CONTROL - FA2 JUST DIED...       M5
# 2                            \nOK. GOT FA4 BUT NOT FA3\n       M5
# 3       \nSLIDING JOINT ALARMS A BIT LOWER. PLASMA OK.\n       M5
# 4      \nGOOD PLASMA F/B CONTROL. SLIDING JOINT ALARM...       M5
# ...                                                  ...      ...
# 11276  \nTwo times lower DD neutron rate than referen...       M9
# 11277                       \nGood beam.\nGood repeat.\n       M9
# 11278                      \nGood shot. Modes present.\n       M9
# 11279                                     \nNo HF gas.\n       M9
# 11280                                     \nGood shot.\n       M9
#
#       current_range divertor_config           plasma_shape commissioner  \
# 0              None    Conventional                   None         None
# 1              None    Conventional                   None         None
# 2              None    Conventional                   None         None
# 3              None    Conventional                   None         None
# 4              None    Conventional                   None         None
# ...             ...             ...                    ...          ...
# 11276        700 kA    Conventional  Connected Double Null         None
# 11277        700 kA    Conventional      Lower Single Null         None
# 11278        700 kA    Conventional  Connected Double Null         None
# 11279        700 kA    Conventional                   None         None
# 11280        700 kA    Conventional      Lower Single Null         None
#
#       facility  ... cpf_vol_ipmax cpf_vol_max  cpf_vol_truby cpf_wmhd_ipmax  \
# 0         MAST  ...      8.088068    8.478948            NaN    9286.269388
# 1         MAST  ...      7.707199    8.559942            NaN    7343.788162
# 2         MAST  ...      8.300782    8.580827            NaN   10585.928086
# 3         MAST  ...      8.112973    8.742647            NaN    8189.273726
# 4         MAST  ...      7.978917    8.760519            NaN    8206.258460
# ...        ...  ...           ...         ...            ...            ...
# 11276     MAST  ...      9.029202    9.046394            NaN   49469.122469
# 11277     MAST  ...      9.102411    9.107017            NaN   48516.962675
# 11278     MAST  ...      8.988730    9.047923            NaN   47466.249616
# 11279     MAST  ...      9.687049   10.055509            NaN   17290.432865
# 11280     MAST  ...      8.817559    9.283702            NaN   38063.582380
#
#       cpf_wmhd_max cpf_wmhd_truby  cpf_zeff_ipmax  cpf_zeff_max  \
# 0        14370.632            NaN             NaN           NaN
# 1        11461.490            NaN             NaN           NaN
# 2        12660.081            NaN             NaN           NaN
# 3        12494.456            NaN             NaN           NaN
# 4        12345.816            NaN             NaN           NaN
# ...            ...            ...             ...           ...
# 11276    52653.445            NaN             NaN           NaN
# 11277    49382.133            NaN             NaN           NaN
# 11278    49115.805            NaN             NaN           NaN
# 11279    22310.516            NaN             NaN           NaN
# 11280    40906.090            NaN             NaN           NaN
#
#       cpf_zeff_truby cpf_zmag_efit
# 0                NaN     -0.011828
# 1                NaN     -0.007570
# 2                NaN     -0.011107
# 3                NaN     -0.008156
# 4                NaN     -0.008726
# ...              ...           ...
# 11276            NaN      0.013202
# 11277            NaN      0.012445
# 11278            NaN      0.015299
# 11279            NaN      0.015164
# 11280            NaN      0.014340
#
# [11281 rows x 290 columns]

# %% [markdown]
# #### List All Sources

# %%
sources_df = pd.read_parquet(f"{URL}/parquet/level2/sources")
sources_df
# Out:
#                                                   context description  \
# 0       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 1       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 2       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 3       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 4       {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# ...                                                   ...         ...
# 103161  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 103162  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 103163  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 103164  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
# 103165  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...
#
#             quality          type           title  \
# 0       Not Checked  dcat:Dataset  Source Dataset
# 1       Not Checked  dcat:Dataset  Source Dataset
# 2       Not Checked  dcat:Dataset  Source Dataset
# 3       Not Checked  dcat:Dataset  Source Dataset
# 4       Not Checked  dcat:Dataset  Source Dataset
# ...             ...           ...             ...
# 103161  Not Checked  dcat:Dataset  Source Dataset
# 103162  Not Checked  dcat:Dataset  Source Dataset
# 103163  Not Checked  dcat:Dataset  Source Dataset
# 103164  Not Checked  dcat:Dataset  Source Dataset
# 103165  Not Checked  dcat:Dataset  Source Dataset
#
#                                         uuid                  name  \
# 0       0f3fbb3a-8915-593b-8a5e-bb2801bd5b6d           equilibrium
# 1       21df071f-d08f-540c-8f39-a799dc34535c         gas_injection
# 2       c97c0e5c-c26c-52af-9b37-f6660d08726d             magnetics
# 3       ba47b2a2-a6da-5d8e-b6c2-e093fbfc3553             pf_active
# 4       46662499-0e12-5e7a-a8b8-ec44cdfca24d        pulse_schedule
# ...                                      ...                   ...
# 103161  9d2c7bbd-8592-5e3b-a358-921879f34bd4         gas_injection
# 103162  7118a52b-91bc-5575-ae9d-388552642b72             magnetics
# 103163  8a94267d-3c38-516b-83ee-27ba71348716             pf_active
# 103164  7d455235-58fb-5918-9d04-0653d4972b89  spectrometer_visible
# 103165  5da1f1a6-c70f-5ad6-97c4-8e3b1f91da04               summary
#
#                                       url                endpoint_url  \
# 0       s3://mast/level2/shots/11766.zarr  https://s3.echo.stfc.ac.uk
# 1       s3://mast/level2/shots/11766.zarr  https://s3.echo.stfc.ac.uk
# 2       s3://mast/level2/shots/11766.zarr  https://s3.echo.stfc.ac.uk
# 3       s3://mast/level2/shots/11766.zarr  https://s3.echo.stfc.ac.uk
# 4       s3://mast/level2/shots/11766.zarr  https://s3.echo.stfc.ac.uk
# ...                                   ...                         ...
# 103161  s3://mast/level2/shots/30471.zarr  https://s3.echo.stfc.ac.uk
# 103162  s3://mast/level2/shots/30471.zarr  https://s3.echo.stfc.ac.uk
# 103163  s3://mast/level2/shots/30471.zarr  https://s3.echo.stfc.ac.uk
# 103164  s3://mast/level2/shots/30471.zarr  https://s3.echo.stfc.ac.uk
# 103165  s3://mast/level2/shots/30471.zarr  https://s3.echo.stfc.ac.uk
#
#                   imas  shot_id
# 0          equilibrium    11766
# 1        gas_injection    11766
# 2            magnetics    11766
# 3            pf_active    11766
# 4       pulse_schedule    11766
# ...                ...      ...
# 103161   gas_injection    30471
# 103162       magnetics    30471
# 103163       pf_active    30471
# 103164            None    30471
# 103165         summary    30471
#
# [103166 rows x 11 columns]

# %% [markdown]
# #### List all signals Given a Shot Number

# %%
signals_df = pd.read_parquet(f"{URL}/parquet/level2/signals?shot_id=30421")
signals_df
# Out:
#                                               context       shape provenance  \
# 0   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...   [73, 160]       None
# 1   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...   [73, 160]       None
# 2   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# 3   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# 4   {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# ..                                                ...         ...        ...
# 68  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  [146, 120]       None
# 69  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
# 70  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  [146, 120]       None
# 71  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...  [146, 120]       None
# 72  {'dcat': 'http://www.w3.org/ns/dcat#', 'dct': ...       [146]       None
#
#    description            dimensions      quality          type  \
# 0               [time, major_radius]  Not Checked  dcat:Dataset
# 1               [time, major_radius]  Not Checked  dcat:Dataset
# 2                             [time]  Not Checked  dcat:Dataset
# 3                             [time]  Not Checked  dcat:Dataset
# 4                             [time]  Not Checked  dcat:Dataset
# ..         ...                   ...          ...           ...
# 68              [time, major_radius]  Not Checked  dcat:Dataset
# 69                            [time]  Not Checked  dcat:Dataset
# 70              [time, major_radius]  Not Checked  dcat:Dataset
# 71              [time, major_radius]  Not Checked  dcat:Dataset
# 72                            [time]  Not Checked  dcat:Dataset
#
#              title                                  uuid         name  \
# 0   Signal Dataset  75756c34-c5b1-5e75-a53e-82bd90635d75          t_i
# 1   Signal Dataset  dcb14130-bf6a-5cc3-90ff-3985dad388a7          v_i
# 2   Signal Dataset  eb848f08-2f4e-54a6-8bd5-98a98823aa2e  beta_normal
# 3   Signal Dataset  cb95202b-279e-524a-b6af-899729ca9298     beta_pol
# 4   Signal Dataset  fd1ec81b-5eb9-5a59-b507-8b2df648e0ad     beta_tor
# ..             ...                                   ...          ...
# 68  Signal Dataset  f0b586cd-11ea-5208-927b-4e4f057a6c44          n_e
# 69  Signal Dataset  097cfe72-4d53-5a04-a7dc-97b1898e6e98     n_e_core
# 70  Signal Dataset  23c0ad57-6ff8-5222-9a7a-c897b661b9ad          p_e
# 71  Signal Dataset  6e2f4faf-7eb6-5f9e-a8a3-f0869af4abbf          t_e
# 72  Signal Dataset  c83667d9-fd83-5808-90b9-bb6750e98b77     t_e_core
#
#     version  rank                                url  \
# 0         0     2  s3://mast/level2/shots/30421.zarr
# 1         0     2  s3://mast/level2/shots/30421.zarr
# 2         0     1  s3://mast/level2/shots/30421.zarr
# 3         0     1  s3://mast/level2/shots/30421.zarr
# 4         0     1  s3://mast/level2/shots/30421.zarr
# ..      ...   ...                                ...
# 68        0     2  s3://mast/level2/shots/30421.zarr
# 69        0     1  s3://mast/level2/shots/30421.zarr
# 70        0     2  s3://mast/level2/shots/30421.zarr
# 71        0     2  s3://mast/level2/shots/30421.zarr
# 72        0     1  s3://mast/level2/shots/30421.zarr
#
#                   endpoint_url              source units                imas  \
# 0   https://s3.echo.stfc.ac.uk     charge_exchange    eV     charge_exchange
# 1   https://s3.echo.stfc.ac.uk     charge_exchange    eV     charge_exchange
# 2   https://s3.echo.stfc.ac.uk         equilibrium               equilibrium
# 3   https://s3.echo.stfc.ac.uk         equilibrium               equilibrium
# 4   https://s3.echo.stfc.ac.uk         equilibrium               equilibrium
# ..                         ...                 ...   ...                 ...
# 68  https://s3.echo.stfc.ac.uk  thomson_scattering    eV  thomson_scattering
# 69  https://s3.echo.stfc.ac.uk  thomson_scattering    eV  thomson_scattering
# 70  https://s3.echo.stfc.ac.uk  thomson_scattering    eV  thomson_scattering
# 71  https://s3.echo.stfc.ac.uk  thomson_scattering    eV  thomson_scattering
# 72  https://s3.echo.stfc.ac.uk  thomson_scattering    eV  thomson_scattering
#
#     shot_id
# 0     30421
# 1     30421
# 2     30421
# 3     30421
# 4     30421
# ..      ...
# 68    30421
# 69    30421
# 70    30421
# 71    30421
# 72    30421
#
# [73 rows x 18 columns]

# %% [markdown]
# #### Open and plot shot data.
#
# Here we are visualising some plasma current data.

# %%
import s3fs
import zarr
import xarray as xr
import matplotlib.pyplot as plt

endpoint_url = 'https://s3.echo.stfc.ac.uk'
url = f's3://mast/level2/shots/30421.zarr'

fs = s3fs.S3FileSystem(anon=True, endpoint_url=endpoint_url)
store =zarr.storage.FSStore(fs=fs, url=url)
dataset = xr.open_zarr(store, group='summary')

dataset['ip'].plot()
